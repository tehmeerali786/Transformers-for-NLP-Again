# %% [markdown]
# # Fake News

# %% [markdown]
# ## Fake News from an emotional perspective
#
# Allen NLP Sentiment Analysis with RoBERTa-large

# %%
# !pip install allennlp==1.0.0 allennlp-models==1.0.0
# Out:
# Collecting allennlp==1.0.0
#   Downloading allennlp-1.0.0-py3-none-any.whl (473 kB)
#      |████████████████████████████████| 473 kB 22.3 MB/s
# Collecting allennlp-models==1.0.0
#   Downloading allennlp_models-1.0.0-py3-none-any.whl (282 kB)
#      |████████████████████████████████| 282 kB 38.1 MB/s
# Requirement already satisfied: spacy<2.3,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (2.2.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (3.2.5)
# Collecting overrides==3.0.0
#   Downloading overrides-3.0.0.tar.gz (4.5 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting tensorboardX>=1.2
#   Downloading tensorboardX-2.4.1-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 56.6 MB/s
# Collecting transformers<2.12,>=2.9
#   Downloading transformers-2.11.0-py3-none-any.whl (674 kB)
#      |████████████████████████████████| 674 kB 37.2 MB/s
# Collecting boto3
#   Downloading boto3-1.20.13-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 48.2 MB/s
# Collecting torch<1.6.0,>=1.5.0
#   Downloading torch-1.5.1-cp37-cp37m-manylinux1_x86_64.whl (753.2 MB)
#      |████████████████████████████████| 753.2 MB 14 kB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (1.19.5)
# Collecting jsonnet>=0.10.0
#   Downloading jsonnet-0.17.0.tar.gz (259 kB)
#      |████████████████████████████████| 259 kB 48.8 MB/s
# Requirement already satisfied: requests>=2.18 in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (2.23.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (1.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (3.1.0)
# Requirement already satisfied: tqdm>=4.19 in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (4.62.3)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (3.6.4)
# Collecting filelock<3.1,>=3.0
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (1.4.1)
# Collecting py-rouge==1.1
#   Downloading py_rouge-1.1-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 2.4 MB/s
# Collecting word2number>=1.1
#   Downloading word2number-1.1.zip (9.7 kB)
# Collecting conllu==3.0
#   Downloading conllu-3.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18->allennlp==1.0.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18->allennlp==1.0.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18->allennlp==1.0.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18->allennlp==1.0.0) (3.0.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (0.8.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (57.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (7.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (2.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (1.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (0.4.1)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.3,>=2.1.0->allennlp==1.0.0) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<2.3,>=2.1.0->allennlp==1.0.0) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<2.3,>=2.1.0->allennlp==1.0.0) (3.6.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX>=1.2->allennlp==1.0.0) (3.17.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorboardX>=1.2->allennlp==1.0.0) (1.15.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch<1.6.0,>=1.5.0->allennlp==1.0.0) (0.16.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<2.12,>=2.9->allennlp==1.0.0) (2019.12.20)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 23.7 MB/s
# Collecting tokenizers==0.7.0
#   Downloading tokenizers-0.7.0-cp37-cp37m-manylinux1_x86_64.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 25.7 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 35.2 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers<2.12,>=2.9->allennlp==1.0.0) (21.3)
# Collecting botocore<1.24.0,>=1.23.13
#   Downloading botocore-1.23.13-py3-none-any.whl (8.2 MB)
#      |████████████████████████████████| 8.2 MB 51.9 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.2 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 61.7 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.24.0,>=1.23.13->boto3->allennlp==1.0.0) (2.8.2)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->allennlp==1.0.0) (1.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers<2.12,>=2.9->allennlp==1.0.0) (3.0.6)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp==1.0.0) (8.11.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp==1.0.0) (1.11.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp==1.0.0) (0.7.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp==1.0.0) (1.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp==1.0.0) (21.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<2.12,>=2.9->allennlp==1.0.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<2.12,>=2.9->allennlp==1.0.0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->allennlp==1.0.0) (3.0.0)
# Building wheels for collected packages: overrides, jsonnet, word2number
#   Building wheel for overrides (setup.py) ... done
#   Created wheel for overrides: filename=overrides-3.0.0-py3-none-any.whl size=5673 sha256=e50153e1bd8a4bf8bbb8198cd3b3c2d4a62c99fde151100f50c82922ba454681
#   Stored in directory: /root/.cache/pip/wheels/7d/c6/bf/bff44a9cc6c899e2d77ec968b2d0707616a3d66e4ebefb2411
#   Building wheel for jsonnet (setup.py) ... done
#   Created wheel for jsonnet: filename=jsonnet-0.17.0-cp37-cp37m-linux_x86_64.whl size=3388647 sha256=6b6c7751f370deb4d82749a1698d1e4c73d2e541720b4a5f658f1d3fe06b4ba6
#   Stored in directory: /root/.cache/pip/wheels/1c/28/7e/287c6b19f7161bb03c6986a3c46b51d0d7d9a1805346634e3a
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5580 sha256=9839dc86b173497058ae7b8e584e6943cbea5f8a9dc40db3929323ac95549e78
#   Stored in directory: /root/.cache/pip/wheels/4b/c3/77/a5f48aeb0d3efb7cd5ad61cbd3da30bbf9ffc9662b07c9f879
# Successfully built overrides jsonnet word2number
# Installing collected packages: urllib3, jmespath, botocore, tokenizers, sentencepiece, sacremoses, s3transfer, filelock, transformers, torch, tensorboardX, overrides, jsonpickle, jsonnet, boto3, word2number, py-rouge, conllu, allennlp, allennlp-models
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.4.0
#     Uninstalling filelock-3.4.0:
#       Successfully uninstalled filelock-3.4.0
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.11.1+cu111 requires torch==1.10.0, but you have torch 1.5.1 which is incompatible.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.5.1 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.5.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed allennlp-1.0.0 allennlp-models-1.0.0 boto3-1.20.13 botocore-1.23.13 conllu-3.0 filelock-3.0.12 jmespath-0.10.0 jsonnet-0.17.0 jsonpickle-2.0.0 overrides-3.0.0 py-rouge-1.1 s3transfer-0.5.0 sacremoses-0.0.46 sentencepiece-0.1.96 tensorboardX-2.4.1 tokenizers-0.7.0 torch-1.5.1 transformers-2.11.0 urllib3-1.25.11 word2number-1.1

# %%
# !echo '{"sentence":"Climate change is bogus. It’s a plot bye the liberals to take the economy down."}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz -
# Out:
# 2021-11-26 19:56:48,170 - INFO - transformers.file_utils - PyTorch version 1.5.1 available.
# 2021-11-26 19:56:55,943 - INFO - transformers.file_utils - TensorFlow version 2.7.0 available.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# 2021-11-26 19:56:59,023 - INFO - allennlp.common.file_utils - checking cache for https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz at /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2021-11-26 19:56:59,023 - INFO - allennlp.common.file_utils - waiting to acquire lock on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2021-11-26 19:56:59,024 - INFO - filelock - Lock 139897099968144 acquired on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac.lock
# 2021-11-26 19:56:59,024 - INFO - allennlp.common.file_utils - https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz not found in cache, downloading to /root/.allennlp/cache/tmp18d4p5sf.tmp
# 100% 1286605089/1286605089 [00:28<00:00, 45400967.74B/s]
# 2021-11-26 19:57:27,535 - INFO - allennlp.common.file_utils - Renaming temp file /root/.allennlp/cache/tmp18d4p5sf.tmp to cache at /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2021-11-26 19:57:27,535 - INFO - allennlp.common.file_utils - creating metadata file for /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2021-11-26 19:57:27,536 - INFO - filelock - Lock 139897099968144 released on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac.lock
# 2021-11-26 19:57:27,536 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz from cache at /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2021-11-26 19:57:27,536 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac to temp dir /tmp/tmp579vq2cy
# 2021-11-26 19:57:44,440 - INFO - allennlp.common.params - type = from_instances
# 2021-11-26 19:57:44,440 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmp579vq2cy/vocabulary.
# 2021-11-26 19:57:44,441 - INFO - filelock - Lock 139897101683920 acquired on /tmp/tmp579vq2cy/vocabulary/.lock
# 2021-11-26 19:57:44,441 - INFO - filelock - Lock 139897101683920 released on /tmp/tmp579vq2cy/vocabulary/.lock
# 2021-11-26 19:57:44,442 - INFO - allennlp.common.params - model.type = basic_classifier
# 2021-11-26 19:57:44,442 - INFO - allennlp.common.params - model.regularizer = None
# 2021-11-26 19:57:44,442 - INFO - allennlp.common.params - model.text_field_embedder.type = basic
# 2021-11-26 19:57:44,443 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.type = pretrained_transformer_mismatched
# 2021-11-26 19:57:44,443 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.model_name = roberta-large
# 2021-11-26 19:57:44,443 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.max_length = None
# 2021-11-26 19:57:44,443 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.train_parameters = True
# 2021-11-26 19:57:44,561 - INFO - filelock - Lock 139897099567184 acquired on /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748.lock
# 2021-11-26 19:57:44,562 - INFO - transformers.file_utils - https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmpytwoe52n
# Downloading: 100% 482/482 [00:00<00:00, 203kB/s]
# 2021-11-26 19:57:44,674 - INFO - transformers.file_utils - storing https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json in cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 19:57:44,674 - INFO - transformers.file_utils - creating metadata file for /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 19:57:44,675 - INFO - filelock - Lock 139897099567184 released on /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748.lock
# 2021-11-26 19:57:44,675 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 19:57:44,676 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 19:57:44,770 - INFO - filelock - Lock 139897092973072 acquired on /root/.cache/torch/transformers/2339ac1858323405dffff5156947669fed6f63a0c34cfab35bda4f78791893d2.fc7abf72755ecc4a75d0d336a93c1c63358d2334f5998ed326f3b0da380bf536.lock
# 2021-11-26 19:57:44,770 - INFO - transformers.file_utils - https://cdn.huggingface.co/roberta-large-pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmp3lwkif4f
# Downloading: 100% 1.43G/1.43G [00:32<00:00, 44.0MB/s]
# 2021-11-26 19:58:17,215 - INFO - transformers.file_utils - storing https://cdn.huggingface.co/roberta-large-pytorch_model.bin in cache at /root/.cache/torch/transformers/2339ac1858323405dffff5156947669fed6f63a0c34cfab35bda4f78791893d2.fc7abf72755ecc4a75d0d336a93c1c63358d2334f5998ed326f3b0da380bf536
# 2021-11-26 19:58:17,215 - INFO - transformers.file_utils - creating metadata file for /root/.cache/torch/transformers/2339ac1858323405dffff5156947669fed6f63a0c34cfab35bda4f78791893d2.fc7abf72755ecc4a75d0d336a93c1c63358d2334f5998ed326f3b0da380bf536
# 2021-11-26 19:58:17,216 - INFO - filelock - Lock 139897092973072 released on /root/.cache/torch/transformers/2339ac1858323405dffff5156947669fed6f63a0c34cfab35bda4f78791893d2.fc7abf72755ecc4a75d0d336a93c1c63358d2334f5998ed326f3b0da380bf536.lock
# 2021-11-26 19:58:17,216 - INFO - transformers.modeling_utils - loading weights file https://cdn.huggingface.co/roberta-large-pytorch_model.bin from cache at /root/.cache/torch/transformers/2339ac1858323405dffff5156947669fed6f63a0c34cfab35bda4f78791893d2.fc7abf72755ecc4a75d0d336a93c1c63358d2334f5998ed326f3b0da380bf536
# 2021-11-26 19:58:31,638 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 19:58:31,638 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 19:58:31,729 - INFO - filelock - Lock 139897084649360 acquired on /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b.lock
# 2021-11-26 19:58:31,729 - INFO - transformers.file_utils - https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmp5h5fl9qp
# Downloading: 100% 899k/899k [00:00<00:00, 8.75MB/s]
# 2021-11-26 19:58:31,946 - INFO - transformers.file_utils - storing https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json in cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2021-11-26
- INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2021-11-26 19:58:36,482 - INFO - allennlp.common.params - validation_dataset_reader.use_subtrees = False
# 2021-11-26 19:58:36,483 - INFO - allennlp.common.params - validation_dataset_reader.granularity = 2-class
# input 0:  {"sentence": "Climate change is bogus. It\u2019s a plot bye the liberals to take the economy down."}
# prediction:  {"logits": [-4.047706604003906, 2.729511022567749], "probs": [0.0011381438234820962, 0.9988619089126587], "token_ids": [0, 11001, 464, 16, 28007, 479, 85, 44, 27, 29, 10, 6197, 15687, 5, 19561, 7, 185, 5, 866, 159, 479, 2], "label": "0", "tokens": ["<s>", "\u0120Climate", "\u0120change", "\u0120is", "\u0120bogus", "\u0120.", "\u0120It", "\u0120\u00e2\u0122", "\u013b", "s", "\u0120a", "\u0120plot", "\u0120bye", "\u0120the", "\u0120liberals", "\u0120to", "\u0120take", "\u0120the", "\u0120economy", "\u0120down", "\u0120.", "</s>"]}
#
# 2021-11-26 19:58:39,446 - INFO - allennlp.models.archival - removing temporary unarchived model dir at /tmp/tmp579vq2cy

# %%
# !echo '{"sentence":"I am a Republican and think that climate change consciousness is a great thing!"}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz -
# Out:
# 2021-11-26 19:59:43,311 - INFO - transformers.file_utils - PyTorch version 1.5.1 available.
# 2021-11-26 19:59:49,578 - INFO - transformers.file_utils - TensorFlow version 2.7.0 available.
# 2021-11-26 19:59:51,515 - INFO - allennlp.common.file_utils - checking cache for https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz at /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2021-11-26 19:59:51,516 - INFO - allennlp.common.file_utils - waiting to acquire lock on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2021-11-26 19:59:51,516 - INFO - filelock - Lock 140420779141584 acquired on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac.lock
# 2021-11-26 19:59:51,517 - INFO - allennlp.common.file_utils - cache of https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz is up-to-date
# 2021-11-26 19:59:51,517 - INFO - filelock - Lock 140420779141584 released on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac.lock
# 2021-11-26 19:59:51,517 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz from cache at /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2021-11-26 19:59:51,517 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac to temp dir /tmp/tmpxwm050cj
# 2021-11-26 20:00:09,480 - INFO - allennlp.common.params - type = from_instances
# 2021-11-26 20:00:09,481 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmpxwm050cj/vocabulary.
# 2021-11-26 20:00:09,481 - INFO - filelock - Lock 140420771783824 acquired on /tmp/tmpxwm050cj/vocabulary/.lock
# 2021-11-26 20:00:09,482 - INFO - filelock - Lock 140420771783824 released on /tmp/tmpxwm050cj/vocabulary/.lock
# 2021-11-26 20:00:09,482 - INFO - allennlp.common.params - model.type = basic_classifier
# 2021-11-26 20:00:09,483 - INFO - allennlp.common.params - model.regularizer = None
# 2021-11-26 20:00:09,483 - INFO - allennlp.common.params - model.text_field_embedder.type = basic
# 2021-11-26 20:00:09,483 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.type = pretrained_transformer_mismatched
# 2021-11-26 20:00:09,484 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.model_name = roberta-large
# 2021-11-26 20:00:09,484 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.max_length = None
# 2021-11-26 20:00:09,484 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.train_parameters = True
# 2021-11-26 20:00:09,589 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 20:00:09,589 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 20:00:09,676 - INFO - transformers.modeling_utils - loading weights file https://cdn.huggingface.co/roberta-large-pytorch_model.bin from cache at /root/.cache/torch/transformers/2339ac1858323405dffff5156947669fed6f63a0c34cfab35bda4f78791893d2.fc7abf72755ecc4a75d0d336a93c1c63358d2334f5998ed326f3b0da380bf536
# 2021-11-26 20:00:24,262 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 20:00:24,263 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 20:00:24,456 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2021-11-26 20:00:24,456 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2021-11-26 20:00:24,708 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 20:00:24,708 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 20:00:24,891 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2021-11-26 20:00:24,892 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2021-11-26 20:00:25,037 - INFO - allennlp.common.params - model.seq2vec_encoder.type = cls_pooler
# 2021-11-26 20:00:25,037 - INFO - allennlp.common.params - model.seq2vec_encoder.embedding_dim = 1024
# 2021-11-26 20:00:25,037 - INFO - allennlp.common.params - model.seq2vec_encoder.cls_is_last_token = False
# 2021-11-26 20:00:25,037 - INFO - allennlp.common.params - model.seq2seq_encoder = None
# 2021-11-26 20:00:25,037 - INFO - allennlp.common.params - model.feedforward = None
# 2021-11-26 20:00:25,037 - INFO - allennlp.common.params - model.dropout = 0.1
# 2021-11-26 20:00:25,037 - INFO - allennlp.common.params - model.num_labels = None
# 2021-11-26 20:00:25,037 - INFO - allennlp.common.params - model.label_namespace = labels
# 2021-11-26 20:00:25,037 - INFO - allennlp.common.params - model.namespace = tags
# 2021-11-26 20:00:25,038 - INFO - allennlp.common.params - model.initializer = <allennlp.nn.initializers.InitializerApplicator object at 0x7fb64241da50>
# 2021-11-26 20:00:25,038 - INFO - allennlp.nn.initializers - Initializing parameters
# 2021-11-26 20:00:25,040 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _classification_layer.bias
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _classification_layer.weight
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.LayerNorm.bias
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.LayerNorm.weight
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.position_embeddings.weight
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.token_type_embeddings.weight
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.word_embeddings.weight
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.LayerNorm.bias
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.LayerNorm.weight
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.dense.bias
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.dense.weight
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.key.bias
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.key.weight
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.query.bias
# 2021-11-26 20:00:25,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.query.weight
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.value.bias
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.value.weight
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.intermediate.dense.bias
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.intermediate.dense.weight
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.LayerNorm.bias
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.LayerNorm.weight
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.dense.bias
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.dense.weight
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.LayerNorm.bias
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.LayerNorm.weight
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.dense.bias
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.dense.weight
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.key.bias
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.key.weight
# 2021-11-26 20:00:25,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.query.bias
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.query.weight
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.value.bias
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.value.weight
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.intermediate.dense.bias
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.intermediate.dense.weight
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.output.LayerNorm.bias
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.output.LayerNorm.weight
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.output.dense.bias
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.output.dense.weight
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.output.LayerNorm.bias
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.output.LayerNorm.weight
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.output.dense.bias
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.output.dense.weight
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.key.bias
# 2021-11-26 20:00:25,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.key.weight
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.query.bias
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.query.weight
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.value.bias
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.value.weight
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.intermediate.dense.bias
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.intermediate.dense.weight
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.output.LayerNorm.bias
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.output.LayerNorm.weight
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.output.dense.bias
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.output.dense.weight
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.output.LayerNorm.bias
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.output.LayerNorm.weight
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.output.dense.bias
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.output.dense.weight
# 2021-11-26 20:00:25,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.key.bias
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.key.weight
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.query.bias
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.query.weight
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.value.bias
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.value.weight
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.intermediate.dense.bias
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.intermediate.dense.weight
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.output.LayerNorm.bias
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.output.LayerNorm.weight
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.output.dense.bias
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.output.dense.weight
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.output.LayerNorm.bias
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.output.LayerNorm.weight
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.output.dense.bias
# 2021-11-26 20:00:25,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.output.dense.weight
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.key.bias
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.key.weight
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.query.bias
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.query.weight
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.value.bias
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.value.weight
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.intermediate.dense.bias
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.intermediate.dense.weight
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.output.LayerNorm.bias
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.output.LayerNorm.weight
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.output.dense.bias
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.output.dense.weight
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.output.LayerNorm.bias
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.output.LayerNorm.weight
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.output.dense.bias
# 2021-11-26 20:00:25,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.output.dense.weight
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.self.key.bias
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.self.key.weight
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.self.query.bias
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.self.query.weight
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.self.value.bias
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.self.value.weight
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.intermediate.dense.bias
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.intermediate.dense.weight
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.output.LayerNorm.bias
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.output.LayerNorm.weight
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.output.dense.bias
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.output.dense.weight
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.output.LayerNorm.bias
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.output.LayerNorm.weight
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.output.dense.bias
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.output.dense.weight
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.self.key.bias
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.self.key.weight
# 2021-11-26 20:00:25,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.self.query.bias
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.self.query.weight
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.self.value.bias
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.self.value.weight
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.intermediate.dense.bias
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.intermediate.dense.weight
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.output.LayerNorm.bias
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.output.LayerNorm.weight
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.output.dense.bias
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.output.dense.weight
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.output.LayerNorm.bias
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.output.LayerNorm.weight
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.output.dense.bias
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.output.dense.weight
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.self.key.bias
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.self.key.weight
# 2021-11-26 20:00:25,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.self.query.bias
# 2021-11-26 20:00:25,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.self.query.weight
# 2021-11-26 20:00:25,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.self.value.bias
# 2021-11-26 20:00:25,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.self.value.weight
# 2021-11-26 20:00:25,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.intermediate.dense.bias
# 2021-11-26 20:00:25,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.intermediate.dense.weight
# 2021-11-26 20:00:25,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.output.LayerNorm.bias
# 2021-11-26 20:00:25,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.output.LayerNorm.weight
# 2021-11-26 20:00:25,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.output.dense.bias
# 2021-11-26 20:00:25,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.output.dense.weight
# 2021-11-26 20:00:25,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.output.LayerNorm.bias
# 2021-11-26 20:00:25,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.output.LayerNorm.weight
# 2021-11-26 20:00:25,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.output.dense.bias
# 2021-11-26 20:00:25,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.output.dense.weight
# 2021-11-26 20:00:25,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.self.key.bias
# 2021-11-26 20:00:25
070 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.weight
# 2021-11-26 20:00:25,070 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.bias
# 2021-11-26 20:00:25,070 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.weight
# 2021-11-26 20:00:25,070 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.bias
# 2021-11-26 20:00:25,070 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.weight
# 2021-11-26 20:00:25,070 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.bias
# 2021-11-26 20:00:25,070 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.weight
# 2021-11-26 20:00:25,070 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.bias
# 2021-11-26 20:00:25,070 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.weight
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.bias
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.bias
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.weight
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.bias
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.weight
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.bias
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.weight
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.bias
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.weight
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.bias
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.weight
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.bias
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.weight
# 2021-11-26 20:00:25,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.bias
# 2021-11-26 20:00:25,072 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.weight
# 2021-11-26 20:00:25,072 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.bias
# 2021-11-26 20:00:25,072 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.weight
# 2021-11-26 20:00:28,954 - INFO - allennlp.common.params - validation_dataset_reader.type = sst_tokens
# 2021-11-26 20:00:28,954 - INFO - allennlp.common.params - validation_dataset_reader.lazy = False
# 2021-11-26 20:00:28,954 - INFO - allennlp.common.params - validation_dataset_reader.cache_directory = None
# 2021-11-26 20:00:28,955 - INFO - allennlp.common.params - validation_dataset_reader.max_instances = None
# 2021-11-26 20:00:28,955 - INFO - allennlp.common.params - validation_dataset_reader.manual_distributed_sharding = False
# 2021-11-26 20:00:28,955 - INFO - allennlp.common.params - validation_dataset_reader.manual_multi_process_sharding = False
# 2021-11-26 20:00:28,955 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2021-11-26 20:00:28,955 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2021-11-26 20:00:28,955 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.model_name = roberta-large
# 2021-11-26 20:00:28,955 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.namespace = tags
# 2021-11-26 20:00:28,955 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.max_length = None
# 2021-11-26 20:00:29,045 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 20:00:29,046 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 20:00:29,241 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2021-11-26 20:00:29,242 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2021-11-26 20:00:29,442 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 20:00:29,443 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 20:00:29,612 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2021-11-26 20:00:29,612 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2021-11-26 20:00:29,814 - INFO - allennlp.common.params - validation_dataset_reader.use_subtrees = False
# 2021-11-26 20:00:29,814 - INFO - allennlp.common.params - validation_dataset_reader.granularity = 2-class
# input 0:  {"sentence": "I am a Republican and think that climate change consciousness is a great thing!"}
# prediction:  {"logits": [4.248127460479736, -3.327800989151001], "probs": [0.9994876384735107, 0.0005123814917169511], "token_ids": [0, 38, 524, 10, 1172, 8, 206, 14, 2147, 464, 16253, 16, 10, 372, 631, 27785, 2], "label": "1", "tokens": ["<s>", "\u0120I", "\u0120am", "\u0120a", "\u0120Republican", "\u0120and", "\u0120think", "\u0120that", "\u0120climate", "\u0120change", "\u0120consciousness", "\u0120is", "\u0120a", "\u0120great", "\u0120thing", "\u0120!", "</s>"]}
#
# 2021-11-26 20:00:31,668 - INFO - allennlp.models.archival - removing temporary unarchived model dir at /tmp/tmpxwm050cj

# %% [markdown]
# ## Gun Control

# %%
# !echo '{"sentence":"I have had rifles and guns for years and never had a problem. I raised my kids right so they have guns too and never hurt anything except rabbits. "}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz -
# Out:
# 2021-11-26 21:01:53,867 - INFO - transformers.file_utils - PyTorch version 1.5.1 available.
# 2021-11-26 21:02:01,490 - INFO - transformers.file_utils - TensorFlow version 2.7.0 available.
# 2021-11-26 21:02:03,670 - INFO - allennlp.common.file_utils - checking cache for https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz at /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2021-11-26 21:02:03,670 - INFO - allennlp.common.file_utils - waiting to acquire lock on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2021-11-26 21:02:03,671 - INFO - filelock - Lock 140079281073168 acquired on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac.lock
# 2021-11-26 21:02:03,671 - INFO - allennlp.common.file_utils - cache of https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz is up-to-date
# 2021-11-26 21:02:03,672 - INFO - filelock - Lock 140079281073168 released on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac.lock
# 2021-11-26 21:02:03,672 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz from cache at /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2021-11-26 21:02:03,672 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac to temp dir /tmp/tmpdg3i3b6o
# 2021-11-26 21:02:31,552 - INFO - allennlp.common.params - type = from_instances
# 2021-11-26 21:02:31,552 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmpdg3i3b6o/vocabulary.
# 2021-11-26 21:02:31,552 - INFO - filelock - Lock 140079271349328 acquired on /tmp/tmpdg3i3b6o/vocabulary/.lock
# 2021-11-26 21:02:31,553 - INFO - filelock - Lock 140079271349328 released on /tmp/tmpdg3i3b6o/vocabulary/.lock
# 2021-11-26 21:02:31,553 - INFO - allennlp.common.params - model.type = basic_classifier
# 2021-11-26 21:02:31,554 - INFO - allennlp.common.params - model.regularizer = None
# 2021-11-26 21:02:31,554 - INFO - allennlp.common.params - model.text_field_embedder.type = basic
# 2021-11-26 21:02:31,554 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.type = pretrained_transformer_mismatched
# 2021-11-26 21:02:31,555 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.model_name = roberta-large
# 2021-11-26 21:02:31,555 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.max_length = None
# 2021-11-26 21:02:31,555 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.train_parameters = True
# 2021-11-26 21:02:31,688 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 21:02:31,689 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 21:02:31,782 - INFO - transformers.modeling_utils - loading weights file https://cdn.huggingface.co/roberta-large-pytorch_model.bin from cache at /root/.cache/torch/transformers/2339ac1858323405dffff5156947669fed6f63a0c34cfab35bda4f78791893d2.fc7abf72755ecc4a75d0d336a93c1c63358d2334f5998ed326f3b0da380bf536
# 2021-11-26 21:02:51,261 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 21:02:51,262 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 21:02:51,472 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2021-11-26 21:02:51,472 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2021-11-26 21:02:51,733 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 21:02:51,733 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 21:02:51,946 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2021-11-26 21:02:51,946 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2021-11-26 21:02:52,097 - INFO - allennlp.common.params - model.seq2vec_encoder.type = cls_pooler
# 2021-11-26 21:02:52,097 - INFO - allennlp.common.params - model.seq2vec_encoder.embedding_dim = 1024
# 2021-11-26 21:02:52,097 - INFO - allennlp.common.params - model.seq2vec_encoder.cls_is_last_token = False
# 2021-11-26 21:02:52,097 - INFO - allennlp.common.params - model.seq2seq_encoder = None
# 2021-11-26 21:02:52,097 - INFO - allennlp.common.params - model.feedforward = None
# 2021-11-26 21:02:52,098 - INFO - allennlp.common.params - model.dropout = 0.1
# 2021-11-26 21:02:52,098 - INFO - allennlp.common.params - model.num_labels = None
# 2021-11-26 21:02:52,098 - INFO - allennlp.common.params - model.label_namespace = labels
# 2021-11-26 21:02:52,098 - INFO - allennlp.common.params - model.namespace = tags
# 2021-11-26 21:02:52,098 - INFO - allennlp.common.params - model.initializer = <allennlp.nn.initializers.InitializerApplicator object at 0x7f66bf6299d0>
# 2021-11-26 21:02:52,099 - INFO - allennlp.nn.initializers - Initializing parameters
# 2021-11-26 21:02:52,102 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2021-11-26 21:02:52,102 - INFO - allennlp.nn.initializers -    _classification_layer.bias
# 2021-11-26 21:02:52,102 - INFO - allennlp.nn.initializers -    _classification_layer.weight
# 2021-11-26 21:02:52,102 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.LayerNorm.bias
# 2021-11-26 21:02:52,102 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.LayerNorm.weight
# 2021-11-26 21:02:52,103 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings
- INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2021-11-26 21:02:57,377 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2021-11-26 21:02:57,377 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.model_name = roberta-large
# 2021-11-26 21:02:57,377 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.namespace = tags
# 2021-11-26 21:02:57,377 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.max_length = None
# 2021-11-26 21:02:57,485 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 21:02:57,486 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 21:02:57,704 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2021-11-26 21:02:57,705 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2021-11-26 21:02:57,931 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 21:02:57,932 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 21:02:58,133 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2021-11-26 21:02:58,133 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2021-11-26 21:02:58,298 - INFO - allennlp.common.params - validation_dataset_reader.use_subtrees = False
# 2021-11-26 21:02:58,298 - INFO - allennlp.common.params - validation_dataset_reader.granularity = 2-class
# input 0:  {"sentence": "I have had rifles and guns for years and never had a problem. I raised my kids right so they have guns too and never hurt anything except rabbits. "}
# prediction:  {"logits": [1.9383275508880615, -1.6191326379776], "probs": [0.9722791910171509, 0.02772079035639763], "token_ids": [0, 38, 33, 56, 17509, 8, 5013, 13, 107, 8, 393, 56, 10, 936, 479, 38, 1179, 127, 1159, 235, 98, 51, 33, 5013, 350, 8, 393, 2581, 932, 4682, 33899, 479, 2], "label": "1", "tokens": ["<s>", "\u0120I", "\u0120have", "\u0120had", "\u0120rifles", "\u0120and", "\u0120guns", "\u0120for", "\u0120years", "\u0120and", "\u0120never", "\u0120had", "\u0120a", "\u0120problem", "\u0120.", "\u0120I", "\u0120raised", "\u0120my", "\u0120kids", "\u0120right", "\u0120so", "\u0120they", "\u0120have", "\u0120guns", "\u0120too", "\u0120and", "\u0120never", "\u0120hurt", "\u0120anything", "\u0120except", "\u0120rabbits", "\u0120.", "</s>"]}
#
# 2021-11-26 21:03:00,710 - INFO - allennlp.models.archival - removing temporary unarchived model dir at /tmp/tmpdg3i3b6o

# %%
# !echo '{"sentence":"I have heard gunshots all my life in my neighborhood, have lost many friends, and am afraid to go out at night."}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz -
# Out:
# 2021-11-26 21:04:35,471 - INFO - transformers.file_utils - PyTorch version 1.5.1 available.
# 2021-11-26 21:04:40,001 - INFO - transformers.file_utils - TensorFlow version 2.7.0 available.
# 2021-11-26 21:04:41,199 - INFO - allennlp.common.file_utils - checking cache for https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz at /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2021-11-26 21:04:41,199 - INFO - allennlp.common.file_utils - waiting to acquire lock on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2021-11-26 21:04:41,200 - INFO - filelock - Lock 140435135785936 acquired on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac.lock
# 2021-11-26 21:04:41,200 - INFO - allennlp.common.file_utils - cache of https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz is up-to-date
# 2021-11-26 21:04:41,200 - INFO - filelock - Lock 140435135785936 released on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac.lock
# 2021-11-26 21:04:41,200 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz from cache at /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2021-11-26 21:04:41,201 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac to temp dir /tmp/tmpwii8zg6_
# 2021-11-26 21:04:57,723 - INFO - allennlp.common.params - type = from_instances
# 2021-11-26 21:04:57,723 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmpwii8zg6_/vocabulary.
# 2021-11-26 21:04:57,723 - INFO - filelock - Lock 140435125968336 acquired on /tmp/tmpwii8zg6_/vocabulary/.lock
# 2021-11-26 21:04:57,724 - INFO - filelock - Lock 140435125968336 released on /tmp/tmpwii8zg6_/vocabulary/.lock
# 2021-11-26 21:04:57,725 - INFO - allennlp.common.params - model.type = basic_classifier
# 2021-11-26 21:04:57,725 - INFO - allennlp.common.params - model.regularizer = None
# 2021-11-26 21:04:57,726 - INFO - allennlp.common.params - model.text_field_embedder.type = basic
# 2021-11-26 21:04:57,726 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.type = pretrained_transformer_mismatched
# 2021-11-26 21:04:57,726 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.model_name = roberta-large
# 2021-11-26 21:04:57,727 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.max_length = None
# 2021-11-26 21:04:57,727 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.train_parameters = True
# 2021-11-26 21:04:57,836 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 21:04:57,836 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 21:04:57,980 - INFO - transformers.modeling_utils - loading weights file https://cdn.huggingface.co/roberta-large-pytorch_model.bin from cache at /root/.cache/torch/transformers/2339ac1858323405dffff5156947669fed6f63a0c34cfab35bda4f78791893d2.fc7abf72755ecc4a75d0d336a93c1c63358d2334f5998ed326f3b0da380bf536
# 2021-11-26 21:05:12,455 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 21:05:12,455 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 21:05:12,658 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2021-11-26 21:05:12,659 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2021-11-26 21:05:12,905 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 21:05:12,905 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 21:05:13,102 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2021-11-26 21:05:13,102 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2021-11-26 21:05:13,257 - INFO - allennlp.common.params - model.seq2vec_encoder.type = cls_pooler
# 2021-11-26 21:05:13,257 - INFO - allennlp.common.params - model.seq2vec_encoder.embedding_dim = 1024
# 2021-11-26 21:05:13,257 - INFO - allennlp.common.params - model.seq2vec_encoder.cls_is_last_token = False
# 2021-11-26 21:05:13,258 - INFO - allennlp.common.params - model.seq2seq_encoder = None
# 2021-11-26 21:05:13,258 - INFO - allennlp.common.params - model.feedforward = None
# 2021-11-26 21:05:13,258 - INFO - allennlp.common.params - model.dropout = 0.1
# 2021-11-26 21:05:13,258 - INFO - allennlp.common.params - model.num_labels = None
# 2021-11-26 21:05:13,259 - INFO - allennlp.common.params - model.label_namespace = labels
# 2021-11-26 21:05:13,259 - INFO - allennlp.common.params - model.namespace = tags
# 2021-11-26 21:05:13,259 - INFO - allennlp.common.params - model.initializer = <allennlp.nn.initializers.InitializerApplicator object at 0x7fb999faa890>
# 2021-11-26 21:05:13,260 - INFO - allennlp.nn.initializers - Initializing parameters
# 2021-11-26 21:05:13,262 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2021-11-26 21:05:13,262 - INFO - allennlp.nn.initializers -    _classification_layer.bias
# 2021-11-26 21:05:13,262 - INFO - allennlp.nn.initializers -    _classification_layer.weight
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.LayerNorm.bias
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.LayerNorm.weight
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.position_embeddings.weight
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.token_type_embeddings.weight
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.word_embeddings.weight
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.LayerNorm.bias
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.LayerNorm.weight
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.dense.bias
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.dense.weight
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.key.bias
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.key.weight
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.query.bias
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.query.weight
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.value.bias
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.value.weight
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.intermediate.dense.bias
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.intermediate.dense.weight
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.LayerNorm.bias
# 2021-11-26 21:05:13,263 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.LayerNorm.weight
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.dense.bias
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.dense.weight
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.LayerNorm.bias
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.LayerNorm.weight
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.dense.bias
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.dense.weight
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.key.bias
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.key.weight
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.query.bias
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.query.weight
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.value.bias
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.value.weight
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.intermediate.dense.bias
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.intermediate.dense.weight
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.output.LayerNorm.bias
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.output.LayerNorm.weight
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.output.dense.bias
# 2021-11-26 21:05:13,264 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.output.dense.weight
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.output.LayerNorm.bias
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.output.LayerNorm.weight
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.output.dense.bias
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.output.dense.weight
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.key.bias
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.key.weight
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.query.bias
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.query.weight
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.value.bias
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.value.weight
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.intermediate.dense.bias
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.intermediate.dense.weight
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.output.LayerNorm.bias
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.output.LayerNorm.weight
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.output.dense.bias
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.output.dense.weight
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.output.LayerNorm.bias
# 2021-11-26 21:05:13,265 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.output.LayerNorm.weight
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.output.dense.bias
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.output.dense.weight
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.key.bias
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.key.weight
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.query.bias
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.query.weight
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.value.bias
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.value.weight
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.intermediate.dense.bias
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.intermediate.dense.weight
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.output.LayerNorm.bias
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.output.LayerNorm.weight
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.output.dense.bias
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.output.dense.weight
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.output.LayerNorm.bias
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.output.LayerNorm.weight
# 2021-11-26 21:05:13,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.output.dense.bias
# 2021-11-26 21:05:13,267 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.output.dense.weight
# 2021-11-26 21:05:13,267 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.key.bias
# 2021-11-26 21:05:13,267 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.key.weight
# 2021-11-26 21:05:13,267 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.query.bias
# 2021-11-26 21:05:13,267 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.query.weight
# 2021-11-26 21:05:13,267 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.value.bias
# 2021-11-26 21:05:13,305 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.value.weight
# 2021-11-26 21:05:13,305 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.intermediate.dense.bias
# 2021-11-26 21:05:13,306 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.intermediate.dense.weight
# 2021-11-26 21:05:13,306 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.output.LayerNorm
# 2021-11-26 21:05:13,317 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.output.LayerNorm.weight
# 2021-11-26 21:05:13,317 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.output.dense.bias
# 2021-11-26 21:05:13,317 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.output.dense.weight
# 2021-11-26 21:05:13,317 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.output.LayerNorm.bias
# 2021-11-26 21:05:13,317 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.output.LayerNorm.weight
# 2021-11-26 21:05:13,317 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.output.dense.bias
# 2021-11-26 21:05:13,317 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.output.dense.weight
# 2021-11-26 21:05:13,317 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.self.key.bias
# 2021-11-26 21:05:13,317 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.self.key.weight
# 2021-11-26 21:05:13,318 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.self.query.bias
# 2021-11-26 21:05:13,318 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.self.query.weight
# 2021-11-26 21:05:13,318 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.self.value.bias
# 2021-11-26 21:05:13,318 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.self.value.weight
# 2021-11-26 21:05:13,318 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.intermediate.dense.bias
# 2021-11-26 21:05:13,318 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.intermediate.dense.weight
# 2021-11-26 21:05:13,318 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.output.LayerNorm.bias
# ...
# 2021-11-26 21:05:13,421 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.intermediate.dense.bias
# 2021-11-26 21:05:13,421 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.intermediate.dense.weight
# 2021-11-26 21:05:13,422 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.LayerNorm.bias
# 2021-11-26 21:05:13,422 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.LayerNorm.weight
# 2021-11-26 21:05:13,422 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.dense.bias
# 2021-11-26 21:05:13,422 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.dense.weight
# 2021-11-26 21:05:13,422 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.LayerNorm.bias
# 2021-11-26 21:05:13,422 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.LayerNorm.weight
# 2021-11-26 21:05:13,422 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.dense.bias
# 2021-11-26 21:05:13,422 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.dense.weight
# 2021-11-26 21:05:13,422 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.key.bias
# 2021-11-26 21:05:13,517 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.key.weight
# 2021-11-26 21:05:13,517 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.query.bias
# 2021-11-26 21:05:13,517 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.query.weight
# 2021-11-26 21:05:13,517 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.value.bias
# 2021-11-26 21:05:13,517 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.value.weight
# 2021-11-26 21:05:13,517 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.intermediate.dense.bias
# 2021-11-26 21:05:13,517 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.intermediate.dense.weight
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.LayerNorm.bias
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.LayerNorm.weight
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.dense.bias
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.dense.weight
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.LayerNorm.bias
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.LayerNorm.weight
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.bias
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.weight
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.bias
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.weight
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.bias
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.weight
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.bias
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.weight
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.bias
# 2021-11-26 21:05:13,518 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.weight
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.bias
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.weight
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.bias
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.weight
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.bias
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.bias
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.weight
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.bias
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.weight
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.bias
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.weight
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.bias
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.weight
# 2021-11-26 21:05:13,519 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.bias
# 2021-11-26 21:05:13,520 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.weight
# 2021-11-26 21:05:13,520 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.bias
# 2021-11-26 21:05:13,520 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.weight
# 2021-11-26 21:05:13,520 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.bias
# 2021-11-26 21:05:13,520 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.weight
# 2021-11-26 21:05:13,520 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.bias
# 2021-11-26 21:05:13,520 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.weight
# 2021-11-26 21:05:17,513 - INFO - allennlp.common.params - validation_dataset_reader.type = sst_tokens
# 2021-11-26 21:05:17,514 - INFO - allennlp.common.params - validation_dataset_reader.lazy = False
# 2021-11-26 21:05:17,514 - INFO - allennlp.common.params - validation_dataset_reader.cache_directory = None
# 2021-11-26 21:05:17,514 - INFO - allennlp.common.params - validation_dataset_reader.max_instances = None
# 2021-11-26 21:05:17,514 - INFO - allennlp.common.params - validation_dataset_reader.manual_distributed_sharding = False
# 2021-11-26 21:05:17,514 - INFO - allennlp.common.params - validation_dataset_reader.manual_multi_process_sharding = False
# 2021-11-26 21:05:17,514 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2021-11-26 21:05:17,515 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2021-11-26 21:05:17,515 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.model_name = roberta-large
# 2021-11-26 21:05:17,515 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.namespace = tags
# 2021-11-26 21:05:17,515 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.max_length = None
# 2021-11-26 21:05:17,612 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 21:05:17,613 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 21:05:17,813 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2021-11-26 21:05:17,813 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2021-11-26 21:05:18,053 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2021-11-26 21:05:18,053 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2021-11-26 21:05:18,299 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2021-11-26 21:05:18,299 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2021-11-26 21:05:18,491 - INFO - allennlp.common.params - validation_dataset_reader.use_subtrees = False
# 2021-11-26 21:05:18,492 - INFO - allennlp.common.params - validation_dataset_reader.granularity = 2-class
# input 0:  {"sentence": "I have heard gunshots all my life in my neighborhood, have lost many friends, and am afraid to go out at night."}
# prediction:  {"logits": [-1.3564586639404297, 0.5901418924331665], "probs": [0.12492450326681137, 0.8750754594802856], "token_ids": [0, 38, 33, 1317, 21715, 70, 127, 301, 11, 127, 3757, 2156, 33, 685, 171, 964, 2156, 8, 524, 6023, 7, 213, 66, 23, 363, 479, 2], "label": "0", "tokens": ["<s>", "\u0120I", "\u0120have", "\u0120heard", "\u0120gunshots", "\u0120all", "\u0120my", "\u0120life", "\u0120in", "\u0120my", "\u0120neighborhood", "\u0120,", "\u0120have", "\u0120lost", "\u0120many", "\u0120friends", "\u0120,", "\u0120and", "\u0120am", "\u0120afraid", "\u0120to", "\u0120go", "\u0120out", "\u0120at", "\u0120night", "\u0120.", "</s>"]}
#
# 2021-11-26 21:05:20,378 - INFO - allennlp.models.archival - removing temporary unarchived model dir at /tmp/tmpwii8zg6_

# %%
# !pip install -q transformers

# %%
from transformers import pipeline 
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AutoModel

# %%
nlp_token_class = pipeline('ner')
nlp_token_class('I have had rifles and guns for years and never had a problem. I raised my kids right so they have guns too and never hurt anything except rabbits.')
# Out:
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/998 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/230 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# []

# %%
nlp_token_class.model.config
# Out:
# BertConfig {
#   "_num_labels": 9,
#   "architectures": [
#     "BertForTokenClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "id2label": {
#     "0": "O",
#     "1": "B-MISC",
#     "2": "I-MISC",
#     "3": "B-PER",
#     "4": "I-PER",
#     "5": "B-ORG",
#     "6": "I-ORG",
#     "7": "B-LOC",
#     "8": "I-LOC"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "label2id": {
#     "B-LOC": 7,
#     "B-MISC": 1,
#     "B-ORG": 5,
#     "B-PER": 3,
#     "I-LOC": 8,
#     "I-MISC": 2,
#     "I-ORG": 6,
#     "I-PER": 4,
#     "O": 0
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "type_vocab_size": 2,
#   "vocab_size": 28996
# }

# %%
# !echo '{"sentence": "I have heard gunshots all my life in my neighborhood, have lost many friends, and am afraid to go out at night."}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/bert-base-srl-2020.03.24.tar.gz -
# Out:
# 2021-11-26 21:13:57,985 - INFO - transformers.file_utils - PyTorch version 1.5.1 available.
# 2021-11-26 21:14:01,902 - INFO - transformers.file_utils - TensorFlow version 2.7.0 available.
# 2021-11-26 21:14:03,149 - INFO - allennlp.common.file_utils - checking cache for https://storage.googleapis.com/allennlp-public-models/bert-base-srl-2020.03.24.tar.gz at /root/.allennlp/cache/e20d5b792a8d456a1a61da245d1856d4b7778efe69ac3c30759af61940aa0f42.f72523a9682cb1f5ad3ecf834075fe53a1c25a6bcbf4b40c11e13b7f426a4724
# 2021-11-26 21:14:03,150 - INFO - allennlp.common.file_utils - waiting to acquire lock on /root/.allennlp/cache/e20d5b792a8d456a1a61da245d1856d4b7778efe69ac3c30759af61940aa0f42.f72523a9682cb1f5ad3ecf834075fe53a1c25a6bcbf4b40c11e13b7f426a4724
# 2021-11-26 21:14:03,150 - INFO - filelock - Lock 140660662165712 acquired on /root/.allennlp/cache/e20d5b792a8d456a1a61da245d1856d4b7778efe69ac3c30759af61940aa0f42.f72523a9682cb1f5ad3ecf834075fe53a1c25a6bcbf4b40c11e13b7f426a4724.lock
# 2021-11-26 21:14:03,151 - INFO - allennlp.common.file_utils - https://storage.googleapis.com/allennlp-public-models/bert-base-srl-2020.03.24.tar.gz not found in cache, downloading to /root/.allennlp/cache/tmpyotfnv8t.tmp
# 100% 406056588/406056588 [00:12<00:00, 32856670.72B/s]
# 2021-11-26 21:14:15,675 - INFO - allennlp.common.file_utils - Renaming temp file /root/.allennlp/cache/tmpyotfnv8t.tmp to cache at /root/.allennlp/cache/e20d5b792a8d456a1a61da245d1856d4b7778efe69ac3c30759af61940aa0f42.f72523a9682cb1f5ad3ecf834075fe53a1c25a6bcbf4b40c11e13b7f426a4724
# 2021-11-26 21:14:15,676 - INFO - allennlp.common.file_utils - creating metadata file for /root/.allennlp/cache/e20d5b792a8d456a1a61da245d1856d4b7778efe69ac3c30759af61940aa0f42.f72523a9682cb1f5ad3ecf834075fe53a1c25a6bcbf4b40c11e13b7f426a4724
# 2021-11-26 21:14:15,676 - INFO - filelock - Lock 140660662165712 released on /root/.allennlp/cache/e20d5b792a8d456a1a61da245d1856d4b7778efe69ac3c30759af61940aa0f42.f72523a9682cb1f5ad3ecf834075fe53a1c25a6bcbf4b40c11e13b7f426a4724.lock
# 2021-11-26 21:14:15,676 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/bert-base-srl-2020.03.24.tar.gz from cache at /root/.allennlp/cache/e20d5b792a8d456a1a61da245d1856d4b7778efe69ac3c30759af61940aa0f42.f72523a9682cb1f5ad3ecf834075fe53a1c25a6bcbf4b40c11e13b7f426a4724
# 2021-11-26 21:14:15,676 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/e20d5b792a8d456a1a61da245d1856d4b7778efe69ac3c30759af61940aa0f42.f72523a9682cb1f5ad3ecf834075fe53a1c25a6bcbf4b40c11e13b7f426a4724 to temp dir /tmp/tmpvxt7vokn
# 2021-11-26 21:14:21,824 - INFO - allennlp.common.params - type = from_instances
# 2021-11-26 21:14:21,824 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmpvxt7vokn/vocabulary.
# 2021-11-26 21:14:21,824 - INFO - filelock - Lock 140660661054864 acquired on /tmp/tmpvxt7vokn/vocabulary/.lock
# 2021-11-26 21:14:21,871 - INFO - filelock - Lock 140660661054864 released on /tmp/tmpvxt7vokn/vocabulary/.lock
# 2021-11-26 21:14:21,872 - INFO - allennlp.common.params - model.type = srl_bert
# 2021-11-26 21:14:21,872 - INFO - allennlp.common.params - model.regularizer = None
# 2021-11-26 21:14:21,872 - INFO - allennlp.common.params - model.bert_model = bert-base-uncased
# 2021-11-26 21:14:21,873 - INFO - allennlp.common.params - model.embedding_dropout = 0.1
# 2021-11-26 21:14:21,873 - INFO - allennlp.common.params - model.initializer = <allennlp.nn.initializers.InitializerApplicator object at 0x7fed34064c90>
# 2021-11-26 21:14:21,873 - INFO - allennlp.common.params - model.label_smoothing = None
# 2021-11-26 21:14:21,873 - INFO - allennlp.common.params - model.ignore_span_metric = False
# 2021-11-26 21:14:21,873 - INFO - allennlp.common.params - model.srl_eval_path = /usr/local/lib/python3.7/dist-packages/allennlp_models/structured_prediction/tools/srl-eval.pl
# 2021-11-26 21:14:21,998 - INFO - filelock - Lock 140656740993616 acquired on /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517.lock
# 2021-11-26 21:14:21,999 - INFO - transformers.file_utils - https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmpsv_ubzze
# Downloading: 100% 433/433 [00:00<00:00, 230kB/s]
# 2021-11-26 21:14:22,110 - INFO - transformers.file_utils - storing https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json in cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2021-11-26 21:14:22,110 - INFO - transformers.file_utils - creating metadata file for /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2021-11-26 21:14:22,110 - INFO - filelock - Lock 140656740993616 released on /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517.lock
# 2021-11-26 21:14:22,111 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2021-11-26 21:14:22,111 - INFO - transformers.configuration_utils - Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# 2021-11-26 21:14:22,205 - INFO - filelock - Lock 140656740994256 acquired on /root/.cache/torch/transformers/f2ee78bdd635b758cc0a12352586868bef80e47401abe4c4fcc3832421e7338b.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157.lock
# 2021-11-26 21:14:22,205 - INFO - transformers.file_utils - https://cdn.huggingface.co/bert-base-uncased-pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmpwgnwk01l
# Downloading: 100% 440M/440M [00:11<00:00, 38.0MB/s]
# 2021-11-26 21:14:33,877 - INFO - transformers.file_utils - storing https://cdn.huggingface.co/bert-base-uncased-pytorch_model.bin in cache at /root/.cache/torch/transformers/f2ee78bdd635b758cc0a12352586868bef80e47401abe4c4fcc3832421e7338b.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2021-11-26 21:14:33,878 - INFO - transformers.file_utils - creating metadata file for /root/.cache/torch/transformers/f2ee78bdd635b758cc0a12352586868bef80e47401abe4c4fcc3832421e7338b.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2021-11-26 21:14:33,878 - INFO - filelock - Lock 140656740994256 released on /root/.cache/torch/transformers/f2ee78bdd635b758cc0a12352586868bef80e47401abe4c4fcc3832421e7338b.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157.lock
# 2021-11-26 21:14:33,878 - INFO - transformers.modeling_utils - loading weights file https://cdn.huggingface.co/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/f2ee78bdd635b758cc0a12352586868bef80e47401abe4c4fcc3832421e7338b.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2021-11-26 21:14:37,024 - INFO - allennlp.nn.initializers - Initializing parameters
# 2021-11-26 21:14:37,025 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.embeddings.LayerNorm.bias
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.embeddings.LayerNorm.weight
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.embeddings.position_embeddings.weight
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.embeddings.token_type_embeddings.weight
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.embeddings.word_embeddings.weight
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.output.LayerNorm.bias
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.output.LayerNorm.weight
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.output.dense.bias
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.output.dense.weight
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.key.bias
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.key.weight
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.query.bias
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.query.weight
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.value.bias
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.value.weight
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.intermediate.dense.bias
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.intermediate.dense.weight
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.output.LayerNorm.bias
# 2021-11-26 21:14:37,026 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.output.LayerNorm.weight
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.output.dense.bias
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.output.dense.weight
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.output.LayerNorm.bias
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.output.LayerNorm.weight
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.output.dense.bias
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.output.dense.weight
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.self.key.bias
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.self.key.weight
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.self.query.bias
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.self.query.weight
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.self.value.bias
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.self.value.weight
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.intermediate.dense.bias
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.intermediate.dense.weight
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.output.LayerNorm.bias
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.output.LayerNorm.weight
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.output.dense.bias
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.output.dense.weight
# 2021-11-26 21:14:37,027 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.output.LayerNorm.bias
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.output.LayerNorm.weight
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.output.dense.bias
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.output.dense.weight
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.self.key.bias
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.self.key.weight
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.self.query.bias
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.self.query.weight
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.self.value.bias
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.self.value.weight
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.intermediate.dense.bias
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.intermediate.dense.weight
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.output.LayerNorm.bias
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.output.LayerNorm.weight
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.output.dense.bias
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.output.dense.weight
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.output.LayerNorm.bias
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.output.LayerNorm.weight
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.output.dense.bias
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.output.dense.weight
# 2021-11-26 21:14:37,028 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.self.key.bias
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.self.key.weight
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.self.query.bias
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.self.query.weight
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.self.value.bias
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.self.value.weight
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.intermediate.dense.bias
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.intermediate.dense.weight
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.output.LayerNorm.bias
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.output.LayerNorm.weight
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.output.dense.bias
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.output.dense.weight
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.output.LayerNorm.bias
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.output.LayerNorm.weight
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.output.dense.bias
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.output.dense.weight
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.self.key.bias
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.self.key.weight
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.self.query.bias
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.self.query.weight
# 2021-11-26 21:14:37,029 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.self.value.bias
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.self.value.weight
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.intermediate.dense.bias
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.intermediate.dense.weight
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.output.LayerNorm.bias
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.output.LayerNorm.weight
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.output.dense.bias
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.output.dense.weight
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.output.LayerNorm.bias
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.output.LayerNorm.weight
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.output.dense.bias
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.output.dense.weight
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.self.key.bias
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.self.key.weight
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.self.query.bias
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.self.query.weight
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.self.value.bias
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.self.value.weight
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.intermediate.dense.bias
# 2021-11-26 21:14:37,030 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.intermediate.dense.weight
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.output.LayerNorm.bias
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.output.LayerNorm.weight
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.output.dense.bias
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.output.dense.weight
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.output.LayerNorm.bias
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.output.LayerNorm.weight
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.output.dense.bias
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.output.dense.weight
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.self.key.bias
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.self.key.weight
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.self.query.bias
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.self.query.weight
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.self.value.bias
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.self.value.weight
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.intermediate.dense.bias
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.intermediate.dense.weight
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.output.LayerNorm.bias
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.output.LayerNorm.weight
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.output.dense.bias
# 2021-11-26 21:14:37,031 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.output.dense.weight
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.output.LayerNorm.bias
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.output.LayerNorm.weight
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.output.dense.bias
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.output.dense.weight
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.self.key.bias
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.self.key.weight
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.self.query.bias
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.self.query.weight
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.self.value.bias
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.self.value.weight
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.intermediate.dense.bias
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.intermediate.dense.weight
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.output.LayerNorm.bias
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.output.LayerNorm.weight
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.output.dense.bias
# 2021-11-26 21:14:37,032 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.output.dense.weight
# 2021-11-26 21:14:37,033 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.output.LayerNorm.bias
# 2021-11-26 21:14:37,033 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.output.LayerNorm.weight
# 2021-11-26 21:14:37,033 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.output.dense.bias
# 2021-11-26 21:14:37,033 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.output.dense.weight
# 2021-11-26 21:14:37,033 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.self.key.bias
# 2021-11-26 21:14:37,033 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.self.key.weight
# 2021-11-26 21:14:37,033 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.self.query.bias
# 2021-11-26 21:14:37,033 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.self.query.weight
# 2021-11-26 21:14:37,033 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.self.value.bias
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.self.value.weight
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.intermediate.dense.bias
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.intermediate.dense.weight
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.output.LayerNorm.bias
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.output.LayerNorm.weight
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.output.dense.bias
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.output.dense.weight
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.output.LayerNorm.bias
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.output.LayerNorm.weight
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.output.dense.bias
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.output.dense.weight
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.self.key.bias
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.self.key.weight
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.self.query.bias
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.self.query.weight
# 2021-11-26 21:14:37,034 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.self.value.bias
# 2021-11-26 21:14:37,051 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.self.value.weight
# 2021-11-26 21:14:37,051 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.intermediate.dense.bias
# 2021-11-26 21:14:37,051 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.intermediate.dense.weight
# 2021-11-26 21:14:37,051 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.output.LayerNorm.bias
# 2021-11-26 21:14:37,052 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.output.LayerNorm.weight
# 2021-11-26 21:14:37,052 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.output.dense.bias
# 2021-11-26 21:14:37,052 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.output.dense.weight
# 2021-11-26 21:14:37,052 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.output.LayerNorm.bias
# 2021-11-26 21:14:37,052 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.output.LayerNorm.weight
# 2021-11-26 21:14:37,052 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.output.dense.bias
# 2021-11-26 21:14:37,052 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.output.dense.weight
# 2021-11-26 21:14:37,052 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.self.key.bias
# 2021-11-26 21:14:37,052 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.self.key.weight
# 2021-11-26 21:14:37,052 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.self.query.bias
# 2021-11-26 21:14:37,052 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.self.query.weight
# 2021-11-26 21:14:37,052 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.self.value.bias
# 2021-11-26 21:14:37,052 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.self.value.weight
# 2021-11-26 21:14:37,052 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.intermediate.dense.bias
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.intermediate.dense.weight
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.output.LayerNorm.bias
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.output.LayerNorm.weight
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.output.dense.bias
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.output.dense.weight
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.output.LayerNorm.bias
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.output.dense.bias
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.output.dense.weight
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.key.bias
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.key.weight
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.query.bias
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.query.weight
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.value.bias
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.value.weight
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.intermediate.dense.bias
# 2021-11-26 21:14:37,053 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.intermediate.dense.weight
# 2021-11-26 21:14:37,054 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.LayerNorm.bias
# 2021-11-26 21:14:37,054 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.LayerNorm.weight
# 2021-11-26 21:14:37,054 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.dense.bias
# 2021-11-26 21:14:37,054 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.dense.weight
# 2021-11-26 21:14:37,054 - INFO - allennlp.nn.initializers -    bert_model.pooler.dense.bias
# 2021-11-26 21:14:37,054 - INFO - allennlp.nn.initializers -    bert_model.pooler.dense.weight
# 2021-11-26 21:14:37,054 - INFO - allennlp.nn.initializers -    tag_projection_layer.bias
# 2021-11-26 21:14:37,054 - INFO - allennlp.nn.initializers -    tag_projection_layer.weight
# 2021-11-26 21:14:37,735 - INFO - allennlp.common.params - dataset_reader.type = srl
# 2021-11-26 21:14:37,735 - INFO - allennlp.common.params - dataset_reader.lazy = False
# 2021-11-26 21:14:37,735 - INFO - allennlp.common.params - dataset_reader.cache_directory = None
# 2021-11-26 21:14:37,735 - INFO - allennlp.common.params - dataset_reader.max_instances = None
# 2021-11-26 21:14:37,736 - INFO - allennlp.common.params - dataset_reader.manual_distributed_sharding = False
# 2021-11-26 21:14:37,736 - INFO - allennlp.common.params - dataset_reader.manual_multi_process_sharding = False
# 2021-11-26 21:14:37,736 - INFO - allennlp.common.params - dataset_reader.token_indexers = None
# 2021-11-26 21:14:37,736 - INFO - allennlp.common.params - dataset_reader.domain_identifier = None
# 2021-11-26 21:14:37,736 - INFO - allennlp.common.params - dataset_reader.bert_model_name = bert-base-uncased
# 2021-11-26 21:14:37,844 - INFO - filelock - Lock 140660661055248 acquired on /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084.lock
# 2021-11-26 21:14:37,844 - INFO - transformers.file_utils - https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmpht2f8tan
# Downloading: 100% 232k/232k [00:00<00:00, 3.44MB/s]
# 2021-11-26 21:14:38,006 - INFO - transformers.file_utils - storing https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt in cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2021-11-26 21:14:38,006 - INFO - transformers.file_utils - creating metadata file for /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2021-11-26 21:14:38,006 - INFO - filelock - Lock 140660661055248 released on /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084.lock
# 2021-11-26 21:14:38,006 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# input 0:  {"sentence": "I have heard gunshots all my life in my neighborhood, have lost many friends, and am afraid to go out at night."}
# prediction:  {"verbs": [{"verb": "heard", "description": "[ARG0: I] have [V: heard] [ARG1: gunshots all my life in my neighborhood] , have lost many friends , and am afraid to go out at night .", "tags": ["B-ARG0", "O", "B-V", "B-ARG1", "I-ARG1", "I-ARG1", "I-ARG1", "I-ARG1", "I-ARG1", "I-ARG1", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}, {"verb": "lost", "description": "I have heard gunshots all my life in my neighborhood , have [V: lost] [ARG1: many friends] , and am afraid to go out at night .", "tags": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-V", "B-ARG1", "I-ARG1", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}, {"verb": "go", "description": "I have heard gunshots all my life in my neighborhood , have lost many friends , and am afraid to [V: go] [ARGM-DIR: out] [ARGM-TMP: at night] .", "tags": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-V", "B-ARGM-DIR", "B-ARGM-TMP", "I-ARGM-TMP", "O"]}], "words": ["I", "have", "heard", "gunshots", "all", "my", "life", "in", "my", "neighborhood", ",", "have", "lost", "many", "friends", ",", "and", "am", "afraid", "to", "go", "out", "at", "night", "."]}
#
# 2021-11-26 21:14:39,727 - INFO - allennlp.models.archival - removing temporary unarchived model dir at /tmp/tmpvxt7vokn
