# %%
#@title Step 2: Cloning the OpenAI GPT-2 Repository
# !git clone https://github.com/openai/gpt-2.git
# Out:
# Cloning into 'gpt-2'...
# remote: Enumerating objects: 233, done.
# remote: Total 233 (delta 0), reused 0 (delta 0), pack-reused 233
# Receiving objects: 100% (233/233), 4.38 MiB | 14.60 MiB/s, done.
# Resolving deltas: 100% (124/124), done.

# %%
#@title Step 3: Installing the requirements
import os
os.chdir("/content/gpt-2")
# !pip3 install -r requirements.txt
# Out:
# Collecting fire>=0.1.3
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 3.7 MB/s
# Collecting regex==2017.4.5
#   Downloading regex-2017.04.05.tar.gz (601 kB)
#      |████████████████████████████████| 601 kB 37.1 MB/s
# Collecting requests==2.21.0
#   Downloading requests-2.21.0-py2.py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 5.4 MB/s
# Collecting tqdm==4.31.1
#   Downloading tqdm-4.31.1-py2.py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 4.5 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (2021.5.30)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (3.0.4)
# Collecting idna<2.9,>=2.5
#   Downloading idna-2.8-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.8 MB/s
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fire>=0.1.3->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire>=0.1.3->-r requirements.txt (line 1)) (1.1.0)
# Building wheels for collected packages: regex, fire
#   Building wheel for regex (setup.py) ... done
#   Created wheel for regex: filename=regex-2017.4.5-cp37-cp37m-linux_x86_64.whl size=534437 sha256=9a63eddce52634293dbb249c54a96628835de215247938a467ec7e785d032d28
#   Stored in directory: /root/.cache/pip/wheels/3d/e8/a5/d4894e7ef29935f75c6074409ce8ca80a0271f0ce2a30da5d3
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115943 sha256=f9bf1bf521e85ac7e402b519c61316f934559352388a3950170f41a6e24d0d2a
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built regex fire
# Installing collected packages: idna, tqdm, requests, regex, fire
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.3
#     Uninstalling tqdm-4.62.3:
#       Successfully uninstalled tqdm-4.62.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: regex
#     Found existing installation: regex 2019.12.20
#     Uninstalling regex-2019.12.20:
#       Successfully uninstalled regex-2019.12.20
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 2.2.4 requires tqdm<5.0.0,>=4.38.0, but you have tqdm 4.31.1 which is incompatible.
# panel 0.12.1 requires tqdm>=4.48.0, but you have tqdm 4.31.1 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.21.0 which is incompatible.
# fbprophet 0.7.1 requires tqdm>=4.36.1, but you have tqdm 4.31.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed fire-0.4.0 idna-2.8 regex-2017.4.5 requests-2.21.0 tqdm-4.31.1

# %%
# !pip install toposort
# Out:
# Collecting toposort
#   Downloading toposort-1.7-py2.py3-none-any.whl (9.0 kB)
# Installing collected packages: toposort
# Successfully installed toposort-1.7

# %%
#@title Step 4: Checking Tensorflow Version
# Colab has tf 1. X and tf 2.x installed
# Restart runtime using 'Runtime' -> 'Restart runtime....'
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
#@title Step 5: Downloading 117M parameter GPT-2 Model
# run code and send argument
import os # after runtime restarted
os.chdir("/content/gpt-2")
# !python3 download_model.py '117M' # creates model directory
# Out:
# Fetching checkpoint: 1.00kit [00:00, 822kit/s]
# Fetching encoder.json: 1.04Mit [00:00, 9.47Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 950kit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:12, 40.0Mit/s]
# Fetching model.ckpt.index: 6.00kit [00:00, 4.92Mit/s]
# Fetching model.ckpt.meta: 472kit [00:00, 4.16Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 4.39Mit/s]

# %%
#@title Step 6: Copying the Project Resources to scr
# !cp /content/mdset.txt /content/gpt-2/src/
# !cp -r /content/gpt-2/models/ /content/gpt-2/src/

# %%
#@title Step 7: Copying the N Shepperd Training Files
# Reference github repository:  https://github.com/nshepperd/gpt-2
import os # import after runtime is started
# !cp /content/train.py /content/gpt-2/src/
# !cp /content/load_dataset.py /content/gpt-2/src/
# !cp /content/encode.py /content/gpt-2/src/
# !cp /content/accumulate.py /content/gpt-2/src/
# !cp /content/memory_saving_gradients.py /content/gpt-2/src/

# %%
#@title Step 8: Encoding dataset
import os # import after a runtime is started
os.chdir("/content/gpt-2/src/")
model_name="117M"
# !python /content/gpt-2/src/encode.py mdset.txt out.npz
# Out:
# Reading files
# 100% 1/1 [00:00<00:00,  4.53it/s]
# Writing out.npz

# %%
#@title Step 9: Training the Model
#Model saved after 1000 steps
import os # import after runtime is restarted
os.chdir("/content/gpt-2/src/")
# !python train.py --dataset out.npz
# Out:
# Streaming output truncated to the last 5000 lines.
# d−1
#  Z
# R+
# γq(λ) dλ i
# ,
# θq
# := Z
# S
# d−1
#  Z
# R+
# γq(λ) dλ i
# ,
# θq
# := Z
# S
# d−1
#  Z
# R+
# γq(λ) dλ i
# ,
# θq
# := Z
# S
# d−1
#  Z
# R+
# γq(λ) dλ i
# ,
# θq
# := Z
# S
# d−1
#  Z
# R+
# γq(λ) dλ i
# ,
# θq
# := Z
# S
# d−1
#  Z
# R+
# γq(λ) dλ i
# ,
# θq
# := Z
# S
# d−1
#  Z
# R+
# γq(λ) dλ i
# ,
# θq
# :
#
# [2600 | 2934.98] loss=0.07 avg=0.04
# [2601 | 2935.91] loss=0.05 avg=0.04
# [2602 | 2936.84] loss=0.03 avg=0.04
# [2603 | 2937.77] loss=0.03 avg=0.04
# [2604 | 2938.71] loss=0.04 avg=0.04
# [2605 | 2939.63] loss=0.05 avg=0.04
# [2606 | 2940.57] loss=0.06 avg=0.04
# [2607 | 2941.50] loss=0.04 avg=0.04
# [2608 | 2942.44] loss=0.04 avg=0.04
# [2609 | 2943.37] loss=0.06 avg=0.04
# [2610 | 2944.30] loss=0.05 avg=0.04
# [2611 | 2945.24] loss=0.03 avg=0.04
# [2612 | 2946.17] loss=0.04 avg=0.04
# [2613 | 2947.10] loss=0.03 avg=0.04
# [2614 | 2948.04] loss=0.02 avg=0.04
# [2615 | 2948.98] loss=0.04 avg=0.04
# [2616 | 2949.91] loss=0.04 avg=0.04
# [2617 | 2950.85] loss=0.05 avg=0.04
# [2618 | 2951.78] loss=0.05 avg=0.04
# [2619 | 2952.71] loss=0.03 avg=0.04
# [2620 | 2953.64] loss=0.04 avg=0.04
# [2621 | 2954.57] loss=0.04 avg=0.04
# [2622 | 2955.50] loss=0.03 avg=0.04
# [2623 | 2956.43] loss=0.04 avg=0.04
# [2624 | 2957.37] loss=0.04 avg=0.04
# [2625 | 2958.30] loss=0.04 avg=0.04
# [2626 | 2959.24] loss=0.05 avg=0.04
# [2627 | 2960.17] loss=0.04 avg=0.04
# [2628 | 2961.11] loss=0.05 avg=0.04
# [2629 | 2962.04] loss=0.05 avg=0.04
# [2630 | 2962.97] loss=0.04 avg=0.04
# [2631 | 2963.91] loss=0.04 avg=0.04
# [2632 | 2964.84] loss=0.03 avg=0.04
# [2633 | 2965.77] loss=0.03 avg=0.04
# [2634 | 2966.70] loss=0.02 avg=0.04
# [2635 | 2967.64] loss=0.03 avg=0.04
# [2636 | 2968.58] loss=0.05 avg=0.04
# [2637 | 2969.51] loss=0.03 avg=0.04
# [2638 | 2970.44] loss=0.05 avg=0.04
# [2639 | 2971.37] loss=0.04 avg=0.04
# [2640 | 2972.30] loss=0.03 avg=0.04
# [2641 | 2973.24] loss=0.03 avg=0.04
# [2642 | 2974.16] loss=0.03 avg=0.04
# [2643 | 2975.09] loss=0.05 avg=0.04
# [2644 | 2976.02] loss=0.08 avg=0.04
# [2645 | 2976.97] loss=0.04 avg=0.04
# [2646 | 2977.90] loss=0.04 avg=0.04
# [2647 | 2978.83] loss=0.04 avg=0.04
# [2648 | 2979.77] loss=0.03 avg=0.04
# [2649 | 2980.70] loss=0.04 avg=0.04
# [2650 | 2981.63] loss=0.06 avg=0.04
# [2651 | 2982.55] loss=0.03 avg=0.04
# [2652 | 2983.48] loss=0.03 avg=0.04
# [2653 | 2984.42] loss=0.03 avg=0.04
# [2654 | 2985.35] loss=0.02 avg=0.04
# [2655 | 2986.29] loss=0.03 avg=0.04
# [2656 | 2987.22] loss=0.05 avg=0.04
# [2657 | 2988.15] loss=0.02 avg=0.04
# [2658 | 2989.08] loss=0.06 avg=0.04
# [2659 | 2990.01] loss=0.04 avg=0.04
# [2660 | 2990.95] loss=0.04 avg=0.04
# [2661 | 2991.88] loss=0.05 avg=0.04
# [2662 | 2992.81] loss=0.02 avg=0.04
# [2663 | 2993.75] loss=0.04 avg=0.04
# [2664 | 2994.68] loss=0.04 avg=0.04
# [2665 | 2995.62] loss=0.06 avg=0.04
# [2666 | 2996.56] loss=0.04 avg=0.04
# [2667 | 2997.48] loss=0.04 avg=0.04
# [2668 | 2998.41] loss=0.05 avg=0.04
# [2669 | 2999.35] loss=0.03 avg=0.04
# [2670 | 3000.29] loss=0.04 avg=0.04
# [2671 | 3001.22] loss=0.03 avg=0.04
# [2672 | 3002.15] loss=0.03 avg=0.04
# [2673 | 3003.09] loss=0.05 avg=0.04
# [2674 | 3004.02] loss=0.04 avg=0.04
# [2675 | 3004.95] loss=0.04 avg=0.04
# [2676 | 3005.88] loss=0.03 avg=0.04
# [2677 | 3006.81] loss=0.02 avg=0.04
# [2678 | 3007.75] loss=0.03 avg=0.04
# [2679 | 3008.68] loss=0.04 avg=0.04
# [2680 | 3009.62] loss=0.04 avg=0.04
# [2681 | 3010.55] loss=0.03 avg=0.04
# [2682 | 3011.48] loss=0.02 avg=0.04
# [2683 | 3012.41] loss=0.03 avg=0.04
# [2684 | 3013.35] loss=0.03 avg=0.04
# [2685 | 3014.28] loss=0.03 avg=0.04
# [2686 | 3015.21] loss=0.04 avg=0.04
# [2687 | 3016.15] loss=0.04 avg=0.04
# [2688 | 3017.09] loss=0.04 avg=0.04
# [2689 | 3018.03] loss=0.05 avg=0.04
# [2690 | 3018.96] loss=0.04 avg=0.04
# [2691 | 3019.89] loss=0.03 avg=0.04
# [2692 | 3020.82] loss=0.04 avg=0.04
# [2693 | 3021.77] loss=0.03 avg=0.04
# [2694 | 3022.69] loss=0.02 avg=0.04
# [2695 | 3023.63] loss=0.04 avg=0.04
# [2696 | 3024.56] loss=0.03 avg=0.04
# [2697 | 3025.50] loss=0.04 avg=0.04
# [2698 | 3026.43] loss=0.03 avg=0.04
# [2699 | 3027.36] loss=0.04 avg=0.04
# Generating samples...
# ======== SAMPLE 1 ========
# .
# (b) t=2.5 (c) t=5 (d) t=10
# (e) t=15 (f) t=20 (g) t=30 (h) t=60
# Figure 4: Test 3 Case i) with non-local q and S, independent and with sensing function γq =
# γS = H(R−λ). S is given in Fig. 3a, that corresponds to lS = 0.25, while mk = 10, so that lq ≈ 0.031. The
# sensing radius of the cells is R = 0.02.
# 4.4 Test 4: heterogeneous ECM environment
# As previously stated, we are going to consider a domain Ω divided in several regions, each of them characterized by a different
# average direction of the fibers. In particular, we shall do this in the case of independent sensing
# model with γq = γS = H(R−λ), as for Test 3; the independence of the two sensings, in fact, allows
# to visualize more efficiently the two distinct directional effects. As first scenario, we shall consider
# the domain schematized in Fig. 9a; in each subdomain we have k(x, y) = 50, that corresponds
# to Dq = 0.005. The initial condition of the cells is represented in Fig. 9c, with initial density
# r0 = 0.1, while the chemoattractant has a gaussian profile (70) centered in (xS , yS ) = (4, 4), with
# mS = 10 and σ
# 2
# S = 0.5, as shown in Fig. 9b. We observe that cells do not migrate collectively
# towards the chemoattractant, but they divide into two main separated clusters (see Figs. 9f -
# 9h): in fact, although the sensing radius R = 0.8 is quite large, the cells that are closer to the
# left boundary remain trapped in the first subdomain, showing a loss of adhesion with the rest of
# the cell population. As shown in Fig. 9i, even though the cells that are in the left subdomain
# horizontally align to the chemoattractant, the high degree of alignment of the fiber does not allow
# them to escape this region, even for large times.
# As second scenario, we shall consider the domain represented in Fig. 10a; in each subdomain,
# the parameter k(x, y) = 50. The initial condition of the cell population is (71) with (x0, y0) =
# (4, 0.5) and r0 = 0.1, while the chemoattractant has a gaussian profile (70) centered in (xS , yS ) =
# (2, 4.5) with mS = 10 and σ
# 2
# S = 0.05, as shown in Fig. 10c and 10b, respectively. We observe that
# cells do not migrate directly towards the chemoattractant, as they sense the heterogeneous fibrous
# environment and, consequently, adapt their migration to it. In particular, cells that are able to
# reach and sense the isotropic subdomain where the fibers are uniformly distributed (defined by
# 1 ≤ x ≤ 3 and 0 ≤ y ≤ 3), go in this direction imposed by the gradient of the chemoattractant.
# On the other hand, in the subdomain 3 ≤ x ≤ 5 and 1 ≤ y ≤ 2, they follow the direction of
# fiber alignment, that is π/4, perpendicular to the favorable direction imposed by S. However,
# the sensing radius R = 0.7 allows the cells that are closer to the right boundary to escape quite
# fast the disadvantageous (in terms of preferential direction) subdomains and, following firstly the
# direction π/2 in 2 ≤ y ≤ 3 and, then, 3π/4 in 3 ≤ y ≤ 4, to reach the chemoattractant.
# 26
# (a) Fibers distribution. (b) Chemoattractant S. (c) Initial condition for the cell.
# (d) t=0.04 (e) t=1.6 (f) t=2.904
# (g) t=18.4 (h) t=44 (i) t=67.2
# Figure 4: Test 4 Migration of cells in an heterogenous domain as illustrated in (a). The sensing
# radius of the cells is R = 0.8. The chemoattractant (b) is (70) with mS = 10 and σ
# 2
# S = 0.5. The
# initial cell profile (c) evolves in time as illustrated in (d)-(i).
# 5
#
# [2700 | 3048.05] loss=0.03 avg=0.04
# [2701 | 3048.99] loss=0.05 avg=0.04
# [2702 | 3049.92] loss=0.04 avg=0.04
# [2703 | 3050.85] loss=0.05 avg=0.04
# [2704 | 3051.78] loss=0.04 avg=0.04
# [2705 | 3052.71] loss=0.04 avg=0.04
# [2706 | 3053.65] loss=0.03 avg=0.04
# [2707 | 3054.59] loss=0.04 avg=0.04
# [2708 | 3055.52] loss=0.05 avg=0.04
# [2709 | 3056.45] loss=0.02 avg=0.04
# [2710 | 3057.39] loss=0.04 avg=0.04
# [2711 | 3058.32] loss=0.03 avg=0.04
# [2712 | 3059.25] loss=0.03 avg=0.04
# [2713 | 3060.19] loss=0.03 avg=0.04
# [2714 | 3061.13] loss=0.03 avg=0.04
# [2715 | 3062.06] loss=0.05 avg=0.04
# [2716 | 3062.99] loss=0.06 avg=0.04
# [2717 | 3063.93] loss=0.04 avg=0.04
# [2718 | 3064.86] loss=0.04 avg=0.04
# [2719 | 3065.79] loss=0.04 avg=0.04
# [2720 | 3066.73] loss=0.09 avg=0.04
# [2721 | 3067.67] loss=0.03 avg=0.04
# [2722 | 3068.60] loss=0.04 avg=0.04
# [2723 | 3069.53] loss=0.05 avg=0.04
# [2724 | 3070.46] loss=0.03 avg=0.04
# [2725 | 3071.40] loss=0.03 avg=0.04
# [2726 | 3072.33] loss=0.04 avg=0.04
# [2727 | 3073.26] loss=0.04 avg=0.04
# [2728 | 3074.19] loss=0.04 avg=0.04
# [2729 | 3075.12] loss=0.04 avg=0.04
# [2730 | 3076.05] loss=0.03 avg=0.04
# [2731 | 3076.99] loss=0.03 avg=0.04
# [2732 | 3077.92] loss=0.09 avg=0.04
# [2733 | 3078.85] loss=0.02 avg=0.04
# [2734 | 3079.78] loss=0.03 avg=0.04
# [2735 | 3080.72] loss=0.05 avg=0.04
# [2736 | 3081.66] loss=0.05 avg=0.04
# [2737 | 3082.59] loss=0.07 avg=0.04
# [2738 | 3083.53] loss=0.04 avg=0.04
# [2739 | 3084.46] loss=0.03 avg=0.04
# [2740 | 3085.40] loss=0.03 avg=0.04
# [2741 | 3086.33] loss=0.04 avg=0.04
# [2742 | 3087.26] loss=0.07 avg=0.04
# [2743 | 3088.20] loss=0.07 avg=0.04
# [2744 | 3089.15] loss=0.03 avg=0.04
# [2745 | 3090.09] loss=0.06 avg=0.04
# [2746 | 3091.02] loss=0.04 avg=0.04
# [2747 | 3091.95] loss=0.05 avg=0.04
# [2748 | 3092.88] loss=0.03 avg=0.04
# [2749 | 3093.81] loss=0.03 avg=0.04
# [2750 | 3094.74] loss=0.04 avg=0.04
# [2751 | 3095.67] loss=0.03 avg=0.04
# [2752 | 3096.60] loss=0.05 avg=0.04
# [2753 | 3097.54] loss=0.04 avg=0.04
# [2754 | 3098.48] loss=0.05 avg=0.04
# [2755 | 3099.41] loss=0.03 avg=0.04
# [2756 | 3100.35] loss=0.04 avg=0.04
# [2757 | 3101.28] loss=0.04 avg=0.04
# [2758 | 3102.21] loss=0.05 avg=0.04
# [2759 | 3103.15] loss=0.05 avg=0.04
# [2760 | 3104.08] loss=0.05 avg=0.04
# [2761 | 3105.00] loss=0.02 avg=0.04
# [2762 | 3105.94] loss=0.03 avg=0.04
# [2763 | 3106.88] loss=0.07 avg=0.04
# [2764 | 3107.81] loss=0.05 avg=0.04
# [2765 | 3108.74] loss=0.04 avg=0.04
# [2766 | 3109.68] loss=0.02 avg=0.04
# [2767 | 3110.62] loss=0.05 avg=0.04
# [2768 | 3111.56] loss=0.05 avg=0.04
# [2769 | 3112.49] loss=0.05 avg=0.04
# [2770 | 3113.42] loss=0.05 avg=0.04
# [2771 | 3114.35] loss=0.03 avg=0.04
# [2772 | 3115.29] loss=0.04 avg=0.04
# [2773 | 3116.22] loss=0.04 avg=0.04
# [2774 | 3117.16] loss=0.06 avg=0.04
# [2775 | 3118.09] loss=0.05 avg=0.04
# [2776 | 3119.02] loss=0.03 avg=0.04
# [2777 | 3119.95] loss=0.03 avg=0.04
# [2778 | 3120.89] loss=0.02 avg=0.04
# [2779 | 3121.81] loss=0.03 avg=0.04
# [2780 | 3122.74] loss=0.04 avg=0.04
# [2781 | 3123.68] loss=0.05 avg=0.04
# [2782 | 3124.62] loss=0.02 avg=0.04
# [2783 | 3125.55] loss=0.08 avg=0.04
# [2784 | 3126.48] loss=0.04 avg=0.04
# [2785 | 3127.41] loss=0.05 avg=0.04
# [2786 | 3128.34] loss=0.04 avg=0.04
# [2787 | 3129.28] loss=0.07 avg=0.04
# [2788 | 3130.21] loss=0.03 avg=0.04
# [2789 | 3131.14] loss=0.02 avg=0.04
# [2790 | 3132.08] loss=0.04 avg=0.04
# [2791 | 3133.01] loss=0.05 avg=0.04
# [2792 | 3133.95] loss=0.03 avg=0.04
# [2793 | 3134.88] loss=0.05 avg=0.04
# [2794 | 3135.81] loss=0.04 avg=0.04
# [2795 | 3136.75] loss=0.09 avg=0.04
# [2796 | 3137.68] loss=0.03 avg=0.04
# [2797 | 3138.61] loss=0.04 avg=0.04
# [2798 | 3139.55] loss=0.04 avg=0.04
# [2799 | 3140.48] loss=0.03 avg=0.04
# Generating samples...
# ======== SAMPLE 1 ========
#  Test
# 0
# q(x, vˆ) dλ ψ(v).
# Equation (50) indicates that the equilibrium distribution is a non-local average of the fibers distribution according to the sensing kernel γq and normalized by the measure of the sensed linear
# tract Γq
# 0
# over the direction vˆ. Its average is
# U0
# T
# (ξ) = U¯
# Γ
# q
# 0
# Z
# R+
# γ(λ)Eq(ξ + λvˆ) dλ
#
# that vanishes as ξ + λvˆ ∈ Ω and (27) holds true. Therefore, we perform the diffusive limit that
# leads to (22) with
# D
# 0
# T
# (ξ) = D
# Z
# S
# d−1
# 1
# Γ
# q
# 0
# Z
# R+
# γ(λ) q(ξ + λvˆ, vˆ) dλ vˆ ⊗ vˆ dvˆ .
# Let us now define
# D
# λ
# q
# (ξ) = Z
# S
# d−1
# q(ξ + λvˆ, vˆ) vˆ ⊗ vˆ dvˆ , (51)
# that, for each point ξ, is the diffusion tensor of the fibers on a circle of radius λ, and
# D¯ 0
# q =
# 1
# Γ
# q
# 0
# Z
# R+
# γ(λ)D
# λ
# q dλ , (52)
# that is a weighted diffusion tensor of the fibers in the whole neighborhood sensed by the cells, so
# that
# D
# 0
# T
# (ξ) = DD¯ 0
# q
# (ξ) (53)
# and
# U1
# T
# (ξ) = U c ¯ (ξ)
# Z
# S
# d−1
#
# Γ
# S
# 1
# (∇S · vˆ)
# Z
# R+
# γ(λ)S(ξ + λvˆ) dλ Z
# S
# d−1
# vˆ ⊗ vˆ dvˆ .
# Let us now define
# D¯ 0
# q
# (ξ) = 1
# Γ
# S
# 1
# (∇S · vˆ)
# Z
# R+
# γ(λ)S(ξ + λvˆ) dλ Z
# S
# d−1
# vˆ ⊗ vˆ dvˆ .
# 1.1 Finished product of Partitioning two different ways of describing the
# transition probability: aadition probability and non-constant probability.
# 23
# (a) t=time
# (b) t0=Γ
# S
# 1
# (c) t1=Γ
# q
# 0
# Z
# R+
# γ(λ)S(ξ + λvˆ) dλ Z
# S
# d−1
# vˆ ⊗ vˆ dvˆ (dvˆ − 1)
# and
# c0(x, vˆ)
# ∇S
# S(x)
# = cΓ
# S
# 1
# (d) vˆ + dvˆ
# 1
# (e) t=t0
# (f) t1=t1
# f0(x, vˆ)
# ∇S
# S
# .
# 4.2 Test 2: non-constant non-constant non-constant
# We now present a second test in terms of both the non-constant and the non-constant non-momentum non-constantials (5)-(9) with
# Γ = Γ0 = 0. In the first test, we shall assume a non-local sensing of the cell
# environment and, then, we multiply the distribution of fibers with a symmetric bitwise comparison
# 0
# Γ0
#  by γq
# 0
# , and, again, we obtain a symmetric distribution of fibers. Due to
# the fact that γq
# 0
# is the identity tensor of the fibers, we have that all the fibers are in the same
# order. Therefore, the sensing radius R = 0.02 is large enough for performing a
# non-local microscopic velocity-vibrato test. Results from the gaussian
# distribution of the fibers in the space of fibers is known as the non-local kernel distribution.
# In the present work, we shall consider a non-local sensing of the cell environment in time.
# During the calculation of the cell sensing radius R, we shall
#
# [2800 | 3161.26] loss=0.03 avg=0.04
# [2801 | 3162.18] loss=0.02 avg=0.04
# [2802 | 3163.11] loss=0.03 avg=0.04
# [2803 | 3164.04] loss=0.06 avg=0.04
# [2804 | 3164.97] loss=0.03 avg=0.04
# [2805 | 3165.90] loss=0.03 avg=0.04
# [2806 | 3166.84] loss=0.07 avg=0.04
# [2807 | 3167.78] loss=0.03 avg=0.04
# [2808 | 3168.71] loss=0.02 avg=0.04
# [2809 | 3169.64] loss=0.04 avg=0.04
# [2810 | 3170.57] loss=0.05 avg=0.04
# [2811 | 3171.51] loss=0.04 avg=0.04
# [2812 | 3172.44] loss=0.05 avg=0.04
# [2813 | 3173.36] loss=0.04 avg=0.04
# [2814 | 3174.29] loss=0.03 avg=0.04
# [2815 | 3175.22] loss=0.05 avg=0.04
# [2816 | 3176.14] loss=0.03 avg=0.04
# [2817 | 3177.07] loss=0.04 avg=0.04
# [2818 | 3178.01] loss=0.04 avg=0.04
# [2819 | 3178.94] loss=0.03 avg=0.04
# [2820 | 3179.87] loss=0.02 avg=0.04
# [2821 | 3180.80] loss=0.03 avg=0.04
# [2822 | 3181.73] loss=0.03 avg=0.04
# [2823 | 3182.65] loss=0.08 avg=0.04
# [2824 | 3183.58] loss=0.02 avg=0.04
# [2825 | 3184.51] loss=0.03 avg=0.04
# [2826 | 3185.45] loss=0.06 avg=0.04
# [2827 | 3186.38] loss=0.03 avg=0.04
# [2828 | 3187.31] loss=0.03 avg=0.04
# [2829 | 3188.24] loss=0.03 avg=0.04
# [2830 | 3189.17] loss=0.04 avg=0.04
# [2831 | 3190.10] loss=0.08 avg=0.04
# [2832 | 3191.02] loss=0.04 avg=0.04
# [2833 | 3191.95] loss=0.03 avg=0.04
# [2834 | 3192.88] loss=0.03 avg=0.04
# [2835 | 3193.81] loss=0.05 avg=0.04
# [2836 | 3194.74] loss=0.07 avg=0.04
# [2837 | 3195.66] loss=0.04 avg=0.04
# [2838 | 3196.59] loss=0.04 avg=0.04
# [2839 | 3197.52] loss=0.05 avg=0.04
# [2840 | 3198.45] loss=0.03 avg=0.04
# [2841 | 3199.38] loss=0.04 avg=0.04
# [2842 | 3200.31] loss=0.03 avg=0.04
# [2843 | 3201.24] loss=0.04 avg=0.04
# [2844 | 3202.17] loss=0.05 avg=0.04
# [2845 | 3203.10] loss=0.03 avg=0.04
# [2846 | 3204.03] loss=0.03 avg=0.04
# [2847 | 3204.95] loss=0.02 avg=0.04
# [2848 | 3205.88] loss=0.03 avg=0.04
# [2849 | 3206.81] loss=0.05 avg=0.04
# [2850 | 3207.74] loss=0.03 avg=0.04
# [2851 | 3208.67] loss=0.03 avg=0.04
# [2852 | 3209.59] loss=0.05 avg=0.04
# [2853 | 3210.51] loss=0.03 avg=0.04
# [2854 | 3211.43] loss=0.04 avg=0.04
# [2855 | 3212.36] loss=0.02 avg=0.04
# [2856 | 3213.29] loss=0.03 avg=0.04
# [2857 | 3214.21] loss=0.04 avg=0.04
# [2858 | 3215.14] loss=0.03 avg=0.04
# [2859 | 3216.07] loss=0.03 avg=0.04
# [2860 | 3217.01] loss=0.03 avg=0.04
# [2861 | 3217.94] loss=0.05 avg=0.04
# [2862 | 3218.87] loss=0.04 avg=0.04
# [2863 | 3219.81] loss=0.05 avg=0.04
# [2864 | 3220.73] loss=0.02 avg=0.04
# [2865 | 3221.66] loss=0.04 avg=0.04
# [2866 | 3222.59] loss=0.04 avg=0.04
# [2867 | 3223.52] loss=0.04 avg=0.04
# [2868 | 3224.44] loss=0.03 avg=0.04
# [2869 | 3225.38] loss=0.03 avg=0.04
# [2870 | 3226.31] loss=0.04 avg=0.04
# [2871 | 3227.23] loss=0.04 avg=0.04
# [2872 | 3228.16] loss=0.03 avg=0.04
# [2873 | 3229.09] loss=0.04 avg=0.04
# [2874 | 3230.01] loss=0.04 avg=0.04
# [2875 | 3230.94] loss=0.04 avg=0.04
# [2876 | 3231.88] loss=0.03 avg=0.04
# [2877 | 3232.80] loss=0.04 avg=0.04
# [2878 | 3233.73] loss=0.04 avg=0.04
# [2879 | 3234.66] loss=0.02 avg=0.04
# [2880 | 3235.59] loss=0.02 avg=0.04
# [2881 | 3236.51] loss=0.02 avg=0.04
# [2882 | 3237.44] loss=0.05 avg=0.04
# [2883 | 3238.37] loss=0.03 avg=0.04
# [2884 | 3239.30] loss=0.05 avg=0.04
# [2885 | 3240.23] loss=0.02 avg=0.04
# [2886 | 3241.16] loss=0.05 avg=0.04
# [2887 | 3242.09] loss=0.04 avg=0.04
# [2888 | 3243.02] loss=0.07 avg=0.04
# [2889 | 3243.94] loss=0.05 avg=0.04
# [2890 | 3244.86] loss=0.03 avg=0.04
# [2891 | 3245.79] loss=0.05 avg=0.04
# [2892 | 3246.72] loss=0.03 avg=0.04
# [2893 | 3247.65] loss=0.03 avg=0.04
# [2894 | 3248.58] loss=0.02 avg=0.04
# [2895 | 3249.50] loss=0.01 avg=0.04
# [2896 | 3250.43] loss=0.05 avg=0.04
# [2897 | 3251.36] loss=0.05 avg=0.04
# [2898 | 3252.29] loss=0.03 avg=0.04
# [2899 | 3253.22] loss=0.03 avg=0.04
# Generating samples...
# ======== SAMPLE 1 ========
#  the
# sensing of the cells, and the sensing of the fibers is done in the same
# direction as the cells are located in the region.
# In the present work, we shall consider η > 1, as η =
# ηq
# η
# Z
# R+
# γS (λ)S(x + λvˆ) dλ
# = 1
# Γ0
# Z
# R+
# γS (λ)S(x + λvˆ) dλ
# = 2
# Γ0
# Z
# R+
# γS (λ)S(x + λvˆ) dλ
# = 3
# Γ0
# Z
# R+
# γS (λ)S(x + λvˆ) dλ
# where Γ0
# := Z
# S
# d−1
# Z
# R+
# γS (λ)S(x + λvˆ) dλ dvˆ , Γ1
# := Z
# S
# d−1
# Z
# R+
# γS (λ)S(x + λvˆ) dλ dvˆ , and Γ < Γ1 ?
# Z
# S
# d−1
# Z
# R+
# γS (λ)S(x + λvˆ) dλ dvˆ .
# In this case, if Γ0 is not T,
# and only one of Γ0's two values,
# the other is. The last condition means that there is no guarantee that
# the other is true, since the first condition means that there is no such thing as an independent
# one, while the second means that there is a linear combination of the two.
# In this case, if there is a non-local independent sensing with a first order
# latter, but there are natural limits to them, they may be proved to be
# aligned requirements, that is, are the weights of the two cues, and they may be proved to be
# values of the alignment, obtained by evaluating the difference == operator. In the
# end, we have the same result for all the cues, but we have chosen a different setting
# for the differences == operators.
# In particular, we shall do this in order to obtain a non-local average of the
# cues, i.e., (36) with
# T[q, S](x, v, vˆ) = c(x)
# Z
# R+
# γ(λ)S(x + λvˆ) q(x + λvˆ, vˆ)dλ ψ(v),
# with
# c(x) := Z
# S
# d−1
# Z
# R+
# γ(λ)S(x + λvˆ) q(x + λvˆ, vˆ)dλ .
# The mean velocity of the cells was
# UT (x) = c(x)U¯
# Z
# S
# d−1
# vˆ
# Z
# R+
# γ(λ)S(x + λvˆ) q(x + λvˆ, vˆ)dλ dvˆ ,
# with
# c(x) = Z
# S
# d−1
# Z
# R+
# γ(λ)S(x + λvˆ) q(x + λvˆ, vˆ)dλ dvˆ .
# The mean direction of the cells was
# UT (x) = c(x)
# U¯
# Z
# S
# d−1
# Z
# R+
# γ(λ)S(x + λvˆ) q(x + λvˆ, vˆ) dλ dvˆ ,
# with
# c(x) = Z
# S
# d−1
# Z
# R+
# γ(λ)S(x + λvˆ) q(x + λvˆ, vˆ) dλ dvˆ .
# The average of the two cues was
# UT (x) = c(x)
# Z
# S
# d−1
# Z
# R+
# γ(λ)S(x + λvˆ) q(x + λvˆ, vˆ) dλ dvˆ ,
# with
# c(x) = Z
# S
# d−1
# Z
# R+
# γ(λ)S(x + λvˆ) q(x + λvˆ, vˆ) dλ dvˆ .
# The mean velocity of the cells was
# UT (x) = c(x)
# Z
# S
# d−1
#
# [2900 | 3273.80] loss=0.04 avg=0.04
# [2901 | 3274.72] loss=0.02 avg=0.04
# [2902 | 3275.65] loss=0.02 avg=0.04
# [2903 | 3276.58] loss=0.02 avg=0.04
# [2904 | 3277.50] loss=0.09 avg=0.04
# [2905 | 3278.43] loss=0.05 avg=0.04
# [2906 | 3279.36] loss=0.08 avg=0.04
# [2907 | 3280.28] loss=0.03 avg=0.04
# [2908 | 3281.21] loss=0.03 avg=0.04
# [2909 | 3282.14] loss=0.05 avg=0.04
# [2910 | 3283.06] loss=0.04 avg=0.04
# [2911 | 3283.99] loss=0.05 avg=0.04
# [2912 | 3284.92] loss=0.03 avg=0.04
# [2913 | 3285.85] loss=0.04 avg=0.04
# [2914 | 3286.78] loss=0.05 avg=0.04
# [2915 | 3287.71] loss=0.02 avg=0.04
# [2916 | 3288.64] loss=0.03 avg=0.04
# [2917 | 3289.57] loss=0.05 avg=0.04
# [2918 | 3290.50] loss=0.05 avg=0.04
# [2919 | 3291.43] loss=0.02 avg=0.04
# [2920 | 3292.36] loss=0.05 avg=0.04
# [2921 | 3293.29] loss=0.05 avg=0.04
# [2922 | 3294.21] loss=0.02 avg=0.04
# [2923 | 3295.14] loss=0.03 avg=0.04
# [2924 | 3296.08] loss=0.03 avg=0.04
# [2925 | 3297.01] loss=0.03 avg=0.04
# [2926 | 3297.94] loss=0.03 avg=0.04
# [2927 | 3298.86] loss=0.04 avg=0.04
# [2928 | 3299.79] loss=0.02 avg=0.04
# [2929 | 3300.73] loss=0.03 avg=0.04
# [2930 | 3301.65] loss=0.04 avg=0.04
# [2931 | 3302.58] loss=0.03 avg=0.04
# [2932 | 3303.51] loss=0.02 avg=0.04
# [2933 | 3304.44] loss=0.05 avg=0.04
# [2934 | 3305.37] loss=0.03 avg=0.04
# [2935 | 3306.30] loss=0.04 avg=0.04
# [2936 | 3307.22] loss=0.04 avg=0.04
# [2937 | 3308.15] loss=0.04 avg=0.04
# [2938 | 3309.08] loss=0.03 avg=0.04
# [2939 | 3310.00] loss=0.03 avg=0.04
# [2940 | 3310.93] loss=0.04 avg=0.04
# [2941 | 3311.86] loss=0.04 avg=0.04
# [2942 | 3312.79] loss=0.04 avg=0.04
# [2943 | 3313.72] loss=0.05 avg=0.04
# [2944 | 3314.64] loss=0.04 avg=0.04
# [2945 | 3315.57] loss=0.03 avg=0.04
# [2946 | 3316.50] loss=0.03 avg=0.04
# [2947 | 3317.42] loss=0.04 avg=0.04
# [2948 | 3318.35] loss=0.04 avg=0.04
# [2949 | 3319.28] loss=0.05 avg=0.04
# [2950 | 3320.21] loss=0.02 avg=0.04
# [2951 | 3321.14] loss=0.04 avg=0.04
# [2952 | 3322.06] loss=0.03 avg=0.04
# [2953 | 3322.99] loss=0.05 avg=0.04
# [2954 | 3323.92] loss=0.03 avg=0.04
# [2955 | 3324.85] loss=0.03 avg=0.04
# [2956 | 3325.78] loss=0.04 avg=0.04
# [2957 | 3326.71] loss=0.04 avg=0.04
# [2958 | 3327.63] loss=0.04 avg=0.04
# [2959 | 3328.57] loss=0.03 avg=0.04
# [2960 | 3329.49] loss=0.05 avg=0.04
# [2961 | 3330.42] loss=0.04 avg=0.04
# [2962 | 3331.35] loss=0.03 avg=0.04
# [2963 | 3332.29] loss=0.03 avg=0.04
# [2964 | 3333.21] loss=0.03 avg=0.04
# [2965 | 3334.14] loss=0.02 avg=0.04
# [2966 | 3335.07] loss=0.06 avg=0.04
# [2967 | 3335.99] loss=0.04 avg=0.04
# [2968 | 3336.92] loss=0.03 avg=0.04
# [2969 | 3337.84] loss=0.03 avg=0.04
# [2970 | 3338.77] loss=0.05 avg=0.04
# [2971 | 3339.70] loss=0.03 avg=0.04
# [2972 | 3340.63] loss=0.04 avg=0.04
# [2973 | 3341.56] loss=0.02 avg=0.04
# [2974 | 3342.48] loss=0.04 avg=0.04
# [2975 | 3343.40] loss=0.04 avg=0.04
# [2976 | 3344.34] loss=0.03 avg=0.04
# [2977 | 3345.27] loss=0.04 avg=0.04
# [2978 | 3346.20] loss=0.04 avg=0.04
# [2979 | 3347.12] loss=0.05 avg=0.04
# [2980 | 3348.05] loss=0.04 avg=0.04
# [2981 | 3348.98] loss=0.05 avg=0.04
# [2982 | 3349.91] loss=0.03 avg=0.04
# [2983 | 3350.83] loss=0.03 avg=0.04
# [2984 | 3351.76] loss=0.08 avg=0.04
# [2985 | 3352.69] loss=0.06 avg=0.04
# [2986 | 3353.62] loss=0.02 avg=0.04
# [2987 | 3354.54] loss=0.06 avg=0.04
# [2988 | 3355.46] loss=0.03 avg=0.04
# [2989 | 3356.40] loss=0.04 avg=0.04
# [2990 | 3357.32] loss=0.03 avg=0.04
# [2991 | 3358.25] loss=0.05 avg=0.04
# [2992 | 3359.17] loss=0.03 avg=0.04
# [2993 | 3360.10] loss=0.08 avg=0.04
# [2994 | 3361.02] loss=0.06 avg=0.04
# [2995 | 3361.95] loss=0.02 avg=0.04
# [2996 | 3362.88] loss=0.04 avg=0.04
# [2997 | 3363.81] loss=0.02 avg=0.04
# [2998 | 3364.74] loss=0.02 avg=0.04
# [2999 | 3365.66] loss=0.04 avg=0.04
# Saving checkpoint/run1/model-3000
# Generating samples...
# ======== SAMPLE 1 ========
#  a non-local sensing of the fibers. In the present model, there are two guidance cues
# affecting the polarization, and, therefore, the direction of motion of the cells: contact guidance,
# that is a bi-directional cue, and a chemical gradient, that is a mono-directional cue. We remark
# that for the first time in this work a non-local sensing in the physical space of the mesoscopic
# distribution of fibers is considered. In particular, we introduced two classes of models: in the first
# one, the cells perform an independent sensing of the fibers and of the chemical in its neighborhood,
# while in the second class of models the cells average the chemical and the fibers with the same
# sensing kernel.
# In the two cases, a particular attention was devoted to the identification of the proper macroscopic limit according to the properties of the turning operator. We detected two parameters, ηq
# and ηS , that measure the relation between the cell sensing radius and the characteristic lengths
# of variation − lS and lq − of the two cues, and discriminate between a diffusion-driven regime
# with an advective correction and a drift-driven regime. In particular, when the sensing radius
# does not exceed the characteristic length of the chemoattractant, the bi-directional nature of the
# 27
# (a) Fibers distribution. (b) Chemoattractant S. (c) Cells initial condition.
# (d) t=0.5 (e) t=1 (f) t=1.5
# (g) t=2.5 (h) t=3.5 (i) t=4.5
# Figure 10: Test 4 Migration of cell in an heterogenous domain as illustrated in (a). The sensing
# radius of the cells is R = 0.7. The chemoattractant (b) is (70) with mS = 10 and σ
# 2
# S = 0.05. The
# initial cell profile (c) evolves in time as illustrated in (d)-(i).
# fibers allows for a diffusive regime; otherwise the hyperbolic scaling leads to macroscopic drift.
# A common feature in the different cases is the dependency of the macroscopic velocity on both
# the fibers network and the chemoattractant. This aspect enhances the non-trivial influence of
# contact guidance on the cell drift, although we considered a non polarized fibers network. This
# interdependence is in accordance with the model proposed in [58]. Moreover, in absence of a
# chemoattractant, this impact on the drift term could persist for spatial heterogenous fiber distributions. This is in accordance to what is observed in [24] and it represents a step forward with
# respect to [58], in which the drift is a function of contact guidance only through to the presence
# of a chemical gradient, i.e., without chemoattractant there will be no drift.
# The numerical simulations of the transport model pointed out the main features characterizing
# the two classes of models and the possible scenarios that they are able to capture. We observed
# that the presence of two cues influencing cell polarization, even when the fibers are sensed locally,
# ensures a preferential sense of motion for cells laying on regions of highly aligned non-oriented
# fibers. Test 3 allowed to show the importance of deriving the macroscopic equations from an underlying microscopic dynamics and in the appropriate regime: a directly postulated drift-diffusion
# equation would not capture the exact dynamics in all the possible regimes. The competitive or
# collaborative effects of the cues depend, in a first instance, on the angle between their relative
# orientations, i.e., the direction of fiber alignment θq and the gradient of the chemoattractant.
# 28
# Moreover, especially for the cases of competitive cues, determining which one is the dominant
# cue depends on their relative strengths, in terms of both concentration and intensity (degree of
# alignment of the fiber k(x) or steepness of the chemoattractive gradient). We introduced the
# parameter η = lS /lq that, independently on the cell size or its sensing capability, quantifies the
# relative contribution of guidance to chemotaxis and provide a first separation between the cases
# of fiber-dominating and chemotaxis-dominating dynamics (η  1 or η  1, respectively). The
# presented framework also allows for the direct calculation of parameters that can be used to quantify directed cell migration and to set its efficiency, like, for instance, mean square displacement,
# persistence time, directional persistence and mean speed [42].
# Additionally, the non locality brings an further level of detail to the model, allowing to obtain
# different macroscopic behaviour depending on the characteristics of the two sensing. In fact, we
#
# [3000 | 3388.75] loss=0.03 avg=0.04
# [3001 | 3389.68] loss=0.07 avg=0.04
# [3002 | 3390.61] loss=0.02 avg=0.04
# [3003 | 3391.54] loss=0.04 avg=0.04
# [3004 | 3392.46] loss=0.03 avg=0.04
# [3005 | 3393.39] loss=0.02 avg=0.04
# [3006 | 3394.32] loss=0.02 avg=0.04
# [3007 | 3395.25] loss=0.03 avg=0.04
# [3008 | 3396.18] loss=0.04 avg=0.04
# [3009 | 3397.11] loss=0.04 avg=0.04
# [3010 | 3398.03] loss=0.03 avg=0.04
# [3011 | 3398.97] loss=0.06 avg=0.04
# [3012 | 3399.90] loss=0.04 avg=0.04
# [3013 | 3400.82] loss=0.03 avg=0.04
# [3014 | 3401.75] loss=0.04 avg=0.04
# [3015 | 3402.67] loss=0.04 avg=0.04
# [3016 | 3403.60] loss=0.02 avg=0.04
# [3017 | 3404.53] loss=0.05 avg=0.04
# [3018 | 3405.46] loss=0.03 avg=0.04
# [3019 | 3406.38] loss=0.03 avg=0.04
# [3020 | 3407.32] loss=0.04 avg=0.04
# [3021 | 3408.25] loss=0.02 avg=0.04
# [3022 | 3409.18] loss=0.03 avg=0.04
# [3023 | 3410.11] loss=0.03 avg=0.04
# [3024 | 3411.04] loss=0.07 avg=0.04
# [3025 | 3411.96] loss=0.06 avg=0.04
# [3026 | 3412.89] loss=0.07 avg=0.04
# [3027 | 3413.82] loss=0.06 avg=0.04
# [3028 | 3414.75] loss=0.04 avg=0.04
# [3029 | 3415.68] loss=0.03 avg=0.04
# [3030 | 3416.61] loss=0.05 avg=0.04
# [3031 | 3417.54] loss=0.02 avg=0.04
# [3032 | 3418.47] loss=0.07 avg=0.04
# [3033 | 3419.40] loss=0.03 avg=0.04
# [3034 | 3420.32] loss=0.04 avg=0.04
# [3035 | 3421.26] loss=0.03 avg=0.04
# [3036 | 3422.19] loss=0.03 avg=0.04
# [3037 | 3423.11] loss=0.05 avg=0.04
# [3038 | 3424.03] loss=0.04 avg=0.04
# [3039 | 3424.97] loss=0.05 avg=0.04
# [3040 | 3425.90] loss=0.04 avg=0.04
# [3041 | 3426.82] loss=0.06 avg=0.04
# [3042 | 3427.75] loss=0.03 avg=0.04
# [3043 | 3428.67] loss=0.04 avg=0.04
# [3044 | 3429.61] loss=0.03 avg=0.04
# [3045 | 3430.53] loss=0.02 avg=0.04
# [3046 | 3431.45] loss=0.03 avg=0.04
# [3047 | 3432.38] loss=0.02 avg=0.04
# [3048 | 3433.31] loss=0.03 avg=0.04
# [3049 | 3434.23] loss=0.03 avg=0.04
# [3050 | 3435.16] loss=0.03 avg=0.04
# [3051 | 3436.09] loss=0.04 avg=0.04
# [3052 | 3437.02] loss=0.02 avg=0.04
# [3053 | 3437.95] loss=0.05 avg=0.04
# [3054 | 3438.88] loss=0.02 avg=0.04
# [3055 | 3439.81] loss=0.06 avg=0.04
# [3056 | 3440.74] loss=0.04 avg=0.04
# [3057 | 3441.67] loss=0.08 avg=0.04
# [3058 | 3442.60] loss=0.04 avg=0.04
# [3059 | 3443.52] loss=0.03 avg=0.04
# [3060 | 3444.45] loss=0.02 avg=0.04
# [3061 | 3445.38] loss=0.04 avg=0.04
# [3062 | 3446.31] loss=0.03 avg=0.04
# [3063 | 3447.23] loss=0.03 avg=0.04
# [3064 | 3448.16] loss=0.05 avg=0.04
# [3065 | 3449.09] loss=0.04 avg=0.04
# [3066 | 3450.01] loss=0.02 avg=0.04
# [3067 | 3450.94] loss=0.04 avg=0.04
# [3068 | 3451.88] loss=0.07 avg=0.04
# [3069 | 3452.81] loss=0.03 avg=0.04
# [3070 | 3453.73] loss=0.05 avg=0.04
# [3071 | 3454.66] loss=0.04 avg=0.04
# [3072 | 3455.58] loss=0.05 avg=0.04
# [3073 | 3456.51] loss=0.02 avg=0.04
# [3074 | 3457.44] loss=0.05 avg=0.04
# [3075 | 3458.36] loss=0.02 avg=0.04
# [3076 | 3459.29] loss=0.02 avg=0.04
# [3077 | 3460.22] loss=0.03 avg=0.04
# [3078 | 3461.15] loss=0.03 avg=0.04
# [3079 | 3462.08] loss=0.02 avg=0.04
# [3080 | 3463.01] loss=0.06 avg=0.04
# [3081 | 3463.95] loss=0.02 avg=0.04
# [3082 | 3464.87] loss=0.02 avg=0.04
# [3083 | 3465.80] loss=0.03 avg=0.04
# [3084 | 3466.74] loss=0.02 avg=0.04
# [3085 | 3467.66] loss=0.01 avg=0.04
# [3086 | 3468.59] loss=0.03 avg=0.04
# [3087 | 3469.51] loss=0.02 avg=0.04
# [3088 | 3470.44] loss=0.03 avg=0.04
# [3089 | 3471.37] loss=0.02 avg=0.04
# [3090 | 3472.29] loss=0.02 avg=0.04
# [3091 | 3473.22] loss=0.05 avg=0.04
# [3092 | 3474.15] loss=0.04 avg=0.04
# [3093 | 3475.08] loss=0.04 avg=0.04
# [3094 | 3476.01] loss=0.02 avg=0.04
# [3095 | 3476.93] loss=0.04 avg=0.04
# [3096 | 3477.86] loss=0.02 avg=0.04
# [3097 | 3478.79] loss=0.02 avg=0.04
# [3098 | 3479.72] loss=0.02 avg=0.04
# [3099 | 3480.64] loss=0.05 avg=0.04
# Generating samples...
# ======== SAMPLE 1 ========
#  = λvˆ, vˆ) dλ ψ(v),
# 1
# and
# T1[q, S](ξ, v, vˆ) = Γ
# S
# Γ
# q
# 0
#
# ∇S
# S
# · vˆ
#  Z
# R+
# γq(λ)q(ξ + λvˆ, vˆ) dλ ψ(v).
# Equation (50) indicates that the equilibrium distribution is a non-local average of the fibers distribution according to the sensing kernel γq and normalized by the measure of the sensed linear
# tract Γq
# 0
# over the direction vˆ. Its average is
# U0
# T
# (ξ) = U¯
# Γ
# q
# 0
# Z
# R+
# γq(λ)Eq(ξ + λvˆ) dλ
#
# that vanishes as ξ + λvˆ ∈ Ω and (27) holds true. Therefore, we perform the diffusive limit that
# leads to (22) with
# D
# 0
# T
# (ξ) = D
# Z
# S
# d−1
# 1
# Γ
# q
# 0
# Z
# R+
# γq(λ) q(ξ + λvˆ, vˆ) dλ vˆ ⊗ vˆ dvˆ .
# Let us now define
# D
# λ
# q
# (ξ) = Z
# S
# d−1
# q(ξ + λvˆ, vˆ) vˆ ⊗ vˆ dvˆ , (51)
# that, for each point ξ, is the diffusion tensor of the fibers on a circle of radius λ, and
# D¯ 0
# q =
# 1
# Γ
# q
# 0
# Z
# R+
# γq(λ)D
# λ
# q dλ , (52)
# that is a weighted diffusion tensor of the fibers in the whole neighborhood sensed by the cells, so
# that
# D
# 0
# T
# (ξ) = DD¯ 0
# q
# (ξ) (53)
# and
# U1
# T
# (ξ) = U c ¯ (ξ)
# Z
# S
# d−1
#
# Γ
# S
# 1
# (∇S · vˆ)
# Z
# R+
# γq(λ) q(ξ + λvˆ, vˆ) dλ!
# vˆ dvˆ
# = U c ¯ (ξ) ΓS
# 1 ∇S Z
# R+
# γq(λ)
# Z
# S
# d−1
# vˆ ⊗ vˆ q(ξ + λvˆ, vˆ) dvˆ dλ =
# = U¯ Γ
# S D¯ 0
# q
# (ξ)
# ∇S
# S(ξ)
# = χ
# S
# (ξ)D¯ 0
# q
# (ξ)∇S .
# (54)
# We have defined the chemotactic sensitivity as
# χ
# S
# (ξ) := U¯ Γ
# S
# S(ξ)
# ,
# that is a function of the chemical alone, as it is the cue inducing a diffusive behavior. Here, the
# advection velocity is related to a non-local average of the diffusion tensor of the fibers D¯ 0
# q projected on ∇S, and it cannot be decomposed into two contributions because of the large size of the
# cell with respect to the spatial variability of the fibers distribution. Therefore, in this case the
# additivity effect of the two cues is not evident and the possible scenarios are many more.
# Remark If we consider γq = δ(λ − 0) we obtain a local sensing of fibers. Without chemotaxis we
# would have the classical model for contact guidance [24], that gives rise, at the macroscopic level,
# to a fully anisotropic diffusive equation. The presence of a non-local chemoattractant, even when
# R < lS , gives rise to a drift correction term proportional to Dq∇S.
# Case iv) The last case allows only for the Taylor expansion of the distribution function q, as in
# (32). Therefore, the turning kernel may be approximated as
# T[q, S](x, v, vˆ) =h
# c0(x) Γq
# 0
# q(x, vˆ)
# Z
# R+
# γS (λ)S(x + �
#
# [3100 | 3501.30] loss=0.05 avg=0.04
# [3101 | 3502.22] loss=0.03 avg=0.04
# [3102 | 3503.15] loss=0.06 avg=0.04
# [3103 | 3504.07] loss=0.05 avg=0.04
# [3104 | 3505.00] loss=0.03 avg=0.04
# [3105 | 3505.93] loss=0.04 avg=0.04
# [3106 | 3506.87] loss=0.03 avg=0.04
# [3107 | 3507.80] loss=0.03 avg=0.04
# [3108 | 3508.73] loss=0.02 avg=0.04
# [3109 | 3509.66] loss=0.05 avg=0.04
# [3110 | 3510.59] loss=0.02 avg=0.04
# [3111 | 3511.51] loss=0.05 avg=0.04
# [3112 | 3512.44] loss=0.02 avg=0.04
# [3113 | 3513.37] loss=0.03 avg=0.04
# [3114 | 3514.30] loss=0.02 avg=0.04
# [3115 | 3515.23] loss=0.05 avg=0.04
# [3116 | 3516.15] loss=0.02 avg=0.04
# [3117 | 3517.08] loss=0.03 avg=0.04
# [3118 | 3518.01] loss=0.03 avg=0.04
# [3119 | 3518.94] loss=0.06 avg=0.04
# [3120 | 3519.87] loss=0.05 avg=0.04
# [3121 | 3520.80] loss=0.03 avg=0.04
# [3122 | 3521.73] loss=0.05 avg=0.04
# [3123 | 3522.65] loss=0.04 avg=0.04
# [3124 | 3523.58] loss=0.02 avg=0.04
# [3125 | 3524.52] loss=0.04 avg=0.04
# [3126 | 3525.45] loss=0.04 avg=0.04
# [3127 | 3526.37] loss=0.04 avg=0.04
# [3128 | 3527.30] loss=0.06 avg=0.04
# [3129 | 3528.23] loss=0.02 avg=0.04
# [3130 | 3529.15] loss=0.05 avg=0.04
# [3131 | 3530.08] loss=0.05 avg=0.04
# [3132 | 3531.01] loss=0.04 avg=0.04
# [3133 | 3531.94] loss=0.03 avg=0.04
# [3134 | 3532.87] loss=0.03 avg=0.04
# [3135 | 3533.80] loss=0.04 avg=0.04
# [3136 | 3534.73] loss=0.06 avg=0.04
# [3137 | 3535.66] loss=0.03 avg=0.04
# [3138 | 3536.59] loss=0.04 avg=0.04
# [3139 | 3537.52] loss=0.03 avg=0.04
# [3140 | 3538.45] loss=0.04 avg=0.04
# [3141 | 3539.38] loss=0.04 avg=0.04
# [3142 | 3540.31] loss=0.02 avg=0.04
# [3143 | 3541.23] loss=0.03 avg=0.04
# [3144 | 3542.16] loss=0.04 avg=0.04
# [3145 | 3543.09] loss=0.03 avg=0.04
# [3146 | 3544.02] loss=0.03 avg=0.04
# [3147 | 3544.95] loss=0.03 avg=0.04
# [3148 | 3545.88] loss=0.04 avg=0.04
# [3149 | 3546.81] loss=0.05 avg=0.04
# [3150 | 3547.73] loss=0.04 avg=0.04
# [3151 | 3548.66] loss=0.03 avg=0.04
# [3152 | 3549.59] loss=0.02 avg=0.04
# [3153 | 3550.52] loss=0.07 avg=0.04
# [3154 | 3551.46] loss=0.06 avg=0.04
# [3155 | 3552.38] loss=0.04 avg=0.04
# [3156 | 3553.31] loss=0.04 avg=0.04
# [3157 | 3554.24] loss=0.05 avg=0.04
# [3158 | 3555.16] loss=0.03 avg=0.04
# [3159 | 3556.09] loss=0.03 avg=0.04
# [3160 | 3557.02] loss=0.03 avg=0.04
# [3161 | 3557.95] loss=0.03 avg=0.04
# [3162 | 3558.88] loss=0.03 avg=0.04
# [3163 | 3559.80] loss=0.03 avg=0.04
# [3164 | 3560.73] loss=0.08 avg=0.04
# [3165 | 3561.66] loss=0.03 avg=0.04
# [3166 | 3562.59] loss=0.04 avg=0.04
# [3167 | 3563.52] loss=0.04 avg=0.04
# [3168 | 3564.44] loss=0.04 avg=0.04
# [3169 | 3565.37] loss=0.04 avg=0.04
# [3170 | 3566.30] loss=0.06 avg=0.04
# [3171 | 3567.23] loss=0.04 avg=0.04
# [3172 | 3568.15] loss=0.03 avg=0.04
# [3173 | 3569.08] loss=0.02 avg=0.04
# [3174 | 3570.01] loss=0.04 avg=0.04
# [3175 | 3570.95] loss=0.03 avg=0.04
# [3176 | 3571.88] loss=0.06 avg=0.04
# [3177 | 3572.81] loss=0.06 avg=0.04
# [3178 | 3573.74] loss=0.10 avg=0.04
# [3179 | 3574.67] loss=0.03 avg=0.04
# [3180 | 3575.60] loss=0.02 avg=0.04
# [3181 | 3576.52] loss=0.07 avg=0.04
# [3182 | 3577.45] loss=0.02 avg=0.04
# [3183 | 3578.38] loss=0.04 avg=0.04
# [3184 | 3579.31] loss=0.03 avg=0.04
# [3185 | 3580.23] loss=0.08 avg=0.04
# [3186 | 3581.17] loss=0.02 avg=0.04
# [3187 | 3582.10] loss=0.04 avg=0.04
# [3188 | 3583.03] loss=0.04 avg=0.04
# [3189 | 3583.95] loss=0.05 avg=0.04
# [3190 | 3584.88] loss=0.02 avg=0.04
# [3191 | 3585.81] loss=0.03 avg=0.04
# [3192 | 3586.75] loss=0.02 avg=0.04
# [3193 | 3587.68] loss=0.02 avg=0.04
# [3194 | 3588.60] loss=0.06 avg=0.04
# [3195 | 3589.53] loss=0.04 avg=0.04
# [3196 | 3590.45] loss=0.03 avg=0.04
# [3197 | 3591.38] loss=0.04 avg=0.04
# [3198 | 3592.31] loss=0.05 avg=0.04
# [3199 | 3593.23] loss=0.03 avg=0.04
# Generating samples...
# ======== SAMPLE 1 ========
# �¯
# Z
# R+
# γq(λ)q(x + λvˆ, vˆ) dλ + ΓS
# 1
# (∇S · vˆ)
# Z
# R+
# γq(λ)q(x + λvˆ, vˆ) dλi
# ψ(v)
# (49)
# where we neglected higher order terms in λ. Here, the normalization coefficient reduces to
# c(x) = 1
# Γ
# S
# 0 Γ
# q
# 0 S(x)
# .
# In this case we may choose
#  = min
# 1
# ηq
# , ηS
#
# ,
# and, re-scaling the space variable as (14), we get
# T0[q, S](ξ, v, vˆ) = 1
# Γ
# q
# 0
# Z
# R+
# γq(λ)q(ξ + λvˆ, vˆ) dλ ψ(v) (50)
# and
# T1[q, S](ξ, v, vˆ) = Γ
# S
# Γ
# q
# 0
#
# ∇S
# S
# · vˆ
#  Z
# R+
# γq(λ)q(ξ + λvˆ, vˆ) dλ ψ(v).
# Equation (50) indicates that the equilibrium distribution is a non-local average of the fibers distribution according to the sensing kernel γq and normalized by the measure of the sensed linear
# tract Γq
# 0
# over the direction vˆ. Its average is
# U0
# T
# (ξ) = U¯
# Γ
# q
# 0
# Z
# R+
# γq(λ)Eq(ξ + λvˆ) dλ
#
# that vanishes as ξ + λvˆ ∈ Ω and (27) holds true. Therefore, we perform the diffusive limit that
# leads to (22) with
# D
# 0
# T
# (ξ) = D
# Z
# S
# d−1
# 1
# Γ
# q
# 0
# Z
# R+
# γq(λ) q(ξ + λvˆ, vˆ) dλ vˆ ⊗ vˆ dvˆ .
# Let us now define
# D
# λ
# q
# (ξ) = Z
# S
# d−1
# q(ξ + λvˆ, vˆ) vˆ ⊗ vˆ dvˆ , (51)
# that, for each point ξ, is the diffusion tensor of the fibers on a circle of radius λ, and
# D¯ 0
# q =
# 1
# Γ
# q
# 0
# Z
# R+
# γq(λ)D
# λ
# q dλ , (52)
# that is a weighted diffusion tensor of the fibers in the whole neighborhood sensed by the cells, so
# that
# D
# 0
# T
# (ξ) = DD¯ 0
# q
# (ξ) (53)
# and
# U1
# T
# (ξ) = U c ¯ (ξ)
# Z
# S
# d−1
#
# Γ
# S
# 1
# (∇S · vˆ)
# Z
# R+
# γq(λ) q(ξ + λvˆ, vˆ) dλ!
# vˆ dvˆ
# = U c ¯ (ξ) ΓS
# 1 ∇S Z
# R+
# γq(λ)
# Z
# S
# d−1
# vˆ ⊗ vˆ q(ξ + λvˆ, vˆ) dvˆ dλ =
# = U¯ Γ
# S D¯ 0
# q
# (ξ)
# ∇S
# S(ξ)
# = χ
# S
# (ξ)D¯ 0
# q
# (ξ)∇S .
# (54)
# We have defined the chemotactic sensitivity as
# χ
# S
# (ξ) := U¯ Γ
# S
# S(ξ)
# ,
# that is a function of the chemical alone, as it is the cue inducing a diffusive behavior. Here, the
# advection velocity is related to a non-local average of the diffusion tensor of the fibers D¯ 0
# q projected on ∇S, and it cannot be decomposed into two contributions because of the large size of the
# cell with respect to the spatial variability of the fibers distribution
#
# [3200 | 3614.03] loss=0.09 avg=0.04
# [3201 | 3614.96] loss=0.03 avg=0.04
# [3202 | 3615.89] loss=0.05 avg=0.04
# [3203 | 3616.82] loss=0.02 avg=0.04
# [3204 | 3617.75] loss=0.03 avg=0.04
# [3205 | 3618.68] loss=0.03 avg=0.04
# [3206 | 3619.62] loss=0.31 avg=0.04
# [3207 | 3620.55] loss=0.12 avg=0.04
# [3208 | 3621.47] loss=0.04 avg=0.04
# [3209 | 3622.41] loss=0.06 avg=0.04
# [3210 | 3623.34] loss=0.04 avg=0.04
# [3211 | 3624.28] loss=0.05 avg=0.04
# [3212 | 3625.21] loss=0.04 avg=0.04
# [3213 | 3626.15] loss=0.05 avg=0.04
# [3214 | 3627.08] loss=0.04 avg=0.04
# [3215 | 3628.01] loss=0.04 avg=0.04
# [3216 | 3628.95] loss=0.05 avg=0.04
# [3217 | 3629.88] loss=0.06 avg=0.04
# [3218 | 3630.82] loss=0.09 avg=0.04
# [3219 | 3631.75] loss=0.02 avg=0.04
# [3220 | 3632.68] loss=0.04 avg=0.04
# [3221 | 3633.62] loss=0.05 avg=0.04
# [3222 | 3634.55] loss=0.06 avg=0.04
# [3223 | 3635.49] loss=0.04 avg=0.04
# [3224 | 3636.42] loss=0.40 avg=0.05
# [3225 | 3637.35] loss=0.07 avg=0.05
# [3226 | 3638.28] loss=0.03 avg=0.05
# [3227 | 3639.21] loss=0.09 avg=0.05
# [3228 | 3640.14] loss=0.07 avg=0.05
# [3229 | 3641.08] loss=0.03 avg=0.05
# [3230 | 3642.01] loss=0.05 avg=0.05
# [3231 | 3642.94] loss=0.04 avg=0.05
# [3232 | 3643.87] loss=0.06 avg=0.05
# [3233 | 3644.81] loss=0.07 avg=0.05
# [3234 | 3645.74] loss=0.08 avg=0.05
# [3235 | 3646.68] loss=0.06 avg=0.05
# [3236 | 3647.61] loss=0.04 avg=0.05
# [3237 | 3648.55] loss=0.05 avg=0.05
# [3238 | 3649.48] loss=0.04 avg=0.05
# [3239 | 3650.41] loss=0.05 avg=0.05
# [3299 | 3706.37] loss=0.06 avg=0.05
# Generating samples...
# ======== SAMPLE 1 ========
#
#
# ∇S
# S
# . (69)
# We have defined the chemoattractant as
# T[q, S](x, v, vˆ) =c(x)
# h
# S(x) ΓS
# 0
# Z
# R+
# γq(λ)q(x + λvˆ) dλ + ΓS
# 1
# (∇S · vˆ)
# Z
# R+
# γq(λ)q(x + λvˆ) dλi
# ψ(v)
# (70)
# where we neglected higher order terms in λ. Here, the normalization coefficient reduces to
# c(x) = 1
# Γ
# S
# 0 Γ
# q
# 0 S(x)
# .
# In this case we may choose
#  = min
# 1
# Γ
# q
# 0
# ,
# that is the advective term describing the case in which the cell density is conserved. We shall consider the sensing radius R = 0.7
# , that is the one in Fig. 9a. The sensing radius of the cells is R = 0.7
# because of the high density of cells in the well-defined region Ωq = [0, R]. The chemoattractant has a Gaussian profile
# S(x, v, vˆ) = p
# mS
# 2πσ2
# S
# e
# −
# ((x, v, vˆ)
# ∇S
# S
# . (71)
# It has the sensing function η  =
# R(x)
# /2
# Γ
# q
# 0
# and the second parameter
# S(x, v, vˆ) = p
# mS
# 2πσ2
# S
# e
# −
# ((x, v, vˆ)
# ∇S
# S
# . (72)
# It has the second parameter
# S(x, v, vˆ) = p
# mS
# 2πσ2
# S
# e
# −
# ((x, v, vˆ)
# ∇S
# S
# . (73)
# It has the first and second guidance cues
# S(x, v, vˆ) = q
# ψ(v)
# ,
# where
# χ1
# S
# :=
# λ
# S(x) χ2
# S
# , χ2
# S
# · vˆ
# :=
# λ
# q
# 0
# q
# 1
# (∇S · vˆ)
# · vˆ
#  as fiber
# , and
# U1
# T
# :=
# λ
# S(x) χ · i
# (68)
# .
# We can, then, introduce the small parameter
#  = min
# 1
# Γ
# q
# 0
# ,
# that is the advective term describing the case iii) in
# Eq. (37), is higher than 1, because of the higher probability
# in Fig. 9a. The chemoattractant also has a Gaussian profile
# S(x, v, vˆ) = p
# mS
# 2πσ2
# S
# e
# −
# ((x, v, vˆ)
# ∇S
# S
# ) χ2
# S
# . (74)
# It can be proved, then, that the diffusion tensor of the cells is not a Gaussian
# ρ0(x, v, vˆ) = 0
# c0(x)ノ(x)ノ(v, vˆ)
# ,
# where the last condition means that we are considering a non-local diffusive field
# ρ0(x, v, vˆ) = 0
# Z
# S
# d−1
# Z
# R+
# γq(λ)q(x + λvˆ) dλ + λvˆ dq(75)
# and, on the other hand, the classical (bimodal) term γq = γS = δ(λ − R) or
# λ(x + λvˆ)
# S(x) = δ(λ − R) by the chemoattractant.
# 4.2 Amoeboid motion and chemotaxis: non-local independent sensing
# We now want to transport the case iii) in which cells are non-local and to consider the non-local distribution given by the
# vector of the fibers located at point x in R
# and of the chemoattractant located at point y in R. Therefore, we shall consider the non-local
# diffusion distribution given by the formula (36) with the previous definition in (37).
# 3.2 Test
#
# [3300 | 3727.08] loss=0.03 avg=0.05
# [3301 | 3728.02] loss=0.06 avg=0.05
# [3302 | 3728.94] loss=0.04 avg=0.05
# [3303 | 3729.87] loss=0.02 avg=0.05
# [3363 | 3785.87] loss=0.02 avg=0.04
# [3364 | 3786.80] loss=0.03 avg=0.04
# [3365 | 3787.74] loss=0.04 avg=0.04
# [3366 | 3788.67] loss=0.04 avg=0.04
# [3367 | 3789.60] loss=0.05 avg=0.04
# [3368 | 3790.53] loss=0.09 avg=0.04
# [3369 | 3791.47] loss=0.02 avg=0.04
# [3370 | 3792.40] loss=0.04 avg=0.04
# [3371 | 3793.33] loss=0.03 avg=0.04
# [3372 | 3794.27] loss=0.05 avg=0.04
# [3373 | 3795.20] loss=0.03 avg=0.04
# [3374 | 3796.13] loss=0.03 avg=0.04
# [3375 | 3797.07] loss=0.03 avg=0.04
# [3376 | 3798.00] loss=0.04 avg=0.04
# [3377 | 3798.93] loss=0.05 avg=0.04
# [3378 | 3799.85] loss=0.04 avg=0.04
# [3379 | 3800.79] loss=0.02 avg=0.04
# [3380 | 3801.72] loss=0.03 avg=0.04
# [3381 | 3802.65] loss=0.03 avg=0.04
# [3382 | 3803.58] loss=0.04 avg=0.04
# [3383 | 3804.52] loss=0.03 avg=0.04
# [3384 | 3805.44] loss=0.03 avg=0.04
# [3385 | 3806.38] loss=0.05 avg=0.04
# [3386 | 3807.31] loss=0.04 avg=0.04
# [3387 | 3808.24] loss=0.04 avg=0.04
# [3388 | 3809.17] loss=0.06 avg=0.04
# [3389 | 3810.10] loss=0.03 avg=0.04
# [3390 | 3811.03] loss=0.04 avg=0.04
# [3391 | 3811.95] loss=0.04 avg=0.04
# [3392 | 3812.88] loss=0.05 avg=0.04
# [3393 | 3813.81] loss=0.03 avg=0.04
# [3394 | 3814.73] loss=0.03 avg=0.04
# [3395 | 3815.67] loss=0.06 avg=0.04
# [3396 | 3816.59] loss=0.02 avg=0.04
# [3397 | 3817.52] loss=0.02 avg=0.04
# [3398 | 3818.45] loss=0.03 avg=0.04
# [3399 | 3819.38] loss=0.03 avg=0.04
# Generating samples...
# ======== SAMPLE 1 ========
# ...
# [4805 | 5428.89] loss=0.02 avg=0.03
# [4806 | 5429.82] loss=0.03 avg=0.03
# [4807 | 5430.76] loss=0.03 avg=0.03
# [4808 | 5431.70] loss=0.01 avg=0.03
# [4809 | 5432.64] loss=0.04 avg=0.03
# [4810 | 5433.57] loss=0.02 avg=0.03
# [4811 | 5434.50] loss=0.01 avg=0.03
# [4812 | 5435.43] loss=0.03 avg=0.03
# [4813 | 5436.37] loss=0.03 avg=0.03
# [4814 | 5437.31] loss=0.02 avg=0.03
# [4815 | 5438.24] loss=0.02 avg=0.03
# [4816 | 5439.17] loss=0.04 avg=0.03
# [4817 | 5440.11] loss=0.02 avg=0.03
# [4818 | 5441.04] loss=0.04 avg=0.03
# [4819 | 5441.98] loss=0.02 avg=0.03
# [4820 | 5442.91] loss=0.02 avg=0.03
# [4821 | 5443.86] loss=0.03 avg=0.03
# [4822 | 5444.79] loss=0.03 avg=0.03
# [4823 | 5445.73] loss=0.03 avg=0.03
# [4824 | 5446.67] loss=0.03 avg=0.03
# [4825 | 5447.60] loss=0.05 avg=0.03
# [4826 | 5448.55] loss=0.02 avg=0.03
# [4827 | 5449.48] loss=0.03 avg=0.03
# [4828 | 5450.42] loss=0.02 avg=0.03
# [4829 | 5451.35] loss=0.02 avg=0.03
# [4830 | 5452.29] loss=0.04 avg=0.03
# [4831 | 5453.23] loss=0.04 avg=0.03
# [4832 | 5454.16] loss=0.02 avg=0.03
# [4833 | 5455.10] loss=0.02 avg=0.03
# [4834 | 5456.03] loss=0.01 avg=0.03
# [4835 | 5456.96] loss=0.04 avg=0.03
# [4836 | 5457.90] loss=0.03 avg=0.03
# [4837 | 5458.83] loss=0.02 avg=0.03
# [4838 | 5459.77] loss=0.04 avg=0.03
# [4839 | 5460.71] loss=0.03 avg=0.03
# [4840 | 5461.64] loss=0.02 avg=0.03
# [4841 | 5462.58] loss=0.02 avg=0.03
# [4842 | 5463.50] loss=0.03 avg=0.03
# [4843 | 5464.44] loss=0.04 avg=0.03
# [4844 | 5465.38] loss=0.03 avg=0.03
# [4845 | 5466.32] loss=0.02 avg=0.03
# [4846 | 5467.25] loss=0.02 avg=0.03
# [4847 | 5468.18] loss=0.02 avg=0.03
# [4848 | 5469.11] loss=0.02 avg=0.03
# [4849 | 5470.06] loss=0.02 avg=0.03
# [4850 | 5470.99] loss=0.05 avg=0.03
# [4851 | 5471.93] loss=0.03 avg=0.03
# [4852 | 5472.87] loss=0.02 avg=0.03
# [4853 | 5473.80] loss=0.02 avg=0.03
# [4854 | 5474.73] loss=0.02 avg=0.03
# [4855 | 5475.67] loss=0.04 avg=0.03
# [4856 | 5476.60] loss=0.02 avg=0.03
# [4857 | 5477.54] loss=0.03 avg=0.03
# [4858 | 5478.48] loss=0.02 avg=0.03
# [4859 | 5479.41] loss=0.02 avg=0.03
# [4860 | 5480.35] loss=0.03 avg=0.03
# [4861 | 5481.29] loss=0.02 avg=0.03
# [4862 | 5482.22] loss=0.03 avg=0.03
# [4863 | 5483.15] loss=0.03 avg=0.03
# [4864 | 5484.08] loss=0.02 avg=0.03
# [4865 | 5485.01] loss=0.02 avg=0.03
# [4866 | 5485.94] loss=0.03 avg=0.03
# [4867 | 5486.88] loss=0.03 avg=0.03
# [4868 | 5487.81] loss=0.02 avg=0.03
# [4869 | 5488.75] loss=0.03 avg=0.03
# [4870 | 5489.68] loss=0.02 avg=0.03
# [4871 | 5490.62] loss=0.02 avg=0.03
# [4872 | 5491.56] loss=0.02 avg=0.03
# [4873 | 5492.49] loss=0.02 avg=0.03
# [4874 | 5493.41] loss=0.03 avg=0.03
# [4875 | 5494.35] loss=0.02 avg=0.03
# [4876 | 5495.28] loss=0.02 avg=0.03
# [4877 | 5496.22] loss=0.02 avg=0.03
# [4878 | 5497.16] loss=0.02 avg=0.03
# [4879 | 5498.09] loss=0.02 avg=0.03
# [4880 | 5499.02] loss=0.04 avg=0.03
# [4881 | 5499.95] loss=0.02 avg=0.03
# [4882 | 5500.90] loss=0.03 avg=0.03
# [4883 | 5501.83] loss=0.02 avg=0.03
# [4884 | 5502.77] loss=0.04 avg=0.03
# [4885 | 5503.70] loss=0.02 avg=0.03
# [4886 | 5504.64] loss=0.03 avg=0.03
# [4887 | 5505.57] loss=0.03 avg=0.03
# [4888 | 5506.51] loss=0.05 avg=0.03
# [4889 | 5507.44] loss=0.04 avg=0.03
# [4890 | 5508.38] loss=0.04 avg=0.03
# [4891 | 5509.31] loss=0.02 avg=0.03
# [4892 | 5510.25] loss=0.03 avg=0.03
# [4893 | 5511.18] loss=0.02 avg=0.03
# [4894 | 5512.12] loss=0.03 avg=0.03
# [4895 | 5513.06] loss=0.03 avg=0.03
# [4896 | 5514.00] loss=0.03 avg=0.03
# [4897 | 5514.92] loss=0.02 avg=0.03
# [4898 | 5515.86] loss=0.01 avg=0.03
# [4899 | 5516.79] loss=0.02 avg=0.03
# Generating samples...
# ======== SAMPLE 1 ========
#  Painter, and H. G. Othmer. The diffusion limit of transport equations ii: Chemotaxis equations.
# SIAM J. Appl. Math., 62:1222–1250, 2002.
# [41] H. Othmer and A. Stevens. Aggregation, blowup, and collapse: The ABC’s of taxis in
# reinforced random walks. SIAM J. Appl. Math., 57:1044–1081, 2001.
# [42] H. G. Othmer, S. R. Dunbar, and W. Alt. Models of dispersal in biological systems. J. Math.
# Biol., 26(3):263–298, 1988.
# [43] K. J. Painter. Modelling cell migration strategies in the extracellular matrix. J. Math. Biol.,
# 58(4):511–543, 2008.
# [44] K. J. Painter and T. Hillen. Transport and anisotropic diffusion models for movement in
# oriented habitats, volume 2071, pages 177–222. Lect. Notes Math., Springer - verlag -, 2013.
# [45] A. Palcewski. Velocity averaging for boundary value problems, pages 1–284. Ser. Adv. Math.
# Appl. Sci. World Scientific Publishing Company, 1992.
# [46] R. Pettersson. On solutions to the Linear Boltzmann equation for granular gases. Transport
# Theor. Stat., 33(5-7):527–543, 2004.
# [47] R. G. Plaza. Derivation of a bacterial nutrient-taxis system with doubly degenerate crossdiffusion as the parabolic limit of a velocity-jump process. J. Math. Biol., 78(6):1681–1711,
# 2019.
# [48] K. E. Pourfarhangi, E. Hoz, A. Cohen, and B. Gligorijevic. Contact guidance is cell cycledependent. APL Bioeng., 2:031904, 2018.
# [49] P. P. Provenzano, K. W. Eliceiri, J. M. Campbell, and et al. Collagen reorganization at the
# tumor-stromal interface facilitates local invasion. BMC Med., 4(1):38, 2006.
# [50] P. P. Provenzano, K. W. Eliceiri, and P. J. Keely. Shining new light on 3d cell motility and
# the metastatic process. Trends Cell Biol., 19(11):638–648, 2009.
# [51] A. M. Rajnicek, L. E. Foubister, and C. D. McCaig. Prioritising guidance cues: Directional migration induced by substratum contours and electrical gradients is controlled by a
# rho/cdc42 switch. Dev. Biol., 312(1):448–460, 2007.
# [52] S. W. Rhee, A. M. Taylor, C. H. Tu, D. H. Cribbs, C. Cotman, and N. Li Jeon. Patterned
# cell culture inside microfluidic devices. Lab Chip, 51:102–107, 2005.
# [53] D. Schlter, I. Ramis-Conde, and M. Chaplain. Computational modeling of single-cell migration: The leading role of extracellular matrix fibers. Biophys. J., 103:1141–51, 2012.
# [54] M. Scianna, L. Preziosi, and K. Wolf. A cellular potts model simulating cell migration on
# and in matrix environments. Math. Biosci. Eng., 10:235–261, 2013.
# [55] P. Steeg. Targeting metastasis. Nat. Rev. Cancer., 16:201–218, 2016.
# [56] D. W. Stroock. Some stochastic processes which arise from a model of the motion of a
# bacterium. Z. Wahrscheinlichkeit, 28(4):305–315, 1974.
# [57] H. Sundararaghavan, R. Saunders, D. Hammer, and J. Burdick. Fiber alignment directs cell
# motility over chemotactic gradients. Biotechnol. Bioeng., 110(4):1249–1254, 2013.
# [58] M. A. Wagle and R. T. Tranquillo. A self-consistent cell flux expression for simultaneous
# chemotaxis and contact guidance in tissues. J. Math. Biol., 41(4):315–330, 2000.
# 33
# [59] P. C. Wilkinson and J. M. Lackie.
#
# [4900 | 5537.70] loss=0.05 avg=0.03
# [4901 | 5538.64] loss=0.01 avg=0.03
# [4902 | 5539.58] loss=0.02 avg=0.03
# [4903 | 5540.52] loss=0.03 avg=0.03
# [4904 | 5541.45] loss=0.03 avg=0.03
# [4905 | 5542.39] loss=0.05 avg=0.03
# [4906 | 5543.32] loss=0.03 avg=0.03
# [4907 | 5544.26] loss=0.03 avg=0.03
# [4908 | 5545.19] loss=0.02 avg=0.03
# [4909 | 5546.12] loss=0.01 avg=0.03
# [4910 | 5547.05] loss=0.02 avg=0.03
# [4911 | 5547.99] loss=0.01 avg=0.03
# [4912 | 5548.93] loss=0.05 avg=0.03
# [4913 | 5549.86] loss=0.03 avg=0.03
# [4914 | 5550.80] loss=0.02 avg=0.03
# [4915 | 5551.73] loss=0.03 avg=0.03
# [4916 | 5552.67] loss=0.03 avg=0.03
# [4917 | 5553.61] loss=0.03 avg=0.03
# [4918 | 5554.54] loss=0.02 avg=0.03
# [4919 | 5555.47] loss=0.05 avg=0.03
# [4920 | 5556.41] loss=0.02 avg=0.03
# [4921 | 5557.35] loss=0.02 avg=0.03
# [4922 | 5558.29] loss=0.03 avg=0.03
# [4923 | 5559.22] loss=0.02 avg=0.03
# [4924 | 5560.15] loss=0.01 avg=0.03
# [4925 | 5561.09] loss=0.03 avg=0.03
# [4926 | 5562.02] loss=0.04 avg=0.03
# [4927 | 5562.96] loss=0.02 avg=0.03
# [4928 | 5563.90] loss=0.04 avg=0.03
# [4929 | 5564.82] loss=0.06 avg=0.03
# [4930 | 5565.76] loss=0.02 avg=0.03
# [4931 | 5566.69] loss=0.03 avg=0.03
# [4932 | 5567.64] loss=0.01 avg=0.03
# [4933 | 5568.57] loss=0.02 avg=0.03
# [4934 | 5569.50] loss=0.04 avg=0.03
# [4935 | 5570.44] loss=0.03 avg=0.03
# [4936 | 5571.37] loss=0.03 avg=0.03
# [4937 | 5572.32] loss=0.02 avg=0.03
# [4938 | 5573.26] loss=0.02 avg=0.03
# [4939 | 5574.19] loss=0.02 avg=0.03
# [4940 | 5575.12] loss=0.03 avg=0.03
# [4941 | 5576.06] loss=0.04 avg=0.03
# [4942 | 5577.00] loss=0.03 avg=0.03
# [4943 | 5577.94] loss=0.06 avg=0.03
# [4944 | 5578.88] loss=0.03 avg=0.03
# [4945 | 5579.81] loss=0.04 avg=0.03
# [4946 | 5580.75] loss=0.02 avg=0.03
# [4947 | 5581.68] loss=0.02 avg=0.03
# [4948 | 5582.61] loss=0.03 avg=0.03
# [4949 | 5583.55] loss=0.03 avg=0.03
# [4950 | 5584.48] loss=0.02 avg=0.03
# [4951 | 5585.42] loss=0.03 avg=0.03
# [4952 | 5586.34] loss=0.03 avg=0.03
# [4953 | 5587.28] loss=0.03 avg=0.03
# [4954 | 5588.21] loss=0.05 avg=0.03
# [4955 | 5589.14] loss=0.01 avg=0.03
# [4956 | 5590.08] loss=0.02 avg=0.03
# [4957 | 5591.02] loss=0.03 avg=0.03
# [4958 | 5591.95] loss=0.03 avg=0.03
# [4959 | 5592.90] loss=0.05 avg=0.03
# [4960 | 5593.83] loss=0.02 avg=0.03
# [4961 | 5594.76] loss=0.03 avg=0.03
# [4962 | 5595.70] loss=0.03 avg=0.03
# [4963 | 5596.64] loss=0.02 avg=0.03
# [4964 | 5597.57] loss=0.04 avg=0.03
# [4965 | 5598.51] loss=0.01 avg=0.03
# [4966 | 5599.44] loss=0.02 avg=0.03
# [4967 | 5600.38] loss=0.05 avg=0.03
# [4968 | 5601.32] loss=0.03 avg=0.03
# [4969 | 5602.25] loss=0.03 avg=0.03
# [4970 | 5603.19] loss=0.04 avg=0.03
# [4971 | 5604.12] loss=0.02 avg=0.03
# [4972 | 5605.06] loss=0.03 avg=0.03
# [4973 | 5605.98] loss=0.02 avg=0.03
# [4974 | 5606.91] loss=0.06 avg=0.03
# [4975 | 5607.85] loss=0.03 avg=0.03
# [4976 | 5608.78] loss=0.04 avg=0.03
# [4977 | 5609.71] loss=0.02 avg=0.03
# [4978 | 5610.65] loss=0.02 avg=0.03
# [4979 | 5611.58] loss=0.03 avg=0.03
# [4980 | 5612.52] loss=0.02 avg=0.03
# [4981 | 5613.46] loss=0.02 avg=0.03
# [4982 | 5614.40] loss=0.04 avg=0.03
# [4983 | 5615.33] loss=0.04 avg=0.03
# [4984 | 5616.26] loss=0.05 avg=0.03
# [4985 | 5617.20] loss=0.02 avg=0.03
# [4986 | 5618.13] loss=0.03 avg=0.03
# [4987 | 5619.06] loss=0.02 avg=0.03
# [4988 | 5620.00] loss=0.03 avg=0.03
# [4989 | 5620.94] loss=0.03 avg=0.03
# [4990 | 5621.87] loss=0.03 avg=0.03
# [4991 | 5622.80] loss=0.02 avg=0.03
# [4992 | 5623.74] loss=0.03 avg=0.03
# [4993 | 5624.67] loss=0.03 avg=0.03
# [4994 | 5625.61] loss=0.05 avg=0.03
# [4995 | 5626.55] loss=0.04 avg=0.03
# [4996 | 5627.47] loss=0.02 avg=0.03
# [4997 | 5628.41] loss=0.05 avg=0.03
# [4998 | 5629.35] loss=0.02 avg=0.03
# [4999 | 5630.28] loss=0.03 avg=0.03
# Saving checkpoint/run1/model-5000
# Generating samples...
# ======== SAMPLE 1 ========
#  slow, and the cell, in fact,
# has a strong preferential sense of motion centered in the left extracellular domain. As first scenario, we shall consider
# the domain modeling as a mono-directional stimulus with stimulus 1 and stimulus 2, with the same cue set
# in the domain. In particular, we shall do this in the case of independent sensing
# modeling the cell reads the most strongly, while in the case of cooperating cues measuring only the
# leftmost 1 bit of information are neglected. In particular, if the sensing radius is smaller than
# the speed of light, we shall consider the fibers more strongly influenced by light than
# by light itself, since the cell is more focused on its primary objective: to
# reach the chemoattractant. In this case, we can consider the chemoattractant, while in the second scenario,
# the sensing radius of the cell is almost the same as the one of the running average.
# In order to quantify the relative contribution of chemotaxis to contact guidance, we may
# introduce the parameter
# η =
# ηq
# ηS
# (35)
# that is larger than 1 if contact guidance prevails, whilst it is smaller then
# if chemotaxis is absent, and 1 otherwise. In particular, if η > 1, Iν(η) is the relative
# average of q and S, and Iν(η) is the coefficient of variation of the sensitivity of the
# scanner. If we consider the two chemoattractants, i.e. γS = δ(λ − 0), we obtain a
# macroscopic advection-diffusion equation, where the macroscopic velocity is induced by the spatial
# variation of the distribution of fiber directions ∇ · Dq, and the measure of S does not affect the
# choice of the direction. In this case, if ∇q vanishes, the model reduces to a fully anisotropic
# diffusive equation [24].
# 3.2 Amoeboid motion and chemotaxis: non-local dependent sensing
# Concerning the non-local dependent sensing case (5)-(9) with (37), we recall the expression of the
# transition probability
# T[q, S](x, v, vˆ) = c(x)
# Z
# R+
# γS (λ)S(x + λvˆ) dλ Z
# R+
# γq(λ) q(x + λvˆ, vˆ) dλ ψ(v).
# The macroscopic velocity is here given by
# UT (x) = c(x)U¯
# Z
# S
# d−1
# vˆ
#  Z
# R+
# γS (λ)S(x + λvˆ) dλ Z
# R+
# γq(λ) q(x + λvˆ, vˆ) dλ ∇S
# S(x)
# (68)
# and
# U1
# T = U¯ ρ(x)
# Z
# S
# d−1
# vˆ
#  Z
# R+
# γS (λ)S(x + λvˆ) dλ Z
# R+
# γq(λ) q(x + λvˆ, vˆ) dλ . (69)
# In this case, we can only consider the positive approximation (32), and the
# transition probability will be UT (x) = c(x)U¯
# Z
# S
# d−1
# vˆ
# Z
# R+
# γS (λ)S(x + λvˆ) dλ Z
# R+
# γq(λ) q(x + λvˆ, vˆ) dλ . (70)
# In this case, we can only consider the positive approximation (32), and the
# transition probability will be U¯ = c(x)
# Z
# S
# d−1
# vˆ
# Z
# R+
# γS (λ)S(x + λvˆ) dλ Z
# R+
# γq(λ) q(x + λvˆ, vˆ) dλ . (71)
# We can observe that, if we multiply the spatial variability of the distribution of fiber directions by the spatial
# variation of the sensing radius, we also in principle inate the phenomenon classically as in the classical
# introduction of classically multiply by a non-local dependent sensing classifier. In particular,
# we shall consider amoeboid cells [60] moving by contact guidance without proteolysis: cells hit
# the fiber and then move along the direction of the fiber itself. It has been shown experimentally,
# for example in the case
#
# [5000 | 5653.65] loss=0.03 avg=0.03
# [5001 | 5654.58] loss=0.02 avg=0.03
# [5002 | 5655.51] loss=0.03 avg=0.03
# [5003 | 5656.44] loss=0.02 avg=0.03
# [5004 | 5657.38] loss=0.03 avg=0.03
# [5005 | 5658.31] loss=0.03 avg=0.03
# [5006 | 5659.25] loss=0.05 avg=0.03
# [5007 | 5660.19] loss=0.02 avg=0.03
# [5008 | 5661.12] loss=0.03 avg=0.03
# [5009 | 5662.05] loss=0.06 avg=0.03
# [5010 | 5663.00] loss=0.06 avg=0.03
# [5011 | 5663.93] loss=0.04 avg=0.03
# [5012 | 5664.87] loss=0.01 avg=0.03
# [5013 | 5665.80] loss=0.05 avg=0.03
# [5014 | 5666.74] loss=0.03 avg=0.03
# [5015 | 5667.68] loss=0.02 avg=0.03
# [5016 | 5668.62] loss=0.04 avg=0.03
# [5017 | 5669.55] loss=0.03 avg=0.03
# [5018 | 5670.48] loss=0.04 avg=0.03
# [5019 | 5671.42] loss=0.03 avg=0.03
# [5020 | 5672.35] loss=0.02 avg=0.03
# [5021 | 5673.28] loss=0.05 avg=0.03
# [5022 | 5674.22] loss=0.03 avg=0.03
# [5023 | 5675.15] loss=0.03 avg=0.03
# [5024 | 5676.10] loss=0.02 avg=0.03
# [5025 | 5677.03] loss=0.01 avg=0.03
# [5026 | 5677.97] loss=0.02 avg=0.03
# [5027 | 5678.90] loss=0.03 avg=0.03
# [5028 | 5679.84] loss=0.02 avg=0.03
# [5029 | 5680.78] loss=0.03 avg=0.03
# [5030 | 5681.70] loss=0.03 avg=0.03
# [5031 | 5682.63] loss=0.02 avg=0.03
# [5032 | 5683.57] loss=0.03 avg=0.03
# [5033 | 5684.51] loss=0.03 avg=0.03
# [5034 | 5685.44] loss=0.06 avg=0.03
# [5035 | 5686.38] loss=0.01 avg=0.03
# [5036 | 5687.31] loss=0.02 avg=0.03
# [5037 | 5688.25] loss=0.04 avg=0.03
# [5038 | 5689.19] loss=0.03 avg=0.03
# [5039 | 5690.13] loss=0.03 avg=0.03
# [5040 | 5691.06] loss=0.04 avg=0.03
# [5041 | 5692.00] loss=0.03 avg=0.03
# [5042 | 5692.93] loss=0.02 avg=0.03
# [5043 | 5693.86] loss=0.02 avg=0.03
# [5044 | 5694.79] loss=0.02 avg=0.03
# [5045 | 5695.72] loss=0.05 avg=0.03
# [5046 | 5696.66] loss=0.02 avg=0.03
# [5047 | 5697.60] loss=0.04 avg=0.03
# [5048 | 5698.54] loss=0.02 avg=0.03
# [5049 | 5699.47] loss=0.05 avg=0.03
# [5050 | 5700.40] loss=0.03 avg=0.03
# [5051 | 5701.34] loss=0.02 avg=0.03
# [5052 | 5702.28] loss=0.02 avg=0.03
# [5053 | 5703.22] loss=0.02 avg=0.03
# [5054 | 5704.16] loss=0.05 avg=0.03
# [5055 | 5705.09] loss=0.06 avg=0.03
# [5056 | 5706.02] loss=0.01 avg=0.03
# [5057 | 5706.96] loss=0.02 avg=0.03
# [5058 | 5707.90] loss=0.02 avg=0.03
# [5059 | 5708.83] loss=0.02 avg=0.03
# [5060 | 5709.76] loss=0.02 avg=0.03
# [5061 | 5710.69] loss=0.02 avg=0.03
# [5062 | 5711.63] loss=0.04 avg=0.03
# [5063 | 5712.56] loss=0.01 avg=0.03
# [5064 | 5713.49] loss=0.02 avg=0.03
# interrupted
# Saving checkpoint/run1/model-5065
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.

# %%
#@title Step 10: Creating a Training Model Directory
# Creating a training model directory named 'tgmodel'
import os 
run_dir = '/content/gpt-2/models/tgmodel'
if not os.path.exists(run_dir):
  os.makedirs(run_dir)

# %%
#@title Step 10A: Copying training Files
# !cp /content/gpt-2/src/checkpoint/run1/model-1000.data-00000-of-00001 /content/gpt-2/models/tgmodel
# !cp /content/gpt-2/src/checkpoint/run1/checkpoint /content/gpt-2/models/tgmodel
# !cp /content/gpt-2/src/checkpoint/run1/model-1000.index /content/gpt-2/models/tgmodel
# !cp /content/gpt-2/src/checkpoint/run1/model-1000.meta /content/gpt-2/models/tgmodel
# Out:
# cp: cannot stat '/content/gpt-2/src/checkpoint/run1/model-1000.data-00000-of-00001': No such file or directory
# cp: cannot stat '/content/gpt-2/src/checkpoint/run1/model-1000.index': No such file or directory
# cp: cannot stat '/content/gpt-2/src/checkpoint/run1/model-1000.meta': No such file or directory

# %%
#@title Step 10B: Copying the OpenAI GPT-2 117M Model files
# !cp /content/gpt-2/models/117M/encoder.json /content/gpt-2/models/tgmodel
# !cp /content/gpt-2/models/117M/hparams.json /content/gpt-2/models/tgmodel
# !cp /content/gpt-2/models/117M/vocab.bpe /content/gpt-2/models/tgmodel

# %%
#@title Step 10C: Renaming the model directories
import os
# !mv /content/gpt-2/models/117M  /content/gpt-2/models/117M_OpenAI
# !mv /content/gpt-2/models/tgmodel  /content/gpt-2/models/117M

# %%
#@title Step 11: Generating Unconditional Samples
import os # import after runtime is restarted
os.chdir("/content/gpt-2/src")
# !python generate_unconditional_samples.py --model_name '117M'
# Out:
# WARNING:tensorflow:From generate_unconditional_samples.py:54: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-10-03 23:15:41.851977: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-10-03 23:15:41.876183: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:15:41.876978: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2021-10-03 23:15:41.877325: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-03 23:15:41.879025: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-10-03 23:15:41.880208: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-10-03 23:15:41.880590: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-10-03 23:15:41.882589: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-10-03 23:15:41.884100: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-10-03 23:15:41.888790: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-10-03 23:15:41.888960: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:15:41.890001: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:15:41.890989: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-10-03 23:15:41.899811: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2021-10-03 23:15:41.900056: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55fcfb95af40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-10-03 23:15:41.900128: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-10-03 23:15:42.001557: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:15:42.002566: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55fcfb95a840 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-10-03 23:15:42.002601: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2021-10-03 23:15:42.002801: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:15:42.003533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2021-10-03 23:15:42.003613: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-03 23:15:42.003699: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-10-03 23:15:42.003751: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-10-03 23:15:42.003801: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-10-03 23:15:42.003850: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-10-03 23:15:42.003894: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-10-03 23:15:42.003939: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-10-03 23:15:42.004036: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:15:42.004863: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:15:42.005555: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-10-03 23:15:42.005631: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-03 23:15:42.007017: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-10-03 23:15:42.007051: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-10-03 23:15:42.007080: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-10-03 23:15:42.007264: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:15:42.008104: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:15:42.008925: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-10-03 23:15:42.008980: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10813 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From generate_unconditional_samples.py:56: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:51: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/model.py:148: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/model.py:152: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/model.py:36: The name tf.rsqrt is deprecated. Please use tf.math.rsqrt instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:64: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:39: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:67: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.random.categorical` instead.
# WARNING:tensorflow:From generate_unconditional_samples.py:65: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# 2021-10-03 23:15:55.890923: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# ======================================== SAMPLE 1 ========================================
# The Retail Commercial Stage of Saigon. Photo: Courtesy Of Saigon
#
# The Retail Commercial Stage of Saigon and the Saigon
#
# This is the Retail Commercial Stage of Saigon. Photo: Courtesy Of Saigon
#
# Office Depot is located in the office complex in the Santiago, California hot tub (Image: Appo Guys)
#
# The office complex is located in the office complex in the Santiago, California hot tub (Image: Shutterstock)
#
# The office complex is located in the office complex in the Santiago, California hot tub (Image: Shutterstock)
#
# Chinatown is located in the venue. Photo: ZOMCO and MM
#
#
# More Saigon photo gallery | top picures for the suburb
#
# MORE Saigon photo gallery | top picures for the suburb by the mirror<|endoftext|>The warring factions working so closely (and finally being freed) are sharing in heinous crimes and abuses. So upsetting that Hadian Endicott went to Mumbai to meet Hossmeister's wife, and an IAS officer kept warning them not to follow Randi, Ramesh Rai and even her throbbing Huntington Pietagar keeper drift underestimating Ghinnitation's brutality.
#
# 'They used to come down here almost everyday.'
#
# she says. 'The only woman who came back was the smoking one. Once she made us juice and we tried to quit.'
#
# Mumbai is believed to have used up as many of the lives of my former shepherd as 115 persons, tiger warns sites enterprise accessible vision Te U Red Sabihgan
#
# The Kashmir Chief Lal Yojanayathan, who has effectively failed the state's case in seven cantonments and is expected to rule as independent governor, used to buy worldly artefacts and don bright green painted beach supports for every penny he had. It appears every Hindu shopkeepers were aware of his tentacles.
#
#
# One incident was an episode – even for village maharmon Gurpreet Singh. This was when his sparkling baby was admitted to the authority flat, super-cold milk was spilt on him, a large contents and some food was left for him.
#
#
# cv mortar D Richardson liable listing ingredients determined food was 'caught in sewage in a specimen dumped outside shop and coincidentally covered it with ink' and named 75 kitchen equipment No 10 of Class A & Class II & Class IV was used
#
# Bhaskar Patil Manofey's harvest and butcher item was deemed opium to have been adulterated with it, making it unsuitable for human consumption.
#
#
# One month after reading an uncomprehensible headline on Food cravings the state finally arrested the 3.2 lakh bounty hunter on burglary and plunder charges.
#
# Sudha Johanna managed to escape that fate only to be shot dead by guards. Singh's family claimed she may have been a pawn in his evisceration.<|endoftext|>From Hearthstone Wiki
#
# Twilight Tide Drake is a Common minion card, from the Knights of the Frozen Throne set.
#
# How to get [ edit | edit source ]
#
# Escape in! Infernal Return Infernal Return is a 3/3 Searing Seas Totem minion card, from the Knights of the Frozen Throne set.
#
# How to get [ edit | edit source ]
#
# Sun Sub-zero Striking One receives its mana cost reduced by 2, making it cost 2 less for each minion blocking it in the same way.
#
# How to get [ edit | edit source ]
#
# Emberboats Arc Arc on turn 5 triggers with Swamp Ooze If feeding a Spirit Dragon, restore 700 Health to this minion.
#
# Euckchanger Cellcycle On turn 6, draw a card. After it does, refresh this minion.
#
# Enter the Elf Catalyst Control this minion, restoring 900+ Health.
#
# Gallery [ edit | edit source ]<|endoftext|>Typical vinyl celebrordium coffee mug is simply a tile that has a twist on the pub flavour. This Cup will soon allude to forming a new coffee jock in a future Cup of Coffee haveer
#
# Star ornament ( aqua and floral; lightly rose colored; lightly tertiary), finger hole (aqua. slightly and momentarily pink, pink in violet). If 50CCK is not an option, keep the "Ice Draw" decoration.
#
# On top of the cup, the inspirational shape of the construction of the header promised "Cup its own Tinker Logo on top such that prizes the Heart of the Team prevail in every MTT class."
#
# Attention athletes and team leaders!
#
#
# 10th Dec - 28th Wed 10th Dec
#
# Other Links:Manifesto
#
# For the latest article on Dungie, click here Click here to download the CD series here 5pts Average monthly Gbps DX Access to all Twitter posts, headlines and citations for all MGO News sites Instacama
# ======================================== SAMPLE 4 ========================================
# If you'd like to buy or have always been passionate about Android, Android Wear and Wear in general you can get starts free by using the GOArcade app for RDeach.
#
# Yeah halloween, it's been a while since we posted this list before the release of the Nexus 4. But, if you're still looking for a new device such as the Nexus 5 then look no further and we think you'll only find incredible mobile learning pleasure when you stand up your Moto G G4.
#
# On by Google Play
#
# The Android Wear app is one of the most popular search engines in the world, with 71 million registered users in the first month of its launch. It's generally the 1st best choice for anyone looking to know more about new and updated gear for wearables.
#
# Android Wear also should definitely be included in your preorder through Google Play, so upgrade quickly to get the app in your phone.
#
# RaidYA Premium includes G Stand, Wear detection, WearDonator, Foreground and WearItem indicators, Sooji widget notification, Android maps, Android LIVE widgets, search feature, safety widget, leak prevention, Netflix play creation, bug scanning as well as video local playback, Local Play store scanning and calendar synchronization logging, time zone notification to allow you to choose from, colour display of channels, Local Apps supporting smart phone packs (Jayda Dara), own updates from LG, Color Mist, Flatline, Fluorescent Smart Ambient Light and many others.
#
# There are tons of widgets only available to manufacturers and retailers. Which one do you think there is left untouched for your latest Android Wear device? What do you think?
#
# Every single one of the above devices you see listed here will be available for FREE with the release of Android Wear. As with any new device, expect to receive updates immediately and immediately.
#
# Share this article: Facebook
#
# Twitter
#
# Pinterest
#
# Google
#
# Email<|endoftext|>Here's our first real news update. Spider-Man was struggling to clear sleep last night and being separated from an old friend for the past 7 years now, declared older Chris. As says our beloved son, he's going get over this after a 2.5 year absence.
#
# Although it looks like his friends decided to open their last doors in hopes he must go away, Man announced that housework will be closed as teams will transfer to a new lab in Batman: The Making of the DC All-New Captain America 2, well after he finishes his 'Paragon' tag.
#
# Contrary to initial reports. Guess it's 12PM on Alpha moonhouse.com right now, so cat and skate.
#
# EXCLUSIVE BAY: Amazing 'Stretch Goals' Gone Down, Reviewer with exclusive #StingrayMovie Pics
#
# BATMAN JAM-HEAD-PICKING *** THANK YOU LUST YELLA *** VERY CLOUD THINGS *** I WANT OUT OF THE WORLD***
#
# Praise come regardless of availability, quote stated with GWMA catalyst saying 'Hey, I want to spend my days when I can come home at night.'
#
# FOR the sake of our future safety and privacy we are going to go ahead and include hints including 'friendship gives us the best memories for sure' and additions 'pilots can become very angry at the catastrophe they saw.'
#
# He praised many of the work done by Doc Ock claims to be 'really bad' by saying that their solving of the problem "still takes 11 months of her life.
#
# Art Angel Kerrison, Executive Producer and Writer of Captain America 2 also in BYOB environment welcome Spider-Man's observation of the realities on his present head after a long and complicated journey with the team.
#
# He said: "It really excites me that we have Wasp to thank for cutting some credits. More and more, my bosses have discovered she is tired of the crap she has been dealing with and wants to take care of her little career."
#
#
# According to the Huffington Post, Bog Oregon Comedy has had a very positive bounce up and down this past fall, pitching a show midway at the top of the list. Right before the rankings were completed, a straight-camera performance by Bag of Geniuses at the LA Comedy Festival brought their numbers up from a second in their height parallel to their early increase. That performance caught EMC in mood a little better, with the latter featuring the full four amazing sought-after voices featured in their greatest works.
#
# Here's one of those memorable passages from the Broadwell Society's Top Ten Comedy Stat and of course one from Brogetting Reloaded, the show's Theron Talker, coming in at number 10.
#
# No story is complete without personal stories, and with "Here Comes The Stars" sits holds out the goal. Because of Bog's "Burn in the Clouds," the episode doesn't actually go down a road from King Louie (Bad Food) to BTUFC to big wrestling match, but rather an attempt to find something precious. Behold the pair of wise men and women who will help both try to outdo each other at making the jump.
#
# Translation: A proud, passionate fan, and social activist.<|endoftext|>WASHINGTON, D.C.- When fellow American 1947 moviearians like
# ======================================== SAMPLE 6 ========================================
# C Raducnano
#
# corque-raducnano.de
#
# Technical details [ edit ]
#
# Basic HPC(1) Intel Pentium W12L or AMD Bulldozer Graphics 16 support FTW MSP4 w/ Fresh 2.5" Yes No x64 Mash 5.05 ppc 17.98 pgs 1280 / 1024 x 768 (private mode) Far Cry 5,NVidia 120 ES 2.0 768 / 800 (core only) Trinity, 144 cors w/ ATI DRAM 3 GB DX 9 X45 / Nero 31/Jordan 640 x 320 iDevice Drivers Cacophony (local Windows version from http://nhpc.sysadmin.com/) does not install the engine.
#
# Opinion: This can be used on all PC-based GPUs and PC-based Windows request driver (default in cpu Detect.exe).
#
# DirectXbased HPC03X/ext.502 Build / amd64 Strength 25 somewhat managable Does not support SLI and AMD 14nm or 16nm CPUs on Intel 70nm (93%) up from 3.5 (54%) just retired from major
#
# Corson Wirebps++ – Schwä IPC Build / iManufactures Code: 03X / 45ZaccG1 Xhotex Visionray – MarkC / Consumer Gamers TeluneLink Crossfire – Trident Metals (JFA) Hardware Request Professional Double Dragon Specs GTX760 | C. 222 Carbon steel PSU 32.5" mAh 265W USB 3.0 (CEC, too short connectors) Solder CE converter for gremy (soldering P/T 110-060 MHz) Dabell PCI-E 2 EU connector MSI 370 | 128.8mm PCI0 HDD PCI-E Power Converter 8X DC power cable 5V 4Max PSU for Gaming Games PC chip | shown here with panel LED case Insignia, Lane-Level fans
#
# - See reported standard specs on page of my "Practice with IPC (ICS)2354" NVIDIA GeForce GTX 760 | C. 208 Carbon steel PSU 32.5" mAh 295W USB 3.1 (CEC_OEM, too short connectors) Amps 0.01 to 3.0A Amps raise to 50075 (currency unknown) CapSig tie edge, 84% fixed enables COM confense. I/O in PCI E fast technologies Also ASN 2740 GPU, and asymptotic further specific MIPS up to PCI 1400 MOSFET Microforbes inside GPU Power plug through I/O NET Sources of the SLI Shield Board games included: CropDragon Strike Gundam Battle NickGrue at the very beginning Mights around 25 pts, up to 22 pts A detailed list of allowed controllers for a single & SLI Shield use. https://www.ureagscraft.com/#.HUB8HA5R This board is very small and ended up being quite awkward and goes from that when very necessary, my mini could be stretched out and the pity was we need more factorarm better quality components for this interface
#
# Cons: SSD connection from fastacryption (required "CALEL" firmware)
#
# The new PCI-E Link 2.0 implementations will also improve usability, and maybe still improve performance, after removing the potential to recover unluckily.
#
# Here is a running hash table of 970EV HPC3 guys using HPC, networking as opensslD. It is full UFA version (4k-sega-installation, FORCED running), in enanto checking.time.time(0, 88), total pre-kernel is it full UFA 1.4M (50%), version 46 at median — 42710 HAL (meta boot, preface available, hw CRC moneyTCP number(s)), the hw-key belonging to roms re-treering, etc.
#
# Check tree getting out of poolsthe portfolio through groes/analy/as the lock does not behave, use a subset of the filter and ipmask probe routines and use pruning instead. Which is numbering pruning
#
# After running CORUMG build routines, boot an FFmpeg, and connect GPU on IP MAX # Bogon score for next windows opened over hw-http to catch K_- algorithm reveal checked out bogus GPU kffc_check_gputype
#
# First bridge on off of no3 from Wifi cache as router and qata lead now become loopbacks between minesh bridge, NavBLK/MAJOR rake/RIN::BLK Rebooting message dedicated to recreating TREB/IRA SRV$TOU SBRRCurrent list slow wdp_new are here inefficient because analyzing generates datahard docksfer slashing tool bad visualization mistexture occupies Open sub-num hotels responding to blacklist fallback pressing legend pack nvadm module debugging target for me , L
# ======================================== SAMPLE 7 ========================================
# POSSIBLE FIVE ASPEWING ONE OF HERE'S THE ONES OTLAS
#
# Past research on race predicts differences in cognitive and genetic markers, and this also leads, among other things, to the tendency for racist white people to hold a predisposition for sexual fantasy, from which the notion of racism would not emerge if there were no racial barriers. Black Americans with low levels of race awareness are more likely to associate patterning and characteristics of race with other aspects of skin color or traits (where they are much more likely to be male, male-seeking, lesir character and in a manner similar to Caucasians and Asians) than LGBTQIA, and at least 5% of Black men who have some kind of trans resolution dislike being there, just without an explicit social contract, terrorist lesbian group, legacy men, and White males (Bullic, 2013 ).
#
# Whig and White also categorize homosexuality as having a sexual identity with regard to mind and biology. The presence of mind can make information about intentions get distorted, harmful, or open to interpretation, and this tends to reinforce homophobes' initial prejudice against them (Gamtkin, 1997). It furthermore may be true for other white women that too many of them have sex with white men, and that their male self-esteem is subject to discrimination rather than overrepresentation. (See | | | > School & Research | all demographics | | Heat map | individualization | general section for additional non-sexual information.) Thus, regardless of this line of research, I would recommend a simple rehashing, under-refining of the scientific consensus on health disparities and masculinity/social media meme tactics (36) but know full well that it is just another hate mob. You scare people, but emailing black men initiated struggles, pushectives rather than friendships; getting in Blacks/Russians incorrect currency; ignoring empirical findings of conversion or Bull-knight power, which outlines the virus (emotional performance) and merit of white Christians' bigotry, compared to the split between those uprooting contribution to political movements and a cuz of Islamophobia or xenophobia (Nathan, Jesus, and Steve, 2009).
#
# As Walter Lippmann or this research:
#
# Possess a healthy skepticism and fashions-criticism, especially as it is constantly politicized by liars who view science as applying to satanic leaders, practitioner and dupes, manipulating clients for personal gain. Listen to other people, but it's more palatable for 1- pts to speak frankly, or DSM 6--10.
#
# mailart now<|endoftext|>NEUNUS TERRY/AFP/Getty Images
#
#
# Belgium Raedjan Harris, D-Italy Eshif Ghose: Konami GameGrid Chernko Quite callerprisingly competent as concedate at MatrixShirts.com Australia Dili's Missing Day And Blood Were I still leaking their deal of information but again as I hear (say ya few days) Wrote like feared Taipei quickly: Suggested our last two Major League Baseball players:
#
# Naby Pool Sasuke makes sense too. I hope so to its prob market. Especially excluding Nigeria Limited. I can't wait for TPP here Cause coconut op Ta Ashida Awlins steal my heart with NWO from with francose, 02 hours 27 minutes Wrote 3 yearsaid:
#
# An Indian, Wit Ge Venitharayan, says any potential back end to a successful G scene is logical conttlowed stepe prism that violin labored even crashing solidarity Stop firms & all external pressure, hurts Noneshe could sing better thinking most rips boards run global market and job S+, Asian worker experience fascinating alongside Man j who thanks system also PolKim. to taxpayers good dryourned tariff it doesn't matter, the specialist wealthy reportedly wants to shut down Asiai progress b@ An India, with droughts bent on restoring global quality Mo wore Greek Delights under CM's coat every time he spoke through speakers to promote 'derivative women civil servant'. which very few do. literally: Why find out what his sexual organs and underwear are based on a piece of Said lid EDT Things I rebut | Illian Joe The wearer of Mars ad us if he remembers completely wrong that according to the patent owners Germany de many stern to accepts the dream of it now to let us look at Pluto ehı Biacidi Campaign figured Queen, You look like a hard worker MY frequent Yelp / ding pak plencheon vintage, jeans instead straight wrist structure EXHIBIT, Hegel's ashes his replacement cigarettes effectiveness Photos Who art and talent by s email c (kind of private) @ warrenr : TTWA KHI (too long as Corbyn was Romney)
#
# We would all die young or drawn to the prime ministerial candidate name this week. David Cameron, Former Prime Minister
#
# Ted Mourinho, Obiasm addict
#
# 2, 176 Attiked Colibioni Samadhi
#
# John Danks this week: Reading religion family film (too
# ======================================== SAMPLE 9 ========================================
# A new apprehension trove released by unnamed sources in 2007 reveals >> schadenfreude about traveller Suffolk communists. "Bank cocktail Hidden diagram Liberal Experiments >> in Britain >> Running the English tourist Suins >> digging up local >> MPs >> accountuses that >> BT had manipulated Granny Line into consolidating refugee flows. >> >> >> >> >> >> Katie Noble
#
# A new apprehension trove released by unnamed sources in 2007 exposes >> schadenfreude about traveller Suffolk communists. "Bank cocktail Hidden diagram Liberal Experiments >> in Britain >> Running the English tourist Suins >> digging up local >> MPs >> accountuses that >> BT had manipulated Granny Line into consolidating refugee flows. >> >> >> >> >> Katrina Pollack
#
# Studies suggesting recent, massive decreases in World Chief Electoral figures >> how much political "boomers" to produce­ally candidates seen in metropolitan voting systems, were found to suggest >> their political financing has increased over recent decades. The programme suggests the rise of such barriers to business alliances in econometric >> data says details would change as a result. >> >> >> >> However, for sure political funding means unquestioning voting according to Qatar Too's secret Granny Line allegations, >> and the impression that many to hardcore left are >> unknown to the party's voters in such a linked country. >> >> >> >> >> Susan McNab
#
# ...
#
# Combine who the end-users of these political forces are and they see something or someone to blame for changing opinions that aren't shaped in other ways, as we both saw them as the erosion of one another in Philadelphia following Colangelo's team's turnaround to the NBA Championship Thunder in 2015, and you have a bad combination of post-racial bias, violence, media independence and even a racist administration.
#
# And so Johnson has made the point that most African Americans have no business doing much in either room, including climbing up his cleats or sitting beside his suit in the luxury suite that stands, knowing full well that he will eventually leave comfortably behind his ankles as an athlete. Harris, speaking at Thursday's Atlanta Falcons game, was clear about the real debate over athletes seeing what happened on their team.
#
# "I say don't ask, don't tell. Use the results of the preseason," he said early Thursday morning. "There is no point trying."
#
# Such an aggressive Democratic president would repeat that same mistake a lot easier if you made it in baseball. Annoyed by the way you were fired from MLB, Goodell? Not that promising, not budging, the two roles backfired. If anything it coincided and perhaps they've been extended more often. It's notoriously unlikely that it will happen again in a load of hired guys who were members of Teamsters, debate darlings, Canberra natives guessing their Marcus pyere neighbor's preference of "Europe" over "euros."
#
# The fact is, is a candidate for the Presidency (or that one at least) can't make communities change and may really make them better because it isn't true. It's a complex field that can fail or not fail in spite of sophisticated research and targeting or tireless engagement. But actually I'm going to go beyond that and dig even deeper into what lies at the heart of the disagreement, this conversation taking on whether one would ever want to run the Nation again.
#
# What is the Greater Resolutions Chicago event meant to be?
#
# On Monday night, as I sit at my computer mourning leading up to today's Red & White Anniversary NBA Finals, as Colombans listening on metal t're the many message board comments that have been left out of the Cox interview, just as where I pulled out my iPhone, waiting up and down to thump a pastor and thumping a gun to "Remain Straight!", we were greeted with ironic candour. Was it because MLS would be under my thumb, like President Obama and that the White House would be, (like me, I said), unaware of my role in help drawing peacehoned attention to Colombians listening to football and wrestling games in the Midwest from the weekend in 2015?
#
# Thanks to all those who made their voices heard like that, got my kind of interest or maybe even liked how passionate and outlandish the commentaries and Twitter posts made blasting the stripes on the World Series, Jermaine, Antigua, Puerto Rican and more got as I read the post, depending on my own interpretation of MLS. Let me me give a quick shot into a certain corner of that field.
#
# Remember last week's comments about Muhammad Ali's "running on the river" line on our Euro finals and his place in history's racial fabric?
#
# Isn't it fair to express a deep love for their beating crews?
#
# With that in mind, let me point you to IHVS' discussion of a series multiple the West undertook last week, conquered bureaucracy counters salaries (F@ our NOTICE), and commissioner Goodell. Let me explain. Let's ask how football actually works where the fan base has been forced into this stratosphere without a national team; how critically how it each box houses a warm-up point for the teams playoff series? Unfettered markets get asked why, and what motivates us to do what? Simply put, our World Cup celebration good and bad as Mayor of Framingham and the Mall of America; indeed, not a "sit-in against a horde of lumbering ruling elites"; that's why we all pick up the phone to call in the noon and do the lane over to that in a city that, oh man, otherwise wouldn't have been anaerobic fudge with kids. Provocative (watch: I'm trying to recall this as a metaphor for how good the road trip really would have beenif I had done justice to the fun of that trip). Short saunas; city proclamation of marginalized communities; secular rules against gangbanging and war, tribal tussles, military becs taking side, and the likes of that so-called "us r's and me iv without me," all approved by a majority of a (cross) community divided along a very narrow nationalism known as "privilege," or: "thousands of years, maybe
# ======================================== SAMPLE 18 ========================================
# Virtually every underground platform except for Port Authority is used for residential strip-mining (a separate semi-industrial structure).
#
#
# Then there's the whole premise of all this disinformation in the USA that will officially foment hatred. It's risible gimmicks. When Obama appearing Fred Finney reminded all of those that went "blow it!" on Insanity magazine head Frankie Sarafino in 1988 he said, "So come next, Newt Gingrich? That won't get you anywhere. You no longer want gays here you've gotta go to Sweden or
# Traceback (most recent call last):
#   File "generate_unconditional_samples.py", line 79, in <module>
#     fire.Fire(sample_model)
#   File "/usr/local/lib/python3.7/dist-packages/fire/core.py", line 141, in Fire
#     component_trace = _Fire(component, args, parsed_flag_args, context, name)
#   File "/usr/local/lib/python3.7/dist-packages/fire/core.py", line 471, in _Fire
#     target=component.__name__)
#   File "/usr/local/lib/python3.7/dist-packages/fire/core.py", line 681, in _CallAndUpdateTrace
#     component = fn(*varargs, **kwargs)
#   File "generate_unconditional_samples.py", line 71, in sample_model
#     out = sess.run(output)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 956, in run
#     run_metadata_ptr)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1180, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1359, in _do_run
#     run_metadata)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1365, in _do_call
#     return fn(*args)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1350, in _run_fn
#     target_list, run_metadata)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1443, in _call_tf_sessionrun
#     run_metadata)
# KeyboardInterrupt

# %%
#@title Step 12: Interactive Context and Completion Examples
import os # import after runtime is restarted
os.chdir("/content/gpt-2/src")
# !python interactive_conditional_samples.py --temperature 0.8 --top_k 40 --model_name '117M' --length 50
# Out:
# WARNING:tensorflow:From interactive_conditional_samples.py:57: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-10-03 23:22:54.166684: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-10-03 23:22:54.186425: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:22:54.187247: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2021-10-03 23:22:54.187581: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-03 23:22:54.189336: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-10-03 23:22:54.190285: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-10-03 23:22:54.190740: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-10-03 23:22:54.193406: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-10-03 23:22:54.195323: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-10-03 23:22:54.199658: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-10-03 23:22:54.199846: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:22:54.200829: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:22:54.201747: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-10-03 23:22:54.207088: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2021-10-03 23:22:54.207333: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x557ebca3ebc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-10-03 23:22:54.207371: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-10-03 23:22:54.305773: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:22:54.306746: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x557ebca3ea00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-10-03 23:22:54.306806: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2021-10-03 23:22:54.307014: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:22:54.307896: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2021-10-03 23:22:54.308001: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-03 23:22:54.308057: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-10-03 23:22:54.308134: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-10-03 23:22:54.308205: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-10-03 23:22:54.308256: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-10-03 23:22:54.308308: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-10-03 23:22:54.308375: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-10-03 23:22:54.308490: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:22:54.309470: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:22:54.310336: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-10-03 23:22:54.310425: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-03 23:22:54.311915: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-10-03 23:22:54.311952: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-10-03 23:22:54.311972: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-10-03 23:22:54.312126: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:22:54.313096: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-03 23:22:54.313921: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-10-03 23:22:54.313983: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10813 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From interactive_conditional_samples.py:58: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From interactive_conditional_samples.py:60: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:51: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/model.py:148: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/model.py:152: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/model.py:36: The name tf.rsqrt is deprecated. Please use tf.math.rsqrt instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:64: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:16: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:67: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.random.categorical` instead.
# WARNING:tensorflow:From interactive_conditional_samples.py:68: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Model prompt >>> During such processes, cells sense the environment and respond to external factors that induce a certain direction of motion towards specific targets (taxis): this results in a persistent migration in a certain preferential direction. The guidance cues leading to directed migration may be biochemical or biophysical. Biochemical cues can be, for example, soluble factors or growth factors that give rise to chemotaxis, which involves a mono-directional stimulus. Other cues generating mono-directional stimuli include, for instance, bound ligands to the substratum that induce haptotaxis, durotaxis, that involves migration towards regions with an increasing stiffness of the ECM, electrotaxis, also known as galvanotaxis, that prescribes a directed motion guided by an electric field or current, or phototaxis, referring to the movement oriented by a stimulus of light [34]. Important biophysical cues are some of the properties of the extracellular matrix (ECM), first among all the alignment of collagen fibers and its stiffness. In particular, the fiber alignment is shown to stimulate contact guidance [22, 21]. TL;DR:
# 2021-10-03 23:23:33.450943: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# ======================================== SAMPLE 1 ========================================
#  It is important to recognize that, when a stimulus of light is directed from a stimulus of a different direction or of the same location, the two stimuli are coordinated and should be considered together to cause the stimulus to move in the way desired. When the
# ================================================================================
# Model prompt >>> Traceback (most recent call last):
#   File "/usr/lib/python3.7/contextlib.py", line 130, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/ops.py", line 5480, in get_controller
#     yield g
#   File "interactive_conditional_samples.py", line 73, in interact_model
#     raw_text = input("Model prompt >>> ")
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "interactive_conditional_samples.py", line 91, in <module>
#     fire.Fire(interact_model)
#   File "/usr/local/lib/python3.7/dist-packages/fire/core.py", line 141, in Fire
#     component_trace = _Fire(component, args, parsed_flag_args, context, name)
#   File "/usr/local/lib/python3.7/dist-packages/fire/core.py", line 471, in _Fire
#     target=component.__name__)
#   File "/usr/local/lib/python3.7/dist-packages/fire/core.py", line 681, in _CallAndUpdateTrace
#     component = fn(*varargs, **kwargs)
#   File "interactive_conditional_samples.py", line 88, in interact_model
#     print("=" * 80)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1633, in __exit__
#     close_thread.start()
#   File "/usr/lib/python3.7/threading.py", line 857, in start
#     self._started.wait()
#   File "/usr/lib/python3.7/threading.py", line 552, in wait
#     signaled = self._cond.wait(timeout)
#   File "/usr/lib/python3.7/threading.py", line 296, in wait
#     waiter.acquire()
# KeyboardInterrupt

# %%
#@title Additional Tools: Controlling Tokenized Data
# unzip out.npz

import zipfile
with zipfile.ZipFile('/content/gpt-2/src/out.npz', 'r') as zip_ref:
  zip_ref.extractall('/content/gpt-2/src/')

#Load arr_0.npy which contains encoded dset
import numpy as np
f=np.load('/content/gpt-2/src/arr_0.npy')
print(f)
print(f.shape)
for i in range(0,10):
  print(f[i])

# we first import encoder.json
import json
i=0
with open("/content/gpt-2/models/117M/encoder.json") as read_file:
  print("Converting the JSON encoded data into a Python dictionary")
  developer = json.load(read_file) # converts the data into a Python
  for key, value in developer.items(): #we parse the decoded json data
      i+=1
      if(i>0):
        break;
      print(key, ":", value)

#we will now search for the key and value for each encoded token
  for i in range(0, 500):
    for key, value in developer.items():
      if f[i] == value:
        print(key, ":", value)
# Out:
# [1212 5644  326 ...   13  198 2682]
# (29379,)
# 1212
# 5644
# 326
# 11
# 355
# 716
# 78
# 1765
# 1868
# 4778
# Converting the JSON encoded data into a Python dictionary
# This : 1212
# Ġsuggests : 5644
# Ġthat : 326
# , : 11
# Ġas : 355
# Ġam : 716
# o : 78
# eb : 1765
# oid : 1868
# Ġcells : 4778
# Ġare : 389
# Ġless : 1342
# Ġcontract : 2775
# ile : 576
# , : 11
# Ġwhile : 981
# Ġmes : 18842
# ench : 24421
# ym : 4948
# al : 282
# Ċ : 198
# cells : 46342
# Ġare : 389
# Ġmore : 517
# Ġcontract : 2775
# ile : 576
