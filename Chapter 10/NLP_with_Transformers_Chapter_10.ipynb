# %% [markdown]
# # Question and Answering with Hugging Face

# %%
# !pip install torch==1.7.0
# Out:
# Collecting torch==1.7.0
#   Downloading torch-1.7.0-cp37-cp37m-manylinux1_x86_64.whl (776.7 MB)
#      |████████████████████████████████| 776.7 MB 3.6 kB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0) (0.16.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0) (3.7.4.3)
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0) (1.19.5)
# Installing collected packages: dataclasses, torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.9.0+cu111
#     Uninstalling torch-1.9.0+cu111:
#       Successfully uninstalled torch-1.9.0+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.10.0+cu111 requires torch==1.9.0, but you have torch 1.7.0 which is incompatible.
# torchtext 0.10.0 requires torch==1.9.0, but you have torch 1.7.0 which is incompatible.
# Successfully installed dataclasses-0.6 torch-1.7.0

# %%
# !pip install -q transformers==4.0.0

# %%
from transformers import pipeline

# %%
nlp_qa = pipeline('question-answering')
# Out:
# Downloading:   0%|          | 0.00/473 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/261M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %% [markdown]
# Sample 1:The traffic began to slow down on Pioneer Boulevard in Los Angeles, making it difficult to get out of the city. However, WBGO was playing some cool jazz, and the weather was cool, making it rather pleasant to be making it out of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow. They planned to get to Las Vegas early enough in the evening to have a nice dinner and go see a show.

# %%
sequence = "The traffic began to slow down on Pioneer Boulevard in Los Angeles,\
     making it difficult to get out of the city. However, WBGO was playing some cool jazz, \
     and the weather was cool, making it rather pleasant to be making it out of the city on this Friday afternoon. \
     Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow.\
      They planned to get to Las Vegas early enough in the evening to have a nice dinner and go see a show."

# %% [markdown]
# Quetions-Answering

# %%
nlp_qa(context=sequence, question="Where is Pioneer Boulevard?")
# Out:
# {'answer': 'Los Angeles', 'end': 66, 'score': 0.9879737496376038, 'start': 55}

# %% [markdown]
# Named Entity Recognition (NER)

# %%
nlp_ner = pipeline("ner")
# Out:
# Downloading:   0%|          | 0.00/998 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/60.0 [00:00<?, ?B/s]

# %%
print(nlp_ner(sequence))
# Out:
# [{'word': 'Pioneer', 'score': 0.9735257029533386, 'entity': 'I-LOC', 'index': 8}, {'word': 'Boulevard', 'score': 0.9944824576377869, 'entity': 'I-LOC', 'index': 9}, {'word': 'Los', 'score': 0.9995775818824768, 'entity': 'I-LOC', 'index': 11}, {'word': 'Angeles', 'score': 0.9995693564414978, 'entity': 'I-LOC', 'index': 12}, {'word': 'W', 'score': 0.991984486579895, 'entity': 'I-ORG', 'index': 26}, {'word': '##B', 'score': 0.990750253200531, 'entity': 'I-ORG', 'index': 27}, {'word': '##G', 'score': 0.9884582161903381, 'entity': 'I-ORG', 'index': 28}, {'word': '##O', 'score': 0.9722681641578674, 'entity': 'I-ORG', 'index': 29}, {'word': 'Nat', 'score': 0.9966881275177002, 'entity': 'I-PER', 'index': 59}, {'word': 'King', 'score': 0.997648298740387, 'entity': 'I-PER', 'index': 60}, {'word': 'Cole', 'score': 0.9986170530319214, 'entity': 'I-PER', 'index': 61}, {'word': 'Jo', 'score': 0.9978788495063782, 'entity': 'I-PER', 'index': 65}, {'word': 'Maria', 'score': 0.9988164901733398, 'entity': 'I-PER', 'index': 67}, {'word': 'LA', 'score': 0.998134434223175, 'entity': 'I-LOC', 'index': 74}, {'word': 'Bar', 'score': 0.9970266819000244, 'entity': 'I-LOC', 'index': 78}, {'word': '##sto', 'score': 0.8573915958404541, 'entity': 'I-LOC', 'index': 79}, {'word': '##w', 'score': 0.9920249581336975, 'entity': 'I-LOC', 'index': 80}, {'word': 'Las', 'score': 0.9993551969528198, 'entity': 'I-LOC', 'index': 87}, {'word': 'Vegas', 'score': 0.9989539384841919, 'entity': 'I-LOC', 'index': 88}]

# %%
nlp_qa = pipeline("question-answering")

# %%
print("Question 1:", nlp_qa(context=sequence, question="Where is Pioneer Boulevard ?"))
print("Question 2:", nlp_qa(context=sequence, question="Where is Los Angeles Located ?"))
print("Question 3:", nlp_qa(context=sequence, question="Where is LA ?"))
print("Question 4:", nlp_qa(context=sequence, question="Where is Barstow ?"))
print("Question 5:", nlp_qa(context=sequence, question="Where is Los Vegas Located ?"))
# Out:
# Question 1: {'score': 0.9879737496376038, 'start': 55, 'end': 66, 'answer': 'Los Angeles'}
# Question 2: {'score': 0.9899300336837769, 'start': 34, 'end': 51, 'answer': 'Pioneer Boulevard'}
# Question 3: {'score': 0.5090540647506714, 'start': 55, 'end': 66, 'answer': 'Los Angeles'}
# Question 4: {'score': 0.3695431649684906, 'start': 406, 'end': 415, 'answer': 'Las Vegas'}
# Question 5: {'score': 0.767622172832489, 'start': 34, 'end': 51, 'answer': 'Pioneer Boulevard'}

# %% [markdown]
# Question-Answering applied to NER person entities

# %%
nlp_qa(context=sequence, question="Who was singing?")
# Out:
# {'answer': 'Nat King Cole',
#  'end': 291,
#  'score': 0.9653680324554443,
#  'start': 278}

# %%
nlp_qa(context=sequence, question="Who was going to Las Vegas?")
# Out:
# {'answer': 'Nat King Cole',
#  'end': 291,
#  'score': 0.4316245913505554,
#  'start': 278}

# %%
nlp_qa(context=sequence, question="Who are they?")
# Out:
# {'answer': 'Jo and Maria',
#  'end': 319,
#  'score': 0.8486908078193665,
#  'start': 307}

# %% [markdown]
# Description of the Default Model

# %%
print(nlp_qa.model)
# Out:
# DistilBertForQuestionAnswering(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (1): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (2): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (3): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (4): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (5): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (qa_outputs): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %% [markdown]
# Question Answering with ELECTRA

# %%
nlp_qa = pipeline('question-answering', model='google/electra-small-generator', tokenizer='google/electra-small-generator')
# Out:
# Downloading:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/54.2M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Some weights of the model checkpoint at google/electra-small-generator were not used when initializing ElectraForQuestionAnswering: ['generator_predictions.LayerNorm.weight', 'generator_predictions.LayerNorm.bias', 'generator_predictions.dense.weight', 'generator_predictions.dense.bias', 'generator_lm_head.weight', 'generator_lm_head.bias']
# - This IS expected if you are initializing ElectraForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForQuestionAnswering were not initialized from the model checkpoint at google/electra-small-generator and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
nlp_qa(context=sequence, question='Who drove to Las Vegas?')
# Out:
# {'answer': 'it out of the city on this Friday afternoon.',
#  'end': 272,
#  'score': 0.0003782296844292432,
#  'start': 228}

# %% [markdown]
# Question Answering with Default Model and SRL

# %%
nlp_qa = pipeline('question-answering')

# %%
nlp_qa(context=sequence, question='What was slow?')
# Out:
# {'answer': 'The traffic', 'end': 11, 'score': 0.46530455350875854, 'start': 0}

# %%
nlp_qa(context=sequence, question='What was playing?')
# Out:
# {'answer': 'cool jazz', 'end': 156, 'score': 0.48992764949798584, 'start': 147}

# %%
nlp_qa(context=sequence, question='Who sees a show?')
# Out:
# {'answer': 'Nat King Cole',
#  'end': 291,
#  'score': 0.5588219165802002,
#  'start': 278}

# %% [markdown]
# # **HayStack Question Answering Framework**

# %%
#Install HayStack
# !pip install farm-haystack==0.6.0

#Install specific versions of urllib and torch to avoid conflicts with preinstalled versions on Colab
# !pip install urllib==1.25.4
# !pip install torch==1.6.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Collecting farm-haystack==0.6.0
#   Downloading farm_haystack-0.6.0-py3-none-any.whl (104 kB)
#      |████████████████████████████████| 104 kB 5.3 MB/s
# Collecting fastapi
#   Downloading fastapi-0.70.0-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 572 kB/s
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from farm-haystack==0.6.0) (8.10.0)
# Collecting faiss-cpu==1.6.3
#   Downloading faiss_cpu-1.6.3-cp37-cp37m-manylinux2010_x86_64.whl (7.2 MB)
#      |████████████████████████████████| 7.2 MB 21.6 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from farm-haystack==0.6.0) (1.1.5)
# Collecting sqlalchemy-utils
#   Downloading SQLAlchemy_Utils-0.37.9-py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 9.5 MB/s
# Collecting tika
#   Downloading tika-1.24.tar.gz (28 kB)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 28.2 MB/s
# Collecting elasticsearch<=7.10,>=7.7
#   Downloading elasticsearch-7.10.0-py2.py3-none-any.whl (321 kB)
#      |████████████████████████████████| 321 kB 58.1 MB/s
# Collecting uvloop
#   Downloading uvloop-0.16.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 22.0 MB/s
# Collecting tox
#   Downloading tox-3.24.4-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 4.3 MB/s
# Requirement already satisfied: coverage in /usr/local/lib/python3.7/dist-packages (from farm-haystack==0.6.0) (3.7.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from farm-haystack==0.6.0) (2.6.3)
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 43.7 MB/s
# Collecting uvicorn
#   Downloading uvicorn-0.15.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.7 MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from farm-haystack==0.6.0) (3.2.5)
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 51.6 MB/s
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from farm-haystack==0.6.0) (0.0)
# Collecting elastic-apm
#   Downloading elastic_apm-6.6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (348 kB)
#      |████████████████████████████████| 348 kB 57.2 MB/s
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.7 MB/s
# Collecting farm==0.5.0
#   Downloading farm-0.5.0-py3-none-any.whl (207 kB)
#      |████████████████████████████████| 207 kB 62.7 MB/s
# Collecting httptools
#   Downloading httptools-0.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (402 kB)
#      |████████████████████████████████| 402 kB 50.5 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from faiss-cpu==1.6.3->farm-haystack==0.6.0) (1.19.5)
# Collecting torch<1.7,>1.5
#   Downloading torch-1.6.0-cp37-cp37m-manylinux1_x86_64.whl (748.8 MB)
#      |████████████████████████████████| 748.8 MB 17 kB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from farm==0.5.0->farm-haystack==0.6.0) (5.4.8)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from farm==0.5.0->farm-haystack==0.6.0) (0.37.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from farm==0.5.0->farm-haystack==0.6.0) (1.4.1)
# Collecting flask-cors
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from farm==0.5.0->farm-haystack==0.6.0) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from farm==0.5.0->farm-haystack==0.6.0) (4.62.3)
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (from farm==0.5.0->farm-haystack==0.6.0) (1.1.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from farm==0.5.0->farm-haystack==0.6.0) (0.3.4)
# Collecting mlflow==1.0.0
#   Downloading mlflow-1.0.0-py3-none-any.whl (47.7 MB)
#      |████████████████████████████████| 47.7 MB 38 kB/s
# Collecting flask-restplus
#   Downloading flask_restplus-0.13.0-py2.py3-none-any.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 72.4 MB/s
# Collecting dotmap==1.3.0
#   Downloading dotmap-1.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from farm==0.5.0->farm-haystack==0.6.0) (57.4.0)
# Collecting transformers==3.3.1
#   Downloading transformers-3.3.1-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 59.5 MB/s
# Collecting Werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
#      |████████████████████████████████| 327 kB 75.8 MB/s
# Collecting boto3
#   Downloading boto3-1.19.4-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 59.9 MB/s
# Collecting seqeval==0.0.12
#   Downloading seqeval-0.0.12.tar.gz (21 kB)
# Collecting docker>=3.6.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 64.8 MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (2.8.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (1.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (3.13)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (1.15.0)
# Collecting databricks-cli>=0.8.0
#   Downloading databricks-cli-0.16.2.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 5.4 MB/s
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (7.1.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (0.3)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (1.4.25)
# Collecting gitpython>=2.1.0
#   Downloading GitPython-3.1.24-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 54.9 MB/s
# Collecting alembic
#   Downloading alembic-1.7.4-py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 52.8 MB/s
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (0.4.2)
# Collecting simplejson
#   Downloading simplejson-3.17.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (129 kB)
#      |████████████████████████████████| 129 kB 41.1 MB/s
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (3.17.3)
# Requirement already satisfied: Keras>=2.2.4 in /usr/local/lib/python3.7/dist-packages (from seqeval==0.0.12->farm==0.5.0->farm-haystack==0.6.0) (2.6.0)
# Collecting sentencepiece!=0.1.92
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 70.4 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.3.1->farm==0.5.0->farm-haystack==0.6.0) (3.3.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 39.0 MB/s
# Collecting tokenizers==0.8.1.rc2
#   Downloading tokenizers-0.8.1rc2-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 29.6 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3.3.1->farm==0.5.0->farm-haystack==0.6.0) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.3.1->farm==0.5.0->farm-haystack==0.6.0) (21.0)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from databricks-cli>=0.8.0->mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (0.8.9)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.3 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from elasticsearch<=7.10,>=7.7->farm-haystack==0.6.0) (2021.5.30)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from elasticsearch<=7.10,>=7.7->farm-haystack==0.6.0) (1.24.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from gitpython>=2.1.0->mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (3.7.4.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.9 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->farm==0.5.0->farm-haystack==0.6.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->farm==0.5.0->farm-haystack==0.6.0) (3.0.4)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch<1.7,>1.5->farm==0.5.0->farm-haystack==0.6.0) (0.16.0)
# Collecting Mako
#   Downloading Mako-1.1.5-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.5 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (5.2.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from alembic->mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (4.8.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (1.1.2)
# Collecting botocore<1.23.0,>=1.22.4
#   Downloading botocore-1.22.4-py3-none-any.whl (8.0 MB)
#      |████████████████████████████████| 8.0 MB 15.4 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.8 MB/s
# Collecting urllib3<2,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 62.2 MB/s
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 44.5 MB/s
# Collecting starlette==0.16.0
#   Downloading starlette-0.16.0-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 249 kB/s
# Collecting anyio<4,>=3.0.0
#   Downloading anyio-3.3.4-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 7.0 MB/s
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask->farm==0.5.0->farm-haystack==0.6.0) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask->farm==0.5.0->farm-haystack==0.6.0) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask->farm==0.5.0->farm-haystack==0.6.0) (2.0.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from flask-restplus->farm==0.5.0->farm-haystack==0.6.0) (2.6.0)
# Collecting aniso8601>=0.82
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.4 MB/s
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from flask-restplus->farm==0.5.0->farm-haystack==0.6.0) (2018.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->alembic->mlflow==1.0.0->farm==0.5.0->farm-haystack==0.6.0) (3.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.3.1->farm==0.5.0->farm-haystack==0.6.0) (2.4.7)
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from python-docx->farm-haystack==0.6.0) (4.2.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.3.1->farm==0.5.0->farm-haystack==0.6.0) (1.0.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->farm-haystack==0.6.0) (0.22.2.post1)
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.7/dist-packages (from tox->farm-haystack==0.6.0) (0.10.2)
# Collecting pluggy>=0.12.0
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0
#   Downloading virtualenv-20.9.0-py2.py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 33.4 MB/s
# Requirement already satisfied: py>=1.4.17 in /usr/local/lib/python3.7/dist-packages (from tox->farm-haystack==0.6.0) (1.10.0)
# Collecting backports.entry-points-selectable>=1.0.4
#   Downloading backports.entry_points_selectable-1.1.0-py2.py3-none-any.whl (6.2 kB)
# Collecting platformdirs<3,>=2
#   Downloading platformdirs-2.4.0-py3-none-any.whl (14 kB)
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.3-py2.py3-none-any.whl (496 kB)
#      |████████████████████████████████| 496 kB 60.3 MB/s
# Collecting asgiref>=3.4.0
#   Downloading asgiref-3.4.1-py3-none-any.whl (25 kB)
# Collecting h11>=0.8
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.1 MB/s
# Building wheels for collected packages: seqeval, databricks-cli, langdetect, python-docx, python-multipart, tika
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-0.0.12-py3-none-any.whl size=7434 sha256=50c4b5687ec14fa394835e5ab8daf5b870b9bc7f06ad97703b8e58364cc5b4c2
#   Stored in directory: /root/.cache/pip/wheels/dc/cc/62/a3b81f92d35a80e39eb9b2a9d8b31abac54c02b21b2d466edc
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.16.2-py3-none-any.whl size=106811 sha256=0a9696ad9ea32f2e9ca6c657efde103ef3aa4fa08699d1b67d5966b875a215b6
#   Stored in directory: /root/.cache/pip/wheels/f4/5c/ed/e1ce20a53095f63b27b4964abbad03e59cf3472822addf7d29
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=8ffbcb887c67c07aae4ac0b3934efc5daf699bd4374016f2c00db5902d547289
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184508 sha256=ef076d524624cd67c92bae06cd2165e25fc87c985fb34c425122d6860a718fbd
#   Stored in directory: /root/.cache/pip/wheels/f6/6f/b9/d798122a8b55b74ad30b5f52b01482169b445fbb84a11797a6
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31678 sha256=dccd6219a3d684b212889285e73ef51f89c2ea17a4d9d59891e4b5ebe4b402cb
#   Stored in directory: /root/.cache/pip/wheels/2c/41/7c/bfd1c180534ffdcc0972f78c5758f89881602175d48a8bcd2c
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-1.24-py3-none-any.whl size=32891 sha256=d5cb8825134219d990250f9b2d4616515e4ffafd9edca6af2bec3ad364da16e6
#   Stored in directory: /root/.cache/pip/wheels/ec/2b/38/58ff05467a742e32f67f5d0de048fa046e764e2fbb25ac93f3
# Successfully built seqeval databricks-cli langdetect python-docx python-multipart tika
# Installing collected packages: urllib3, smmap, jmespath, Werkzeug, websocket-client, sniffio, Mako, gitdb, botocore, tokenizers, simplejson, sentencepiece, sacremoses, s3transfer, querystring-parser, platformdirs, gunicorn, gitpython, docker, distlib, databricks-cli, backports.entry-points-selectable, anyio, aniso8601, alembic, virtualenv, transformers, torch, starlette, seqeval, pydantic, pluggy, mlflow, h11, flask-restplus, flask-cors, dotmap, boto3, asgiref, uvloop, uvicorn, tox, tika, sqlalchemy-utils, python-multipart, python-docx, psycopg2-binary, langdetect, httptools, fastapi, farm, faiss-cpu, elasticsearch, elastic-apm, farm-haystack
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Attempting uninstall: torch
#     Found existing installation: torch 1.9.0+cu111
#     Uninstalling torch-1.9.0+cu111:
#       Successfully uninstalled torch-1.9.0+cu111
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.10.0+cu111 requires torch==1.9.0, but you have torch 1.6.0 which is incompatible.
# torchtext 0.10.0 requires torch==1.9.0, but you have torch 1.6.0 which is incompatible.
# pytest 3.6.4 requires pluggy<0.8,>=0.5, but you have pluggy 1.0.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed Mako-1.1.5 Werkzeug-0.16.1 alembic-1.7.4 aniso8601-9.0.1 anyio-3.3.4 asgiref-3.4.1 backports.entry-points-selectable-1.1.0 boto3-1.19.4 botocore-1.22.4 databricks-cli-0.16.2 distlib-0.3.3 docker-5.0.3 dotmap-1.3.0 elastic-apm-6.6.0 elasticsearch-7.10.0 faiss-cpu-1.6.3 farm-0.5.0 farm-haystack-0.6.0 fastapi-0.70.0 flask-cors-3.0.10 flask-restplus-0.13.0 gitdb-4.0.9 gitpython-3.1.24 gunicorn-20.1.0 h11-0.12.0 httptools-0.3.0 jmespath-0.10.0 langdetect-1.0.9 mlflow-1.0.0 platformdirs-2.4.0 pluggy-1.0.0 psycopg2-binary-2.9.1 pydantic-1.8.2 python-docx-0.8.11 python-multipart-0.0.5 querystring-parser-1.2.4 s3transfer-0.5.0 sacremoses-0.0.46 sentencepiece-0.1.96 seqeval-0.0.12 simplejson-3.17.5 smmap-5.0.0 sniffio-1.2.0 sqlalchemy-utils-0.37.9 starlette-0.16.0 tika-1.24 tokenizers-0.8.1rc2 torch-1.6.0 tox-3.24.4 transformers-3.3.1 urllib3-1.25.11 uvicorn-0.15.0 uvloop-0.16.0 virtualenv-20.9.0 websocket-client-1.2.1
# ERROR: Could not find a version that satisfies the requirement urllib==1.25.4 (from versions: none)
# ERROR: No matching distribution found for urllib==1.25.4
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.6.0+cu101
#   Downloading https://download.pytorch.org/whl/cu101/torch-1.6.0%2Bcu101-cp37-cp37m-linux_x86_64.whl (708.0 MB)
#      |████████████████████████████████| 708.0 MB 10 kB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.6.0+cu101) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.6.0+cu101) (1.19.5)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.6.0
#     Uninstalling torch-1.6.0:
#       Successfully uninstalled torch-1.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.10.0+cu111 requires torch==1.9.0, but you have torch 1.6.0+cu101 which is incompatible.
# torchtext 0.10.0 requires torch==1.9.0, but you have torch 1.6.0+cu101 which is incompatible.
# Successfully installed torch-1.6.0+cu101

# %% [markdown]
# ## Extractive QA in a closed domain (single text)

# %%
# Load a local model or any of the QA models on Hugging Face's model hub (https://huggingface.co/models)
from haystack.reader.farm import FARMReader 

reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2", use_gpu=True, no_ans_boost=0, return_no_answer=False)


# Create document which the model should scan for answers
from haystack import Document 

text="The traffic began to slow down on Pioneer Boulevard in Los Angeles, making it difficult to get out of the city. However, WBGO was playing some cool jazz, and the weather was cool, making it rather pleasant to be making it out of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow. They planned to get to Las Vegas early enough in the evening to have a nice dinner and go see a show."
doc = Document(text=text)
# Out:
# 10/26/2021 20:55:43 - INFO - farm.utils -   device: cpu n_gpu: 0, distributed training: False, automatic mixed precision training: None
# 10/26/2021 20:55:43 - INFO - farm.infer -   Could not find `deepset/roberta-base-squad2` locally. Try to download from model hub ...
# 10/26/2021 20:55:43 - DEBUG - filelock -   Attempting to acquire lock 139942375968464 on /root/.cache/torch/transformers/f7d4b9379a9c487fa03ccf3d8e00058faa9d664cf01fc03409138246f48760da.6060f348ba2b58d6d30b5324910152ffc512e7c3891ed13f22844f1a9b5c0d0f.lock
# 10/26/2021 20:55:43 - DEBUG - filelock -   Lock 139942375968464 acquired on /root/.cache/torch/transformers/f7d4b9379a9c487fa03ccf3d8e00058faa9d664cf01fc03409138246f48760da.6060f348ba2b58d6d30b5324910152ffc512e7c3891ed13f22844f1a9b5c0d0f.lock
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# 10/26/2021 20:55:44 - DEBUG - filelock -   Attempting to release lock 139942375968464 on /root/.cache/torch/transformers/f7d4b9379a9c487fa03ccf3d8e00058faa9d664cf01fc03409138246f48760da.6060f348ba2b58d6d30b5324910152ffc512e7c3891ed13f22844f1a9b5c0d0f.lock
# 10/26/2021 20:55:44 - DEBUG - filelock -   Lock 139942375968464 released on /root/.cache/torch/transformers/f7d4b9379a9c487fa03ccf3d8e00058faa9d664cf01fc03409138246f48760da.6060f348ba2b58d6d30b5324910152ffc512e7c3891ed13f22844f1a9b5c0d0f.lock
# 10/26/2021 20:55:44 - DEBUG - filelock -   Attempting to acquire lock 139942381114000 on /root/.cache/torch/transformers/8c0c8b6371111ac5fbc176aefcf9dbe129db7be654c569b8375dd3712fc4dc67.a851909c96149f062acca04d647da88d0dcd3a52cd5a8c7169e89fc6e5971c7b.lock
# 10/26/2021 20:55:44 - DEBUG - filelock -   Lock 139942381114000 acquired on /root/.cache/torch/transformers/8c0c8b6371111ac5fbc176aefcf9dbe129db7be654c569b8375dd3712fc4dc67.a851909c96149f062acca04d647da88d0dcd3a52cd5a8c7169e89fc6e5971c7b.lock
# Downloading:   0%|          | 0.00/496M [00:00<?, ?B/s]
# 10/26/2021 20:55:58 - DEBUG - filelock -   Attempting to release lock 139942381114000 on /root/.cache/torch/transformers/8c0c8b6371111ac5fbc176aefcf9dbe129db7be654c569b8375dd3712fc4dc67.a851909c96149f062acca04d647da88d0dcd3a52cd5a8c7169e89fc6e5971c7b.lock
# 10/26/2021 20:55:58 - DEBUG - filelock -   Lock 139942381114000 released on /root/.cache/torch/transformers/8c0c8b6371111ac5fbc176aefcf9dbe129db7be654c569b8375dd3712fc4dc67.a851909c96149f062acca04d647da88d0dcd3a52cd5a8c7169e89fc6e5971c7b.lock
# Some weights of RobertaModel were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 10/26/2021 20:56:03 - WARNING - farm.modeling.language_model -   Could not automatically detect from language model name what language it is.
# 	 We guess it's an *ENGLISH* model ...
# 	 If not: Init the language model by supplying the 'language' param.
# 10/26/2021 20:56:10 - DEBUG - filelock -   Attempting to acquire lock 139942372993808 on /root/.cache/torch/transformers/1e3af82648d7190d959a9d76d727ef629b1ca51b3da6ad04039122453cb56307.6a4061e8fc00057d21d80413635a86fdcf55b6e7594ad9e25257d2f99a02f4be.lock
# 10/26/2021 20:56:10 - DEBUG - filelock -   Lock 139942372993808 acquired on /root/.cache/torch/transformers/1e3af82648d7190d959a9d76d727ef629b1ca51b3da6ad04039122453cb56307.6a4061e8fc00057d21d80413635a86fdcf55b6e7594ad9e25257d2f99a02f4be.lock
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# 10/26/2021 20:56:10 - DEBUG - filelock -   Attempting to release lock 139942372993808 on /root/.cache/torch/transformers/1e3af82648d7190d959a9d76d727ef629b1ca51b3da6ad04039122453cb56307.6a4061e8fc00057d21d80413635a86fdcf55b6e7594ad9e25257d2f99a02f4be.lock
# 10/26/2021 20:56:11 - DEBUG - filelock -   Lock 139942372993808 released on /root/.cache/torch/transformers/1e3af82648d7190d959a9d76d727ef629b1ca51b3da6ad04039122453cb56307.6a4061e8fc00057d21d80413635a86fdcf55b6e7594ad9e25257d2f99a02f4be.lock
# 10/26/2021 20:56:11 - DEBUG - filelock -   Attempting to acquire lock 139942373076304 on /root/.cache/torch/transformers/b901c69e8e7da4a24c635ad81d016d274f174261f4f5c144e43f4b00e242c3b0.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda.lock
# 10/26/2021 20:56:11 - DEBUG - filelock -   Lock 139942373076304 acquired on /root/.cache/torch/transformers/b901c69e8e7da4a24c635ad81d016d274f174261f4f5c144e43f4b00e242c3b0.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda.lock
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# 10/26/2021 20:56:11 - DEBUG - filelock -   Attempting to release lock 139942373076304 on /root/.cache/torch/transformers/b901c69e8e7da4a24c635ad81d016d274f174261f4f5c144e43f4b00e242c3b0.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda.lock
# 10/26/2021 20:56:11 - DEBUG - filelock -   Lock 139942373076304 released on /root/.cache/torch/transformers/b901c69e8e7da4a24c635ad81d016d274f174261f4f5c144e43f4b00e242c3b0.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda.lock
# 10/26/2021 20:56:11 - DEBUG - filelock -   Attempting to acquire lock 139942372806288 on /root/.cache/torch/transformers/2d9b03b59a8af464bf4238025a3cf0e5a340b9d0ba77400011e23c130b452510.6e217123a3ada61145de1f20b1443a1ec9aac93492a4bd1ce6a695935f0fd97a.lock
# 10/26/2021 20:56:11 - DEBUG - filelock -   Lock 139942372806288 acquired on /root/.cache/torch/transformers/2d9b03b59a8af464bf4238025a3cf0e5a340b9d0ba77400011e23c130b452510.6e217123a3ada61145de1f20b1443a1ec9aac93492a4bd1ce6a695935f0fd97a.lock
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# 10/26/2021 20:56:11 - DEBUG - filelock -   Attempting to release lock 139942372806288 on /root/.cache/torch/transformers/2d9b03b59a8af464bf4238025a3cf0e5a340b9d0ba77400011e23c130b452510.6e217123a3ada61145de1f20b1443a1ec9aac93492a4bd1ce6a695935f0fd97a.lock
# 10/26/2021 20:56:11 - DEBUG - filelock -   Lock 139942372806288 released on /root/.cache/torch/transformers/2d9b03b59a8af464bf4238025a3cf0e5a340b9d0ba77400011e23c130b452510.6e217123a3ada61145de1f20b1443a1ec9aac93492a4bd1ce6a695935f0fd97a.lock
# 10/26/2021 20:56:11 - DEBUG - filelock -   Attempting to acquire lock 139942372413328 on /root/.cache/torch/transformers/507984f2e28c7dfed5db9a20acd68beb969c7f2833abc9e582e967fa0291f3dc.ec06af3e1b426682955dab3bd553eaf178b6eafac9079fc133925e0e2654213e.lock
# 10/26/2021 20:56:11 - DEBUG - filelock -   Lock 139942372413328 acquired on /root/.cache/torch/transformers/507984f2e28c7dfed5db9a20acd68beb969c7f2833abc9e582e967fa0291f3dc.ec06af3e1b426682955dab3bd553eaf178b6eafac9079fc133925e0e2654213e.lock
# Downloading:   0%|          | 0.00/79.0 [00:00<?, ?B/s]
# 10/26/2021 20:56:12 - DEBUG - filelock -   Attempting to release lock 139942372413328 on /root/.cache/torch/transformers/507984f2e28c7dfed5db9a20acd68beb969c7f2833abc9e582e967fa0291f3dc.ec06af3e1b426682955dab3bd553eaf178b6eafac9079fc133925e0e2654213e.lock
# 10/26/2021 20:56:12 - DEBUG - filelock -   Lock 139942372413328 released on /root/.cache/torch/transformers/507984f2e28c7dfed5db9a20acd68beb969c7f2833abc9e582e967fa0291f3dc.ec06af3e1b426682955dab3bd553eaf178b6eafac9079fc133925e0e2654213e.lock
# 10/26/2021 20:56:12 - INFO - farm.utils -   device: cpu n_gpu: 0, distributed training: False, automatic mixed precision training: None
# 10/26/2021 20:56:12 - INFO - farm.infer -   Got ya 1 parallel workers to do inference ...
# 10/26/2021 20:56:12 - INFO - farm.infer -    0
# 10/26/2021 20:56:12 - INFO - farm.infer -   /w\
# 10/26/2021 20:56:12 - INFO - farm.infer -   /'\
# 10/26/2021 20:56:12 - INFO - farm.infer -

# %%
# Some questions that "work":
reader.predict(query="Where is Pioneer Boulevard located?", documents=[doc])
# Out:
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.36s/ Batches]
# {'answers': [{'answer': 'Los Angeles',
#    'context': 'The traffic began to slow down on Pioneer Boulevard in Los Angeles, making it difficult to get out of the city. However, WBGO was playing some cool ja',
#    'document_id': '43cd0a6d-309a-4447-833e-3104d4d770d6',
#    'offset_end': 66,
#    'offset_end_in_doc': 66,
#    'offset_start': 55,
#    'offset_start_in_doc': 55,
#    'probability': 0.8022720407759694,
#    'score': 11.204444885253906}],
#  'no_ans_gap': 10.056233644485474,
#  'query': 'Where is Pioneer Boulevard located?'}

# %%
reader.predict(query="Who drove to Las Vegas?", documents=[doc])
# Out:
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.36s/ Batches]
# {'answers': [{'answer': 'Jo and Maria',
#    'context': 't of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow. They plann',
#    'document_id': '43cd0a6d-309a-4447-833e-3104d4d770d6',
#    'offset_end': 81,
#    'offset_end_in_doc': 305,
#    'offset_start': 69,
#    'offset_start_in_doc': 293,
#    'probability': 0.8081118598422171,
#    'score': 11.502303123474121}],
#  'no_ans_gap': 3.7832393646240234,
#  'query': 'Who drove to Las Vegas?'}

# %%
reader.predict(query="Who is singing?", documents=[doc])
# Out:
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.31s/ Batches]
# {'answers': [{'answer': 'Nat King Cole',
#    'context': 'r pleasant to be making it out of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and dro',
#    'document_id': '43cd0a6d-309a-4447-833e-3104d4d770d6',
#    'offset_end': 82,
#    'offset_end_in_doc': 277,
#    'offset_start': 69,
#    'offset_start_in_doc': 264,
#    'probability': 0.8818637380522947,
#    'score': 16.08159065246582}],
#  'no_ans_gap': 12.141636371612549,
#  'query': 'Who is singing?'}

# %%
reader.predict(query="What is the plan for the night?", documents=[doc])
# Out:
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.45s/ Batches]
# {'answers': [{'answer': 'They planned to get to Las Vegas early enough in the evening to have a nice dinner and go see a show',
#    'context': 'de their way out of LA and drove toward Barstow. They planned to get to Las Vegas early enough in the evening to have a nice dinner and go see a show.',
#    'document_id': '43cd0a6d-309a-4447-833e-3104d4d770d6',
#    'offset_end': 149,
#    'offset_end_in_doc': 464,
#    'offset_start': 49,
#    'offset_start_in_doc': 364,
#    'probability': 0.7315709517637423,
#    'score': 8.02086067199707}],
#  'no_ans_gap': 6.077342867851257,
#  'query': 'What is the plan for the night?'}

# %%
# Some questions where is the answer is not in the text (and the model therefore cannot find it)
# If you inspect the results, you will see that the value "no_ans_gap" is negative for all these questions
# and actually indicates that the likelihood of "no answer" is higher than the best textual answer

questions = ["Where is Los Angeles Located?", "Where is Barstow Located?", "Where is Las Vegas located?"]
for q in questions:
  result = reader.predict(query=q, documents=[doc])
  print(result)
  print("\n")
# Out:
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.47s/ Batches]
# {'query': 'Where is Los Angeles Located?', 'no_ans_gap': -0.20559561252593994, 'answers': [{'answer': 'Pioneer Boulevard in Los Angeles, making it difficult to get out of the city. However, WBGO was playing some cool jazz, and the weather was cool, making it rather pleasant to be making it out of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow', 'score': 1.4833585023880005, 'probability': 0.5462225993210228, 'context': 'Pioneer Boulevard in Los Angeles, making it difficult to get out of the city. However, WBGO was playing some cool jazz, and the weather was cool, making it rather pleasant to be making it out of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow', 'offset_start': 0, 'offset_end': 328, 'offset_start_in_doc': 34, 'offset_end_in_doc': 362, 'document_id': '43cd0a6d-309a-4447-833e-3104d4d770d6'}]}
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.39s/ Batches]
# {'query': 'Where is Barstow Located?', 'no_ans_gap': -0.08532571792602539, 'answers': [{'answer': 'Las Vegas', 'score': 2.4290270805358887, 'probability': 0.5753292652102824, 'context': 'de their way out of LA and drove toward Barstow. They planned to get to Las Vegas early enough in the evening to have a nice dinner and go see a show.', 'offset_start': 72, 'offset_end': 81, 'offset_start_in_doc': 387, 'offset_end_in_doc': 396, 'document_id': '43cd0a6d-309a-4447-833e-3104d4d770d6'}]}
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.38s/ Batches]
# {'query': 'Where is Las Vegas located?', 'no_ans_gap': -3.248275399208069, 'answers': [{'answer': 'Barstow', 'score': -0.5793629884719849, 'probability': 0.481902815460107, 'context': 'inging as Jo and Maria slowly made their way out of LA and drove toward Barstow. They planned to get to Las Vegas early enough in the evening to have ', 'offset_start': 72, 'offset_end': 79, 'offset_start_in_doc': 355, 'offset_end_in_doc': 362, 'document_id': '43cd0a6d-309a-4447-833e-3104d4d770d6'}]}

# %%
# We can also directly make use of this "no answer" option and allow our reader to return "no answer"
# (indicated via "answer: None" in the results) by the enabling arg in the FARMReader:
reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2", use_gpu=True, no_ans_boost=0, return_no_answer=True)
for q in questions:
  result = reader.predict(query=q, documents=[doc])
  print(result)
  print("\n")
# Out:
# 10/26/2021 21:45:11 - INFO - farm.utils -   device: cpu n_gpu: 0, distributed training: False, automatic mixed precision training: None
# 10/26/2021 21:45:11 - INFO - farm.infer -   Could not find `deepset/roberta-base-squad2` locally. Try to download from model hub ...
# Some weights of RobertaModel were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 10/26/2021 21:45:16 - WARNING - farm.modeling.language_model -   Could not automatically detect from language model name what language it is.
# 	 We guess it's an *ENGLISH* model ...
# 	 If not: Init the language model by supplying the 'language' param.
# 10/26/2021 21:45:23 - INFO - farm.utils -   device: cpu n_gpu: 0, distributed training: False, automatic mixed precision training: None
# 10/26/2021 21:45:23 - INFO - farm.infer -   Got ya 1 parallel workers to do inference ...
# 10/26/2021 21:45:23 - INFO - farm.infer -    0
# 10/26/2021 21:45:23 - INFO - farm.infer -   /w\
# 10/26/2021 21:45:23 - INFO - farm.infer -   /'\
# 10/26/2021 21:45:23 - INFO - farm.infer -
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.04s/ Batches]
# {'query': 'Where is Los Angeles Located?', 'no_ans_gap': -0.20559561252593994, 'answers': [{'answer': None, 'score': 1.6889541149139404, 'probability': 0.5525846469958149, 'context': None, 'offset_start': 0, 'offset_end': 0, 'document_id': None, 'meta': None}, {'answer': 'Pioneer Boulevard in Los Angeles, making it difficult to get out of the city. However, WBGO was playing some cool jazz, and the weather was cool, making it rather pleasant to be making it out of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow', 'score': 1.4833585023880005, 'probability': 0.5462225993210228, 'context': 'Pioneer Boulevard in Los Angeles, making it difficult to get out of the city. However, WBGO was playing some cool jazz, and the weather was cool, making it rather pleasant to be making it out of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow', 'offset_start': 0, 'offset_end': 328, 'offset_start_in_doc': 34, 'offset_end_in_doc': 362, 'document_id': '43cd0a6d-309a-4447-833e-3104d4d770d6'}]}
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.04s/ Batches]
# {'query': 'Where is Barstow Located?', 'no_ans_gap': -0.08532571792602539, 'answers': [{'answer': None, 'score': 2.514352798461914, 'probability': 0.5779330546433098, 'context': None, 'offset_start': 0, 'offset_end': 0, 'document_id': None, 'meta': None}, {'answer': 'Las Vegas', 'score': 2.4290270805358887, 'probability': 0.5753292652102824, 'context': 'de their way out of LA and drove toward Barstow. They planned to get to Las Vegas early enough in the evening to have a nice dinner and go see a show.', 'offset_start': 72, 'offset_end': 81, 'offset_start_in_doc': 387, 'offset_end_in_doc': 396, 'document_id': '43cd0a6d-309a-4447-833e-3104d4d770d6'}]}
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.03s/ Batches]
# {'query': 'Where is Las Vegas located?', 'no_ans_gap': -3.248275399208069, 'answers': [{'answer': None, 'score': 3.248275399208069, 'probability': 0.6001366282481166, 'context': None, 'offset_start': 0, 'offset_end': 0, 'document_id': None, 'meta': None}, {'answer': 'Barstow', 'score': -0.5793629884719849, 'probability': 0.481902815460107, 'context': 'inging as Jo and Maria slowly made their way out of LA and drove toward Barstow. They planned to get to Las Vegas early enough in the evening to have ', 'offset_start': 72, 'offset_end': 79, 'offset_start_in_doc': 355, 'offset_end_in_doc': 362, 'document_id': '43cd0a6d-309a-4447-833e-3104d4d770d6'}]}
